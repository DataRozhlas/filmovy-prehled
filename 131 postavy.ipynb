# %%
import os
import pandas as pd
herectvo = pd.read_json(os.path.join("data", "herectvo.json"))
pd.set_option('display.max_columns', None)

# %%
herectvo = herectvo.explode("Role")
herectvo = herectvo.explode("Úloha")
herectvo = herectvo[herectvo["Úloha"] == "Hrají"]

# %% [markdown]
# ## Explorace

# %%
herectvo.sample(5)
# Out:
#                            Jméno
# 14683      Oldřich Velen (12725)  \
# 12486       Václav Král (126879)
# 9835   Miloslav Šindler (126517)
# 16268     Vladimír Řepa (127334)
# 58568         Zeno Dostál (4948)
#
#                                                      Bio Datum narození
# 14683  OLDŘICH VELEN (vl. jm. Oldřich Volek, nar. 15....     15.09.1921  \
# 12486                                               None     28.12.1919
# 9835                                                None           1928
# 16268                                               None     08.11.1900
# 58568                                               None     12.11.1934
#
#                             Místo narození Datum úmrtí
# 14683        Tuřany u Brna, Československo  04.05.2013  \
# 12486                Praha, Československo  20.03.2000
# 9835                                  None        19??
# 16268              Praha, Rakousko-Uhersko  19.08.1957
# 58568  Konice u Prostějova, Československo  30.01.1996
#
#                   Místo úmrtí                           Titul
# 14683  Praha, Česká republika                     Tažní ptáci  \
# 12486   Praha, Československo             Jezdec formule risk
# 9835                     None                   Mykoin PH 510
# 16268   Praha, Československo  Schůze obecního zastupitelstva
# 58568  Praha, Česká republika                  Pozor, vizita!
#
#                                           Film   Rok  Úloha
# 14683                     Tažní ptáci (396437)  1961  Hrají  \
# 12486             Jezdec formule risk (396987)  1973  Hrají
# 9835                    Mykoin PH 510 (396536)  1963  Hrají
# 16268  Schůze obecního zastupitelstva (400419)  1952  Hrají
# 58568                  Pozor, vizita! (397338)  1981  Hrají
#
#                                          Role
# 14683                               hostinský  \
# 12486               vrátný v hotelu Esplanade
# 9835                                    lékař
# 16268  myslivec Machlíček, starostův náměstek
# 58568                                   lékař
#
#                       Alternativní jména       Město narození
# 14683        Oldřich Volek (rodné jméno)        Tuřany u Brna  \
# 12486                               None                Praha
# 9835      Miroslav Šindler (chybný tvar)                 None
# 16268  Josef Vladimír Řepa (rodné jméno)                Praha
# 58568                ZEDO (šifra autora)  Konice u Prostějova
#
#            Stát narození       Město úmrtí        Stát úmrtí  Rok narození
# 14683     Československo   Česká republika   Česká republika        1921.0  \
# 12486     Československo    Československo    Československo        1919.0
# 9835                None              None              None        1928.0
# 16268   Rakousko-Uhersko    Československo    Československo        1900.0
# 58568     Československo   Česká republika   Česká republika        1934.0
#
#         Věk
# 14683  40.0
# 12486  54.0
# 9835   35.0
# 16268  52.0
# 58568  47.0

# %%
herectvo_ciste = herectvo

# %%
herectvo_ciste["Role"].nunique()
# Out:
# 46511

# %%
herectvo_ciste.groupby("Role")["Film"].nunique().nlargest(50)
# Out:
# Role
# lékař                222
# číšník               176
# hostinský            156
# hudebník             148
# farář                108
# příslušník VB        108
# sousedka             107
# strážník             107
# policista            104
# vrátný                85
# zdravotní sestra      83
# fotograf              81
# listonoš              81
# babička               80
# učitelka              80
# student               79
# dělník                78
# dívka                 77
# učitel                77
# matka                 75
# tanečnice             74
# sekretářka            72
# tanečník              70
# četník                68
# hospodský             67
# voják                 67
# Petr                  66
# taxikář               65
# otec                  64
# úředník               64
# mladík                60
# profesor              59
# dirigent              58
# řidič                 57
# starosta              55
# domovnice             54
# kameraman             54
# recepční              54
# soudce                53
# zpěvačka              53
# kněz                  50
# vrchní                50
# policejní komisař     49
# prodavačka            48
# soused                48
# zpěvák                47
# novinář               46
# režisér               46
# strážmistr VB         46
# tajný                 46
# Name: Film, dtype: int64

# %% [markdown]
# ## Muž s / žena s

# %%
herectvo[herectvo["Role"].str.lower().str.contains("muž s |muž se ")]["Role"].drop_duplicates().to_list()
# Out:
# ['muž s dýmkou',
#  'muž se smrčkem',
#  'muž s trikolorami',
#  'muž se sametovým hlasem',
#  'muž s pistolí',
#  'delegát-muž s ňadry',
#  'muž s vlčími máky',
#  'muž s luxem',
#  'muž se sklem',
#  'muž s deštníkem',
#  'fotograf/muž s hracími hodinkami',
#  'muž s podobou císaře Viléma II.',
#  'muž s brokovnicí',
#  'muž s cigaretou',
#  'muž s knihou',
#  'muž s rozsudkem',
#  'muž s balóny',
#  'muž s brýlemi',
#  'muž s činkou',
#  'muž s kyticí',
#  'muž s úmrtním oznámením',
#  'Chrůma, muž s nůší',
#  'muž s pondělníkem',
#  'muž s novinami v kavárně',
#  'muž s dívkou',
#  'muž s buřinkou u vozu',
#  'muž s hadicí',
#  'muž se sudem',
#  'muž s pivem',
#  'muž s holí',
#  'muž s rádiovkou v tramvaji',
#  'muž s tuhým límcem, člen poroty',
#  'muž se sklenkou ve služebním autě',
#  'muž s bradkou',
#  'muž s novinami',
#  'muž s cvikrem na ulici',
#  'muž s gramofonem v okně',
#  'muž s plnovousem',
#  'muž s bolavým zubem',
#  'muž se svíčkou na přednášce',
#  'muž s aktovkou',
#  'muž s účesem na ježka',
#  'muž s hodinkami',
#  'muž s dalekohledem',
#  'muž s baretem na ulici',
#  'muž s ručníkem',
#  'muž s rampouchem',
#  'muž s kočkou',
#  'muž s mopedem',
#  'muž s pancéřovou pěstí',
#  'muž s harmoniem',
#  'muž s fajfkou z domu',
#  'muž s bombou',
#  'muž se psem',
#  'hráč šachů, muž s bradkou',
#  'muž se sirkou v ústech',
#  'muž s vlajkou',
#  'muž s rourami zvaný Šíša',
#  'muž s demižonem ve služebním autě',
#  'muž s chobotnicí',
#  'muž s tranzistorákem',
#  'muž s růžovýma ušima',
#  'muž s palicí',
#  'muž s bedýnkou',
#  'muž s kšiltovkou',
#  'muž s legitimací',
#  'muž s kufrem',
#  'muž s podobou císaře Františka Josefa I.',
#  'muž s kravatou',
#  'host ve vinárně/muž s kočárkem',
#  'muž s nůžkami',
#  'muž s mikrofonem',
#  'muž s Večerní Prahou',
#  'muž s čokoládou',
#  'muž s baňkou',
#  'snědý muž s kinžálem',
#  'muž s hadem',
#  'muž s plastikou',
#  'muž s provázkem v hospodě',
#  'muž s příborem',
#  'muž s monoklem',
#  'muž s knírem',
#  'muž s ovázaným psem',
#  'muž s anténou',
#  'muž se zápalkou',
#  'muž s cvikrem',
#  'muž s krosničkou',
#  'muž s tranzistorovým rádiem/havíř v tramvaji',
#  'muž s kotletami',
#  'muž se sklenkou alkoholu',
#  'muž s cvikrem na svatbě',
#  'muž s televizí',
#  'muž s taškou',
#  'muž s Tondou',
#  'muž se zlomenou nohou',
#  'muž s páskou na oku',
#  'opilý muž s Marcelou',
#  'flašinetář/muž s gramofonem',
#  'muž s klíči',
#  'muž se samopalem',
#  'muž s raketou',
#  'muž s hodinami v zastavárně',
#  'muž s králíkem v tašce',
#  'Vašek, muž s příčeskem',
#  'policejní prefekt/muž s vázou',
#  'muž s batohem',
#  'Muž s vějíři',
#  'muž se stolním ohňostrojem',
#  'muž s přilbou',
#  'muž s renaultem',
#  'muž s kaprem',
#  'muž s bílou šálou',
#  'muž s vosím hnízdem',
#  'muž s vozítkem s knihami',
#  'muž s buřtem a novinami',
#  'muž s úhledným knírem',
#  'Muž s tyčí',
#  'muž s ohněm',
#  'muž se šálou',
#  'muž s pometlem',
#  'sledující muž s bradkou',
#  'muž s převráceným autem',
#  'muž s vázou',
#  'muž s pírkem',
#  'muž s telefonem',
#  'muž s dmuchavkou',
#  'muž s pronikavým pohledem',
#  'muž s licousy',
#  'muž s pohřebním věncem',
#  'muž s basou',
#  'muž s lasturou',
#  'člen Kandrtovy skupiny/muž s basou piva',
#  'kanárský policista/muž s walkmanem',
#  'muž s puškou',
#  'muž se psem v parku',
#  'starší muž s kolem',
#  'muž s hodinami na policejním ředitelství',
#  'muž s chrty',
#  'muž s buřinkou/opilec',
#  'vousatý muž se zlomenou nohou',
#  'muž s dámou',
#  'muž se psem/dubl za Petra Čepka',
#  'muž s gramodeskami']

# %%
herectvo[herectvo["Role"].str.lower().str.contains("žena s |žena se ")]["Role"].drop_duplicates().to_list()
# Out:
# ['žena s psíkem',
#  'žena s pomerančem',
#  'cestující v letadle-žena s psíčkem',
#  'žena s kočkou',
#  'žena se psem',
#  'žena s kokrhelem',
#  'žena se džbánem',
#  'žena s dítětem',
#  'žena s koláčky',
#  'Váchová, žena s kufrem',
#  'žena s natáčkami',
#  'žena s dítětem Jarouškem, manželka jednoho z vězňů',
#  'žena s nákupem',
#  'žena s kyticí',
#  'žena se synem',
#  'žena s gumovými hračkami',
#  'žena s děckem ve vlaku',
#  'žena s dítětem ve vlaku',
#  'Koreška, žena s chrastím',
#  'žena s cigaretou',
#  'žena s kočárkem',
#  'žena s plnovousem v panoptiku',
#  'žena s knihou',
#  'žena se závojem/žena u teroristů',
#  'Pokorná, žena se zánětem spojivek',
#  'židovská žena s dítětem',
#  'žena s taškou',
#  'žena s chocholem',
#  'žena se židlí',
#  'stará žena s deštníkem',
#  'žena s fotoaparátem',
#  'mladá žena s odpadky',
#  'žena s nákupní taškou',
#  'žena s puškou – symbol osvobození',
#  'žena s kolem',
#  'zvědavá žena s kukátkem',
#  'žena s šátkem v tramvaji',
#  'žena s dětmi v hospodě',
#  'žena s hřebenem',
#  'žena se psem, vcházející do domu',
#  'žena s cigaretovou špičkou',
#  'žena s kožichem',
#  'žena s kufrem',
#  'žena s micinkou',
#  'žena s hrncem horké vody',
#  'žena s dračími zuby',
#  'žena s ručníkem',
#  'žena s taškami',
#  'žena s dítětem před továrnou',
#  'žena s melounem v Čedoku',
#  'žena s prádlem',
#  'žena s deštníkem na zastávce']

# %% [markdown]
# ## Pokus o sjednocení

# %%
herectvo[herectvo["Role"].str.lower().str.contains("sousedk")]["Role"].drop_duplicates().to_list()
# Out:
# ['sousedka',
#  'paní Hanušová, Tomášova a Terezina sousedka',
#  'sousedka Alena Bartáčková',
#  'sousedka Rozkošná',
#  'malířka Somráčková, sousedka Starablažkové',
#  'sousedka u řeky',
#  'sousedka Bárová',
#  'Klikova sousedka',
#  'sousedka Lenka Fazurová',
#  'sousedka Nováková',
#  'sousedka v hospodě',
#  'Helenina sousedka Stárková',
#  'sousedka Zachová',
#  'sousedka Marková',
#  'sousedka Richterová',
#  'sousedka Paličková',
#  'sousedka Nevyjelové',
#  'Polánková, sousedka Hadrbolcových',
#  'sousedka panímáma Pazdírková',
#  'energická sousedka',
#  'sousedka Trčkové na schodech',
#  'sousedka/hysterická žena',
#  'sousedka Spáčilová',
#  'sousedka Nýčová',
#  'Antonie Houdková, Faunova sousedka',
#  'stará sousedka',
#  'sousedka Čeledová',
#  'sousedka Endlová',
#  'sousedka Zacharové',
#  'Toniččina sousedka',
#  'Márinka, sousedka Bláhové',
#  'sousedka Čtvrtečková',
#  'sousedka Janurových',
#  'sousedka Meruňková',
#  'Kolovecká, Víťova sousedka',
#  'sousedka Knedlhansová',
#  'sousedka tety Kláry',
#  'sousedka Radačka',
#  'sousedka pana Nováka',
#  'sousedka Landové',
#  'řečná sousedka',
#  'sousedka Silná',
#  'Bulínova sousedka',
#  'Vojtíškova sousedka',
#  'Fafejtová, sousedka Šimůnkové',
#  'sousedka paní Kokošková',
#  'sousedka Hlubinových',
#  'sousedka Jirákových',
#  'sousedka paní Tomanové',
#  'sousedka v lóži',
#  'sousedka Borových',
#  'vlezlá sousedka',
#  'sousedka v domě',
#  'Brabcova sousedka',
#  'dámička, sousedka Dulských z parteru',
#  'horlivá sousedka',
#  'mladá sousedka Věra',
#  'sousedka Zemková, bývalá učitelka',
#  'sousedka Beranová',
#  'koktavá sousedka věšící prádlo',
#  'sousedka Píšková',
#  'sousedka Brtková',
#  'sousedka Hyacinty Horákové',
#  'sousedka Šomkových',
#  'sousedka pana Straky',
#  'sousedka paní Holarové',
#  'sousedka Kodetová',
#  'sousedka Nekvasilová',
#  'keramička Věra Staňková, sousedka Bernátových',
#  'sousedka Voborníková',
#  'sousedka Stránská',
#  'sousedka s pomerančem',
#  'sousedka Rampasová',
#  'sousedka v růžovém',
#  'zpěvačka, Fifkova sousedka',
#  'sousedka Holanová',
#  'sousedka Hradská',
#  'sousedka Kautská',
#  'sousedka Eva',
#  'Blanka, Petrova sousedka',
#  'sousedka Mařáčková',
#  'sousedka Staňková',
#  'Kujalová, sousedka Chybové',
#  'sousedka Malásková',
#  'mladá sousedka',
#  'sousedka na ulici',
#  'sousedka 2',
#  'sousedka Malinová',
#  'sousedka Mlejnková',
#  'sousedka Tloukalová',
#  'sousedka Pimpárová',
#  'sousedka Jiřiny',
#  'sousedka Heleny',
#  'syn sousedky',
#  'Markova sousedka',
#  'sousedka prostitutky',
#  'sousedka Holovská',
#  'sousedka Bartáková',
#  'sousedka Kalendová',
#  'Šimková, Provazníkova sousedka',
#  'sousedka Círová',
#  'sousedka Součková',
#  'švadlena Prokopová, Bendova sousedka',
#  'Švejkova sousedka na pavlači',
#  'sousedka na chodbě',
#  'sousedka peroucí prádlo',
#  'sousedka Nohejlová',
#  'sousedka deroucí peří',
#  'sousedka Hovorková',
#  'kadeřnice Dáša, Evina sousedka',
#  'Sochorova žena, sousedka Znamínkových',
#  'sousedka Jarošová',
#  'Koudelková, sousedka Kohoutových',
#  'sousedka paní Žandová',
#  'Bradáčová, Novákova sousedka',
#  'sousedka, Evina matka',
#  'sousedka Paseková',
#  'Knotkova sousedka',
#  'Filip, vnuk Knotkovy sousedky',
#  'sousedka s natáčkami',
#  'sousedka Nyklíčkových',
#  'Alenina sousedka',
#  'sousedka Cajthamlová',
#  'sousedka Šimonových',
#  'sousedka Fusková',
#  'sousedka v domě u Kalendy',
#  'sousedka a hokynářka Běta',
#  'sousedka Krásová',
#  'sousedka Květa Ronešová',
#  'sousedka Pospíšilová',
#  'Helenina sousedka',
#  'sousedka Merenda',
#  'Otakarova sousedka',
#  'sousedka 1',
#  'sousedka Laubová',
#  'sousedka na pavlači',
#  'sousedka Niederlová',
#  'sousedka Rybová',
#  'pošťačka Krobová, sousedka Palachových',
#  'sousedka Věruška Holubová, Jiřího matka',
#  'sousedka Hrdličková',
#  'sousedka Skuhrovcová, Danielina teta',
#  'sousedka Růža',
#  'Díďa Kánská-Valentová, Helbichova sousedka',
#  'sousedka Veselá',
#  'Jindřina sousedka',
#  'sousedka se psem',
#  'sousedka Veronika zvaná Rybička',
#  'Bohunka, Danina sousedka',
#  'Milanova sousedka',
#  'sousedka profesora Syřiště',
#  'Slávčina sousedka',
#  'sousedka Koudelková',
#  'sousedka Šefránková',
#  'sousedka Černá',
#  'sousedka Květa',
#  'sousedka Kuncová, Vaškova matka',
#  'sousedka Helena, Olžina kamarádka',
#  'sousedka Tichá',
#  'sousedka Kroupových',
#  'Terezka, sousedka',
#  'Mráčkova sousedka',
#  'sousedka Matylda Krpatovická',
#  'sousedka Eva Vávrová',
#  'hluchá sousedka Kosová',
#  'sousedka Valoušková',
#  'sousedka Karase',
#  'Pepíčkova sousedka',
#  'sousedka Vyoralová',
#  'sousedka a teta Anežka Poláková',
#  'sousedka Šulcová',
#  'Jonášová, Helenina sousedka',
#  'sousedka Švestková',
#  'Karásková, sousedka Koskubových',
#  'sousedka Zelená',
#  'sousedka na schodech',
#  'sousedka Málková',
#  'sousedka Vláčilová',
#  'hlas sousedky Nevyjelové',
#  'Pecháčková, sousedka Pokorných',
#  'hlas sousedky s koštětem',
#  'Jarošová, Helenina sousedka',
#  'sousedka-kuchařka',
#  'sousedka Doubravová',
#  'sousedka Emilie',
#  'sousedka paní starostové',
#  'Helenina sousedka Kalousová',
#  'sousedka Šimková',
#  'sousedka Vaníčková',
#  'sousedka Margita, bývalá jeptiška',
#  'sousedka se slepicí']

# %%
nahrazeni = {
    "příslušník VB": "policista",
    "příslušník SNB": "policista",
    "nadstrážmistr VB": "policista",
    "hospodský": "hostinský",
    "doktor": "lékař",
    "vrchní číšník": "hostinský",
    "číšník v restauraci": "hostinský",
    "vrchní ve vinárně": "hostinský",
    "vrchní": "hostinský",
    "četník": "policista",
    "strážník": "policista",
    "policejní komisař": "policista",
    "kriminalista": "policista",
    "číšník": "hostinský",
    "strážmistr VB": "policista",
    "policejní inspektor": "policista",
    "kněz": "farář",
    "redaktor": "novinář",
    "výčepní": "hostinský",
    "praporčík VB": "policista",
    "podpraporčík VB": "policista",
    "poručík VB": "policista",
    "strážmistr": "policista",
    "primář": "lékař",
    "lékař v nemocnici": "lékař",
    "šofér": "řidič",
    "tajný policista": "policista",
    "tajný": "policista",
    "policejní úředník": "policista",
    "příslušník StB'": "policista",
    "číšník v Savarinu": "hostinský",
    "číšník na večírku": "hostinský",
    "číšník v baru": "hostinský",
    "vrchní v letní restauraci": "hostinský",
    "vrchní sestra": "zdravotní sestra",
    "řidič nákladního auta": "řidič",
    "šofér": "řidič",
    "tatínek": "otec",
    "maminka": "matka"
}

# %%
herectvo["Role"].nunique()
# Out:
# 46511

# %%
herectvo["Role"] = herectvo["Role"].replace(nahrazeni)

# %%
herectvo["Role"].nunique()
# Out:
# 46474

# %%
herectvo.groupby("Role")["Film"].nunique().nlargest(60)
# Out:
# Role
# policista           570
# hostinský           482
# lékař               298
# farář               158
# hudebník            148
# sousedka            107
# zdravotní sestra    107
# matka               103
# řidič                99
# vrátný               85
# otec                 82
# fotograf             81
# listonoš             81
# babička              80
# novinář              80
# učitelka             80
# student              79
# dělník               78
# dívka                77
# učitel               77
# tanečnice            74
# sekretářka           72
# tanečník             70
# voják                67
# Petr                 66
# taxikář              65
# úředník              64
# mladík               60
# profesor             59
# dirigent             58
# starosta             55
# domovnice            54
# kameraman            54
# recepční             54
# soudce               53
# zpěvačka             53
# prodavačka           48
# soused               48
# zpěvák               47
# režisér              46
# železničář           46
# Honza                44
# barman               43
# detektiv             43
# Eva                  42
# reportér             42
# ředitel školy        42
# kluk                 41
# důstojník            39
# komorník             39
# kuchař               39
# servírka             39
# vesničan             38
# pacient              37
# Jana                 36
# Marie                36
# Martin               36
# muž                  36
# strážný              36
# průvodčí             35
# Name: Film, dtype: int64

# %%
top100roli = herectvo.groupby("Role")["Film"].nunique().nlargest(100).index.to_list()
", ".join(top100roli)
# Out:
# 'policista, hostinský, lékař, farář, hudebník, sousedka, zdravotní sestra, matka, řidič, vrátný, otec, fotograf, listonoš, babička, novinář, učitelka, student, dělník, dívka, učitel, tanečnice, sekretářka, tanečník, voják, Petr, taxikář, úředník, mladík, profesor, dirigent, starosta, domovnice, kameraman, recepční, soudce, zpěvačka, prodavačka, soused, zpěvák, režisér, železničář, Honza, barman, detektiv, Eva, reportér, ředitel školy, kluk, důstojník, komorník, kuchař, servírka, vesničan, pacient, Jana, Marie, Martin, muž, strážný, průvodčí, studentka, Tomáš, dítě, inspicient, opilec, sedlák, vyšetřovatel, ředitel, školník, advokát, sluha, úřednice, žena, Karel, dědeček, gestapák, host v baru, domovník, dozorce, herec, holčička, kuchařka, stěhovák, uklízečka, řezník, Pavel, harmonikář, psychiatr, šermíři, Marta, barmanka, klavírista, hostinská, ministr, rybář, zedník, Anna, Jirka, Lenka, chlapec'

# %%
jmena = ["Petr","Eva","Jana","Marie","Martin","Tomáš","Karel","Marta","Pavel","Anna","Jirka"]

# %%
herectvo["Role"].nunique()
# Out:
# 46474

# %%
for t in top100roli:
    if t not in jmena:
        herectvo.loc[herectvo['Role'].str.contains(t), 'Role'] = t

# %%
herectvo["Role"].nunique()
# Out:
# 32491

# %%
herectvo.groupby("Role")["Film"].nunique().nlargest(60)
# Out:
# Role
# žena                1183
# matka                986
# otec                 920
# muž                  714
# policista            624
# ředitel              616
# hostinský            585
# lékař                563
# učitel               444
# řidič                426
# soused               377
# dívka                370
# profesor             311
# úředník              306
# vrátný               286
# student              268
# sekretářka           259
# sluha                238
# babička              221
# dělník               210
# farář                205
# hudebník             204
# voják                189
# prodavačka           185
# mladík               179
# zdravotní sestra     176
# důstojník            173
# kuchař               172
# režisér              169
# fotograf             165
# úřednice             165
# tanečnice            156
# Honza                151
# herec                151
# zpěvačka             150
# zpěvák               145
# listonoš             142
# novinář              139
# starosta             136
# tanečník             126
# pacient              124
# kluk                 123
# reportér             123
# dirigent             121
# barman               116
# komorník             115
# recepční             109
# detektiv             104
# sedlák               103
# dědeček              101
# servírka              98
# soudce                98
# průvodčí              92
# taxikář               92
# advokát               91
# kameraman             89
# dozorce               88
# chlapec               87
# dítě                  87
# domovnice             86
# Name: Film, dtype: int64

# %%
top20roli = herectvo.groupby("Role")["Film"].nunique().nlargest(20).index.to_list()
top20roli
# Out:
# ['žena',
#  'matka',
#  'otec',
#  'muž',
#  'policista',
#  'ředitel',
#  'hostinský',
#  'lékař',
#  'učitel',
#  'řidič',
#  'soused',
#  'dívka',
#  'profesor',
#  'úředník',
#  'vrátný',
#  'student',
#  'sekretářka',
#  'sluha',
#  'babička',
#  'dělník']

# %%
herectvo.groupby("Role")["Film"].nunique().nlargest(1000).index.to_list()
# Out:
# ['žena',
#  'matka',
#  'otec',
#  'muž',
#  'policista',
#  'ředitel',
#  'hostinský',
#  'lékař',
#  'učitel',
#  'řidič',
#  'soused',
#  'dívka',
#  'profesor',
#  'úředník',
#  'vrátný',
#  'student',
#  'sekretářka',
#  'sluha',
#  'babička',
#  'dělník',
#  'farář',
#  'hudebník',
#  'voják',
#  'prodavačka',
#  'mladík',
#  'zdravotní sestra',
#  'důstojník',
#  'kuchař',
#  'režisér',
#  'fotograf',
#  'úřednice',
#  'tanečnice',
#  'Honza',
#  'herec',
#  'zpěvačka',
#  'zpěvák',
#  'listonoš',
#  'novinář',
#  'starosta',
#  'tanečník',
#  'pacient',
#  'kluk',
#  'reportér',
#  'dirigent',
#  'barman',
#  'komorník',
#  'recepční',
#  'detektiv',
#  'sedlák',
#  'dědeček',
#  'servírka',
#  'soudce',
#  'průvodčí',
#  'taxikář',
#  'advokát',
#  'kameraman',
#  'dozorce',
#  'chlapec',
#  'dítě',
#  'domovnice',
#  'ministr',
#  'železničář',
#  'vyšetřovatel',
#  'opilec',
#  'uklízečka',
#  'vesničan',
#  'Lenka',
#  'řezník',
#  'Petr',
#  'strážný',
#  'zedník',
#  'školník',
#  'psychiatr',
#  'domovník',
#  'holčička',
#  'inspicient',
#  'klavírista',
#  'harmonikář',
#  'hostinská',
#  'Eva',
#  'rybář',
#  'gestapák',
#  'host v baru',
#  'Jana',
#  'Marie',
#  'Martin',
#  'Tomáš',
#  'Karel',
#  'stěhovák',
#  'šermíři',
#  'Pavel',
#  'Marta',
#  'Anna',
#  'Jirka',
#  'děda',
#  'host v hospodě',
#  'generál',
#  'host',
#  'host na večírku',
#  'kamelot',
#  'ženich',
#  'Michal',
#  'komorná',
#  'květinářka',
#  'ošetřovatelka',
#  'prodavač',
#  'rváč',
#  'venkovan',
#  'hajný',
#  'kapelník',
#  'major',
#  'obhájce',
#  'předseda soudu',
#  'svatebčan',
#  'svatebčanka',
#  'zahradník',
#  'Eliška',
#  'Irena',
#  'Klára',
#  'karbaník',
#  'komisař',
#  'kostelník',
#  'nevěsta',
#  'služka',
#  'závozník',
#  'Franta',
#  'dáma',
#  'kovář',
#  'kočí',
#  'pořadatel',
#  'stařenka',
#  'teta',
#  'výpravčí',
#  'zloděj',
#  'Alena',
#  'David',
#  'Jarda',
#  'Jitka',
#  'Věra',
#  'Zuzana',
#  'družstevník',
#  'houslista',
#  'inženýr',
#  'krejčí',
#  'ošetřovatel',
#  'prokurátor',
#  'vězeň',
#  'zřízenec',
#  'František',
#  'Helena',
#  'Jakub',
#  'Lucie',
#  'Pepa',
#  'Tereza',
#  'Viktor',
#  'Zdeněk',
#  'celník',
#  'král',
#  'lesník',
#  'lokaj',
#  'pokladní',
#  'příslušník SS',
#  'traktorista',
#  'šatnářka',
#  'Robert',
#  'dvorní dáma',
#  'myslivec',
#  'zákaznice',
#  'štamgast',
#  'Adam',
#  'Anička',
#  'Marcela',
#  'Mirek',
#  'Tonda',
#  'cizinec',
#  'holič',
#  'host ve vinárně',
#  'hráč karet',
#  'muzikant',
#  'měšťan',
#  'notář',
#  'plukovník',
#  'psycholog',
#  'zákazník',
#  'Josef',
#  'Pepík',
#  'cestující ve vlaku',
#  'dvořan',
#  'malíř',
#  'orchestr',
#  'poručík',
#  'prostitutka',
#  'zvukař',
#  'člen komise',
#  'šermíř',
#  'Filip',
#  'Hanka',
#  'Marek',
#  'Milan',
#  'cestující',
#  'chodec',
#  'exekutor',
#  'hasič',
#  'herečka',
#  'hlídač',
#  'kat',
#  'krčmář',
#  'lékárník',
#  'manžel',
#  'pěvecký sbor',
#  'rychtář',
#  'sestřička',
#  'číšnice',
#  'švadlena',
#  'Jiří',
#  'chasník',
#  'jeptiška',
#  'konferenciér',
#  'manželka',
#  'mistr',
#  'pan Tau',
#  'pikolík',
#  'přednosta stanice',
#  'správcová',
#  'tulák',
#  'vojín',
#  'Láďa',
#  'Petra',
#  'Vlasta',
#  'ceremoniář',
#  'hospodská',
#  'host v kavárně',
#  'hrobník',
#  'klaun',
#  'on sám',
#  'osvětlovač',
#  'policajt',
#  'písař',
#  'předseda senátu',
#  'skladník',
#  'tlumočnice',
#  'varhaník',
#  'šlechtic',
#  'žalářník',
#  'Jan',
#  'Kristýna',
#  'Linda',
#  'Lojza',
#  'Matěj',
#  'Němec',
#  'Richard',
#  'Vašek',
#  'Veronika',
#  'bezdomovec',
#  'brigádník',
#  'dřevorubec',
#  'inspektor',
#  'kolega',
#  'kytarista',
#  'laborantka',
#  'mechanik',
#  'mlynář',
#  'montér',
#  'pan domácí',
#  'penzista',
#  'pianista',
#  'porodní bába',
#  'právník',
#  'průvodce',
#  'předseda JZD',
#  'saniťák',
#  'stavbyvedoucí',
#  'technik',
#  'trenér',
#  'trpaslík',
#  'turista',
#  'uhlíř',
#  'čert',
#  'šéfredaktor',
#  'Dáša',
#  'Emil',
#  'Helenka',
#  'Ivan',
#  'Kateřina',
#  'Lída',
#  'Markéta',
#  'Patrik',
#  'Radek',
#  'básník',
#  'funkcionář',
#  'hlas',
#  'laborant',
#  'mistr v továrně',
#  'moderátor',
#  'pilot',
#  'předseda MNV',
#  'přísedící',
#  'státní zástupce',
#  'telefonistka',
#  'trafikant',
#  'tramp',
#  'vetešník',
#  'účetní',
#  'Alice',
#  'Hana',
#  'Jarmila',
#  'Martina',
#  'Olda',
#  'Ondřej',
#  'Standa',
#  'Václav',
#  'Vítek',
#  'architekt',
#  'babka',
#  'bubeník',
#  'divák',
#  'docent',
#  'havíř',
#  'host na svatbě',
#  'host v hotelu',
#  'kamarád',
#  'kaplan',
#  'kominík',
#  'královna',
#  'loutkoherečka',
#  'milenec',
#  'mlynářka',
#  'podomek',
#  'porotce',
#  'přísedící u soudu',
#  'rekvizitář',
#  'služebná',
#  'spolužák',
#  'strýc',
#  'tlumočník',
#  'trafikantka',
#  'vodník',
#  'vrchní v baru',
#  'vypravěč',
#  'Bára',
#  'Kryštof',
#  'Monika',
#  'baletka',
#  'bytná',
#  'cyklista',
#  'dispečer',
#  'drožkář',
#  'družstevnice',
#  'dubl',
#  'dělnice',
#  'gardista',
#  'hlasatel',
#  'host v hostinci',
#  'hraběnka',
#  'kapitán',
#  'klapka',
#  'kouzelník',
#  'lupič',
#  'milenka',
#  'náměstek',
#  'pobočník',
#  'pohraničník',
#  'popelář',
#  'portýr',
#  'párkař',
#  'příslušník StB',
#  'redaktorka',
#  'selka',
#  'skriptka',
#  'spolužačka',
#  'tajemník',
#  'tetička',
#  'továrník',
#  'vekslák',
#  'venkovanka',
#  'vrchní v kavárně',
#  'šafář',
#  'švec',
#  'šéf',
#  'žák',
#  'Bětka',
#  'Dana',
#  'Igor',
#  'Květa',
#  'Luboš',
#  'Magda',
#  'Mařenka',
#  'Miluška',
#  'Ondra',
#  'Oskar',
#  'Pavla',
#  'Renata',
#  'Roman',
#  'Tom',
#  'Toník',
#  'Zuzka',
#  'asistent',
#  'chůva',
#  'cikánka',
#  'dráb',
#  'hejtman',
#  'kadeřnice',
#  'klepna',
#  'kupec',
#  'manekýna',
#  'manekýnka',
#  'nadporučík VB',
#  'námořník',
#  'pokojská',
#  'pradlena',
#  'převozník',
#  'radní',
#  'slečna',
#  'správce',
#  'stárek',
#  'topič',
#  'čarodějnice',
#  'čeledín',
#  'číšník v kavárně',
#  'žebrák',
#  'Alžběta',
#  'Andrea',
#  'Jiřina',
#  'Julie',
#  'Katka',
#  'Lukáš',
#  'Sylva',
#  'anděl',
#  'bachař',
#  'biřic',
#  'bufetářka',
#  'cirkusák',
#  'diskžokej',
#  'doktorka',
#  'drogista',
#  'dětská role',
#  'děvečka',
#  'důchodce',
#  'hospodyně',
#  'houbař',
#  'klarinetista',
#  'kritik',
#  'kulisák',
#  'letuška',
#  'maskérka',
#  'mladý příslušník VB',
#  'mnich',
#  'nájemnice',
#  'obecní strážník',
#  'paní domácí',
#  'partyzán',
#  'pokladník',
#  'poslanec',
#  'průvodkyně',
#  'pumpař',
#  'rabín',
#  'sestra v nemocnici',
#  'slepec',
#  'soudní zapisovatel',
#  'stařec',
#  'stařena',
#  'strojvůdce',
#  'svobodník',
#  'taneční mistr',
#  'taxíkář',
#  'televizní hlasatelka',
#  'televizní redaktor',
#  'tlouštík',
#  'turistka',
#  'velitel',
#  'velitel hasičů',
#  'veterinář',
#  'vozka',
#  'vychovatelka',
#  'vyšetřující komisař',
#  'výrostek',
#  'vězeňkyně',
#  'zbrojnoš',
#  'zelinář',
#  'četnický strážmistr',
#  'šašek',
#  'školní inspektor',
#  'Andrej',
#  'Anežka',
#  'Claudie, Violova vnučka',
#  'Gábina',
#  'Honzík',
#  'Hynek',
#  'Ivana',
#  'Jindra',
#  'Kalous',
#  'Kamil',
#  'Kája',
#  'Lojzík',
#  'Maruška',
#  'Olga',
#  'Ota',
#  'Ríša',
#  'Saša',
#  'Sára',
#  'Terezka',
#  'Vojta',
#  'agent',
#  'animírka',
#  'asistent kamery',
#  'asistentka',
#  'baron',
#  'biskup',
#  'brigádnice',
#  'drbna',
#  'dáma ze společnosti',
#  'elektrikář',
#  'garážmistr',
#  'horník',
#  'hrabě',
#  'hráč kulečníku',
#  'instalatér',
#  'instruktor',
#  'kartářka',
#  'klenotník',
#  'knihkupec',
#  'komediant',
#  'konšel',
#  'kostymérka',
#  'kočébr',
#  'kuchtík',
#  'lampář',
#  'liftboy',
#  'loupežník',
#  'majitel střelnice',
#  'matrikářka',
#  'metař',
#  'mládenec',
#  'modelka',
#  'nadlesní',
#  'nezaměstnaný',
#  'nosič',
#  'návštěvník hospody',
#  'ona sama',
#  'panička',
#  'pekař',
#  'podporučík VB',
#  'policistka',
#  'posel',
#  'požárník',
#  'produkční',
#  'předseda závodní rady',
#  'radista',
#  'rotný VB',
#  'saxofonista',
#  'soudní zřízenec',
#  'staršina',
#  'starší pán',
#  'statkář',
#  'stařeček',
#  'státní návladní',
#  'syn',
#  'trhovec',
#  'tělocvikář',
#  'vazoun',
#  'vedoucí prodejny',
#  'vojáci',
#  'zapisovatelka',
#  'zápasník',
#  'člen orchestru',
#  'Šimon',
#  'Šárka',
#  'žákyně',
#  'Adélka',
#  'Agáta',
#  'Blanka',
#  'Bob',
#  'Boris',
#  'Boženka',
#  'Božka',
#  'Daniel',
#  'Dora',
#  'Eman',
#  'Franc',
#  'Hans',
#  'Hedvika',
#  'Horák',
#  'Hugo',
#  'Indián',
#  'Jindřich',
#  'Johanka',
#  'Karol',
#  'Klárka',
#  'Kučera',
#  'Laura',
#  'Leo',
#  'Milada',
#  'Miloš',
#  'Míša',
#  'Novotný',
#  'Olina',
#  'Peter',
#  'Radka',
#  'Róza',
#  'Sylvie',
#  'Táňa',
#  'asistent režie',
#  'bohatý pan Viola',
#  'císař Rudolf II.',
#  'dcera',
#  'desátník',
#  'doručovatel',
#  'dozorkyně',
#  'dražitel',
#  'dvojče',
#  'děda Novák',
#  'gynekolog',
#  'herold',
#  'hlídač na stavbě',
#  'hofmistr',
#  'hospodář',
#  'host v restauraci',
#  'hromotluk',
#  'jezdec',
#  'kardinál',
#  'kastelán',
#  'kněžna',
#  'lepič plakátů',
#  'motocyklista',
#  'obchodník',
#  'občan',
#  'on sám, major Leoš Jirsák z Federální kriminální ústředny',
#  'paní',
#  'ponocný',
#  'poštmistr',
#  'pošťačka',
#  'pošťák',
#  'primář nemocnice',
#  'princ',
#  'princezna',
#  'pán',
#  'předseda komise',
#  'příbuzný',
#  'rekrut',
#  'revizor',
#  'rolník',
#  'rozhodčí',
#  'rádce',
#  'septimánka',
#  'silák',
#  'sochař',
#  'soudkyně',
#  'starostová',
#  'starožitník',
#  'stará paní',
#  'stařík',
#  'stopařka',
#  'strojník',
#  'svatební host',
#  'tajemník MNV',
#  'televizní hlasatel',
#  'trhovkyně',
#  'zámečník',
#  'závodník',
#  'údržbář',
#  'četař',
#  'čtenář',
#  'Štefan',
#  'Štěpán',
#  'šachista',
#  'Anča',
#  'Barborka',
#  'Bláha',
#  'Dan',
#  'Denisa',
#  'Dominik',
#  'Ema',
#  'Erika',
#  'František Palacký',
#  'Hruška',
#  'Hubert',
#  'Ilona',
#  'Irma',
#  'Jarka',
#  'Jaroušek',
#  'Jenda',
#  'Josef Švejk',
#  'Jára',
#  'Kamila',
#  'Karas',
#  'Kryštofová',
#  'Kuba',
#  'Lexa',
#  'Líza',
#  'Majka',
#  'Mareš',
#  'Max',
#  'Milena',
#  'Míla',
#  'Mína',
#  'Müllerová, Švejkova bytná',
#  'Ona',
#  'Péťa',
#  'René',
#  'Ruda',
#  'Rudolf',
#  'Růženka',
#  'Sandra',
#  'Slávek',
#  'Soňa',
#  'Stáňa',
#  'Tony',
#  'Valihrach',
#  'Viktorka',
#  'Václavík',
#  'Zdena',
#  'Zrzek',
#  'apač',
#  'automechanik',
#  'bardáma',
#  'bača',
#  'biletářka',
#  'blondýna',
#  'blondýnka',
#  'bordelmamá',
#  'cestující v tramvaji',
#  'chirurg',
#  'chlapík',
#  'choreograf',
#  'cikán',
#  'domácí',
#  'dudák',
#  'dědek',
#  'děkan',
#  'důchodkyně',
#  'feťák',
#  'filmař',
#  'flašinetář',
#  'fotbalista',
#  'funebrák',
#  'fízl',
#  'hlasatelka',
#  'hlídač parkoviště',
#  'hlídač v parku',
#  'host na zásnubách',
#  'host v lázních',
#  'hosteska',
#  'hotelový host',
#  'hradlař',
#  'hudebnice',
#  'kadeřník',
#  'kamarádka',
#  'kapitán VB',
#  'katecheta',
#  'kolportér',
#  'komentátor',
#  'komoří',
#  'kontrolor',
#  'legionář',
#  'lehká holka',
#  'lodník',
#  'lovec',
#  'lovčí',
#  'manažer',
#  'medik',
#  'mistr na stavbě',
#  'mladá paní',
#  'měštka',
#  'nádražák',
#  'nápověda',
#  'návštěvník baru',
#  'náčelník',
#  'ochotník',
#  'odbojář',
#  'oddávající',
#  'pan řídící',
#  'patolog',
#  'plavčík',
#  'plukovník VB',
#  'pokladník v bance',
#  'policejní prezident',
#  'policejní rada',
#  'portýr v hotelu',
#  'poručík SNB',
#  'poslíček',
#  'posunovač',
#  'primářka',
#  'promítač',
#  'páže',
#  'písařka',
#  'písařka na stroji',
#  'předseda',
#  'překladatelka',
#  'rada',
#  'sestra',
#  'služka Anna',
#  'spisovatel Jan Neruda',
#  'stará dáma',
#  'stopař',
#  'stráž',
#  'strážmistr SNB',
#  'střihač',
#  'sudička',
#  'svazák',
#  'svačinářka',
#  'tankista',
#  'telegrafista',
#  'tetka',
#  'toaletářka',
#  'trampka',
#  'truhlář',
#  'umělec',
#  'učedník',
#  'učeň',
#  'vedoucí pošty',
#  'vedoucí samoobsluhy',
#  'velitel stráže',
#  'vousáč',
#  'vrátná',
#  'vychovatel',
#  'vyhazovač',
#  'vyslanec',
#  'vědec',
#  'zapisovatel u soudu',
#  'zastavárník',
#  'zelinářka',
#  'člen správní rady',
#  'řečník',
#  'řádová sestra',
#  'švadlenka',
#  'Žorž',
#  'žalobce',
#  'Adéla',
#  'Aleš',
#  'Andula',
#  'Anděla',
#  'Anton',
#  'Arnošt',
#  'Berta',
#  'Bogan',
#  'Bohunka',
#  'Bořek',
#  'Dagmar',
#  'Dežo',
#  'Dostál',
#  'Dušan',
#  'Eda',
#  'Erik',
#  'Ester',
#  'Evička',
#  'Evžen',
#  'Fanda',
#  'Ferda',
#  'Francouz',
#  'Fred',
#  'Goran',
#  'Hanička',
#  'Helga',
#  'Hilda',
#  'Ingrid',
#  'Italka',
#  'Janka',
#  'Jaruna',
#  'Jeník',
#  'Jerry',
#  'Jolana',
#  'Josífek',
#  'Jožka',
#  'Jura',
#  'Jáchym',
#  'Kadlec',
#  'Karel Havlíček Borovský',
#  'Karla',
#  'Karlička',
#  'Karolína',
#  'Kačenka',
#  'Klein',
#  'Leo Kohn',
#  'Libor',
#  'Lojzek',
#  'Lucka',
#  'Ludvík',
#  'Mašek',
#  'Miki',
#  'Mikuláš',
#  'Málková',
#  'Müller',
#  'Novák',
#  'Nováková',
#  'Olin',
#  'On',
#  'Pepek',
#  'Pinďa',
#  'Pišta',
#  'Prošek',
#  'Robin',
#  'Rousek',
#  'Sedláček',
#  'Simona',
#  'Sára Kohnová',
#  'Tobiáš',
#  'Tomek',
#  'Vanda',
#  'Venca',
#  'Vendula',
#  'Vendulka',
#  'Vilda',
#  'Vilma',
#  'Vilém',
#  'Vincek',
#  'Vlastička',
#  'Vláďa',
#  'Zeman',
#  'abatyše',
#  'antikvář',
#  'arcibiskup',
#  'bankéř',
#  'biletář',
#  'blázen',
#  'bodyguard',
#  'bratranec',
#  'bába',
#  'cestující v autobusu',
#  'cestující v letadle',
#  'chalupník',
#  'diplomat',
#  'divadelní zřízenec',
#  'dohazovač Kecal',
#  'dozorčí',
#  'družička',
#  'děda Poláček',
#  'děvče',
#  'děvčátko',
#  'elegán',
#  'fanynka',
#  'flamendr',
#  'frajer',
#  'gangster',
#  'garderobiérka',
#  'hajná',
#  'hejsek',
#  'homosexuál',
#  'houslistka',
#  'hráč',
#  'intelektuál',
#  'invalida',
#  'kameník',
#  'kancléř',
#  'knihovnice',
#  'knihovník',
#  'kníže',
#  'kolotočář',
#  'komisař gestapa',
#  'konstruktér',
#  'kopáč',
#  'korepetitor',
#  'kovářka',
#  'kořenářka',
#  'královský posel',
#  'kulturista',
#  'lapka',
#  'lesák',
#  'lichvář',
#  'loutkář',
#  'macecha',
#  'magistra',
#  'majitel obchodu',
#  'majitel vily',
#  'major SS',
#  'malíř pokojů',
#  'maskér',
#  'masér',
#  'moderátorka',
#  'modistka',
#  'mušketýr',
#  'máma',
#  'měšťanka',
#  'nadpraporčík VB',
#  'nakladatel',
#  'nájemník',
#  'náčelník VB',
#  'německý generál',
#  'ochranka',
#  'opilý host',
#  'orchestr v baru',
#  'ovčák',
#  'pacholek',
#  'panská',
#  'pasažér',
#  'pasák',
#  'pasák holek',
#  'pionýr',
#  'pivař',
#  'pojišťovací agent',
#  'pokladní na nádraží',
#  'pokladní v kině',
#  'pokojská v hotelu',
#  'policejní rada Karel Vacátko',
#  'polír',
#  'polír na stavbě',
#  'poručík Borůvka',
#  'porybný',
#  'pozůstalý',
#  'poštmistrová',
#  'principál']

# %% [markdown]
# ## Obsazení

# %%
for t in top20roli:
    pracovni = herectvo[(herectvo["Role"] == t)].groupby("Jméno")["Film"].nunique().nlargest(3)
    print(f"""{t}: {pracovni}\n""")
# Out:
# žena: Jméno
# Milka Balek-Brodská (28799)    27
# Hermína Vojtová (127041)       24
# Marie Nademlejnská (127317)    22
# Name: Film, dtype: int64
#
# matka: Jméno
# Ella Nollová (127319)       15
# Saša Dobrovolná (127820)    15
# Marie Blažková (127511)     14
# Name: Film, dtype: int64
#
# otec: Jméno
# Theodor Pištěk (37366)       19
# Jaroslav Vojta (77195)       15
# Karel Schleichert (83230)    11
# Name: Film, dtype: int64
#
# muž: Jméno
# Jaroslav Tomsa (2576)       13
# Vítězslav Černý (126687)     9
# Miloš Vavruška (25435)       8
# Name: Film, dtype: int64
#
# policista: Jméno
# Jaroslav Tomsa (2576)      16
# Jan W. Speerger (55928)    13
# Bohumil Koška (126450)     11
# Name: Film, dtype: int64
#
# ředitel: Jméno
# Jaroslav Marvan (9550)    21
# Zdeněk Dítě (5313)        13
# Theodor Pištěk (37366)    12
# Name: Film, dtype: int64
#
# hostinský: Jméno
# Zdeněk Skalický (126510)    25
# Viktor Socha (28353)        12
# Václav Pata (32026)         12
# Name: Film, dtype: int64
#
# lékař: Jméno
# Ota Sklenčka (4753)     9
# Gabriel Hart (89525)    8
# Zdeněk Hodr (83851)     8
# Name: Film, dtype: int64
#
# učitel: Jméno
# Jiří Hálek (7718)       6
# Otto Šimánek (35353)    5
# Běla Jurdová (27291)    4
# Name: Film, dtype: int64
#
# řidič: Jméno
# Karel Bělohradský (6370)    26
# Václav Syřiště (126657)      9
# Pavel Myslík (2615)          8
# Name: Film, dtype: int64
#
# soused: Jméno
# Milka Balek-Brodská (28799)    14
# Hermína Vojtová (127041)       10
# Eva Svobodová (86464)           7
# Name: Film, dtype: int64
#
# dívka: Jméno
# Hana Čížková (9732)             5
# Andrea Čunderlíková (14417)     4
# Milena Steinmasslová (18467)    4
# Name: Film, dtype: int64
#
# profesor: Jméno
# Miloš Nedbal (43208)         9
# František Smolík (126955)    8
# Josef Somr (1054)            7
# Name: Film, dtype: int64
#
# úředník: Jméno
# Zdeněk Řehoř (4855)             7
# Bohuš Hradil (128758)           6
# Ferdinand Jarkovský (127290)    5
# Name: Film, dtype: int64
#
# vrátný: Jméno
# Josef Hlinomaz (26212)    8
# Eman Fiala (64088)        6
# Josef Střecha (55613)     6
# Name: Film, dtype: int64
#
# student: Jméno
# Josef Kemr (4897)         7
# Jaroslav Mareš (17561)    5
# Karel Hábl (27177)        5
# Name: Film, dtype: int64
#
# sekretářka: Jméno
# Jitka Zelenohorská (34821)    7
# Věra Váchová (75641)          6
# Jiřina Bílá (3629)            5
# Name: Film, dtype: int64
#
# sluha: Jméno
# Václav Trégl (35224)               13
# Josef Šváb-Malostranský (55291)    10
# Jan W. Speerger (55928)             8
# Name: Film, dtype: int64
#
# babička: Jméno
# Marie Rosůlková (4751)        10
# Josefa Pechlátová (126344)     9
# Valerie Kaplanová (5168)       8
# Name: Film, dtype: int64
#
# dělník: Jméno
# Hynek Němec (128790)        16
# Antonín Šůra (128753)        7
# Rudolf Deyl ml. (126471)     6
# Name: Film, dtype: int64

# %%
for t in top20roli:
    pracovni = herectvo[(herectvo["Role"] == t) & (herectvo["Rok"] >= 1930)].groupby("Jméno")["Film"].nunique().nlargest(5)
    print(f"""{t}: {pracovni}\n""")
# Out:
# žena: Jméno
# Hermína Vojtová (127041)       23
# Marie Nademlejnská (127317)    21
# Milka Balek-Brodská (28799)    21
# Ella Nollová (127319)          19
# Vlastimila Vlková (27109)      18
# Name: Film, dtype: int64
#
# matka: Jméno
# Ella Nollová (127319)         14
# Marie Blažková (127511)       14
# Míla Myslíková (26893)        14
# Hermína Vojtová (127041)      13
# Jarmila Kurandová (126965)    12
# Name: Film, dtype: int64
#
# otec: Jméno
# Theodor Pištěk (37366)      17
# Jaroslav Vojta (77195)      13
# Vladimír Menšík (126036)    11
# Jaroslav Marvan (9550)      10
# Pavel Nový (510)            10
# Name: Film, dtype: int64
#
# muž: Jméno
# Jaroslav Tomsa (2576)       13
# Vítězslav Černý (126687)     9
# Miloš Vavruška (25435)       8
# Mirko Musil (33555)          8
# Antonín Soukup (87404)       7
# Name: Film, dtype: int64
#
# policista: Jméno
# Jaroslav Tomsa (2576)        16
# Jan W. Speerger (55928)      12
# Bohumil Koška (126450)       11
# Bolek Prchal (129671)        11
# Jaroslav Orlický (129724)     9
# Name: Film, dtype: int64
#
# ředitel: Jméno
# Jaroslav Marvan (9550)    21
# Zdeněk Dítě (5313)        13
# Martin Růžek (4934)       10
# Oldřich Velen (12725)      9
# Theodor Pištěk (37366)     9
# Name: Film, dtype: int64
#
# hostinský: Jméno
# Zdeněk Skalický (126510)    25
# Viktor Socha (28353)        12
# Václav Pata (32026)         12
# Theodor Pištěk (37366)      10
# Jiří Lír (4926)              9
# Name: Film, dtype: int64
#
# lékař: Jméno
# Ota Sklenčka (4753)       9
# Gabriel Hart (89525)      8
# Zdeněk Hodr (83851)       8
# Oldřich Velen (12725)     7
# Bohuš Záhorský (53346)    6
# Name: Film, dtype: int64
#
# učitel: Jméno
# Jiří Hálek (7718)          6
# Otto Šimánek (35353)       5
# Běla Jurdová (27291)       4
# Dana Morávková (2293)      4
# Daniela Kolářová (1847)    4
# Name: Film, dtype: int64
#
# řidič: Jméno
# Karel Bělohradský (6370)    26
# Václav Syřiště (126657)      9
# Pavel Myslík (2615)          8
# Fanda Mrázek (128457)        6
# Pavel Zedníček (9118)        6
# Name: Film, dtype: int64
#
# soused: Jméno
# Milka Balek-Brodská (28799)    12
# Hermína Vojtová (127041)        9
# Eva Svobodová (86464)           7
# Jiřina Bílá (3629)              7
# Václav Trégl (35224)            6
# Name: Film, dtype: int64
#
# dívka: Jméno
# Hana Čížková (9732)             5
# Andrea Čunderlíková (14417)     4
# Milena Steinmasslová (18467)    4
# Bára Štěpánová (511)            3
# Dora Martinová (129999)         3
# Name: Film, dtype: int64
#
# profesor: Jméno
# Miloš Nedbal (43208)         9
# František Smolík (126955)    8
# Josef Somr (1054)            7
# Radovan Lukavský (3301)      7
# Miroslav Macháček (6959)     6
# Name: Film, dtype: int64
#
# úředník: Jméno
# Zdeněk Řehoř (4855)             7
# Bohuš Hradil (128758)           6
# Ferdinand Jarkovský (127290)    5
# František Filipovský (4735)     5
# Bohuš Záhorský (53346)          4
# Name: Film, dtype: int64
#
# vrátný: Jméno
# Josef Hlinomaz (26212)    8
# Eman Fiala (64088)        6
# Josef Střecha (55613)     6
# Karel Němec (128590)      6
# Ota Motyčka (81341)       6
# Name: Film, dtype: int64
#
# student: Jméno
# Josef Kemr (4897)          7
# Jaroslav Mareš (17561)     5
# Karel Hábl (27177)         5
# Karel Šašek (122658)       5
# Svatopluk Beneš (13617)    5
# Name: Film, dtype: int64
#
# sekretářka: Jméno
# Jitka Zelenohorská (34821)    7
# Věra Váchová (75641)          6
# Jiřina Bílá (3629)            5
# Jana Sedlmajerová (123233)    4
# Marta Richterová (27358)      4
# Name: Film, dtype: int64
#
# sluha: Jméno
# Václav Trégl (35224)          13
# Alois Dvorský (127491)         6
# Jan W. Speerger (55928)        6
# Jindřich Láznička (129767)     6
# Fráňa Vajner (128612)          5
# Name: Film, dtype: int64
#
# babička: Jméno
# Marie Rosůlková (4751)        10
# Josefa Pechlátová (126344)     9
# Valerie Kaplanová (5168)       8
# Vlasta Jelínková (61428)       8
# Terezie Brzková (127051)       7
# Name: Film, dtype: int64
#
# dělník: Jméno
# Hynek Němec (128790)        16
# Antonín Šůra (128753)        7
# Rudolf Deyl ml. (126471)     6
# Vilém Besser (77019)         6
# Vladimír Hlavatý (34999)     6
# Name: Film, dtype: int64

# %%
for t in top20roli:
    pracovni = herectvo[(herectvo["Role"] == t) & ~herectvo["Datum narození"].isnull() & herectvo["Datum úmrtí"].isnull()].groupby("Jméno")["Film"].nunique().nlargest(3)
    print(f"""{t}: {pracovni}\n""")
# Out:
# žena: Jméno
# Miriam Kantorková (3863)     8
# Zdena Hadrbolcová (4686)     8
# Alexandra Myšková (87455)    6
# Name: Film, dtype: int64
#
# matka: Jméno
# Zdena Hadrbolcová (4686)    12
# Eva Holubová (5948)          9
# Ivana Chýlková (4684)        6
# Name: Film, dtype: int64
#
# otec: Jméno
# Pavel Nový (510)           10
# Bohumil Klepl (1434)        7
# Boleslav Polívka (1556)     6
# Name: Film, dtype: int64
#
# muž: Jméno
# Jindřich Sejk (11810)    7
# Vít Pešina (2884)        4
# Zdeněk Dušek (993)       4
# Name: Film, dtype: int64
#
# policista: Jméno
# Karel Vítek (126651)       6
# Antonín Hardt (19168)      5
# Bert Schneider (126653)    5
# Name: Film, dtype: int64
#
# ředitel: Jméno
# Ladislav Županič (7910)     5
# Miroslav Táborský (1841)    4
# Tomáš Töpfer (12533)        3
# Name: Film, dtype: int64
#
# hostinský: Jméno
# Petr Kopřiva (105600)     4
# Rudolf Kalina (129024)    4
# Jan Hraběta (2677)        3
# Name: Film, dtype: int64
#
# lékař: Jméno
# Marek Vašut (3566)            4
# Petr Nárožný (1052)           3
# Evelyna Steimarová (16950)    2
# Name: Film, dtype: int64
#
# učitel: Jméno
# Dana Morávková (2293)      4
# Daniela Kolářová (1847)    4
# Eva Holubová (5948)        4
# Name: Film, dtype: int64
#
# řidič: Jméno
# Václav Syřiště (126657)    9
# Pavel Myslík (2615)        8
# Pavel Zedníček (9118)      6
# Name: Film, dtype: int64
#
# soused: Jméno
# Jaroslava Pokorná (2727)    3
# Marek Taclík (9420)         3
# Eva Holubová (5948)         2
# Name: Film, dtype: int64
#
# dívka: Jméno
# Hana Čížková (9732)             5
# Andrea Čunderlíková (14417)     4
# Milena Steinmasslová (18467)    4
# Name: Film, dtype: int64
#
# profesor: Jméno
# Alois Švehlík (6277)           2
# Gert K. Müntefering (34063)    2
# Jan Nemejovský (2605)          2
# Name: Film, dtype: int64
#
# úředník: Jméno
# David Vávra (6006)           2
# Emil Horváth ml. (126551)    2
# Jan Budař (11090)            2
# Name: Film, dtype: int64
#
# vrátný: Jméno
# Jan Dvořák (1855)            2
# Bedřich Čapek (126895)       1
# František Skřípek (12863)    1
# Name: Film, dtype: int64
#
# student: Jméno
# Karel Hábl (27177)            5
# Václav Vydra nejml. (2666)    5
# David Matásek (3884)          4
# Name: Film, dtype: int64
#
# sekretářka: Jméno
# Jitka Zelenohorská (34821)    7
# Jana Sedlmajerová (123233)    4
# Marta Richterová (27358)      4
# Name: Film, dtype: int64
#
# sluha: Jméno
# Antonín Buzič (18428)      1
# Boleslav Polívka (1556)    1
# David Vejražka (5486)      1
# Name: Film, dtype: int64
#
# babička: Jméno
# Lilian Malkina (27097)      3
# Viera Pavlíková (6637)      3
# Jaroslava Pokorná (2727)    2
# Name: Film, dtype: int64
#
# dělník: Jméno
# Ondřej Vetchý (836)    3
# Jan Kraus (1062)       2
# Jan Kuželka (1445)     2
# Name: Film, dtype: int64
