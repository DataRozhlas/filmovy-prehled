# %%
import pandas as pd

# %%
import re

# %%
df = pd.read_json("filmy.json")

# %%
def premiera(x, jaka):
    try:
        if f"{jaka}premiéra" in x:
            x = x.split(f"{jaka}premiéra")[1]
            try:
                datum = re.search('.*?\d{4}', x).group().replace(f"{jaka}premiéra","").strip()
                # datum = pd.to_datetime(datum, errors="coerce", format = "%d. %m. %Y")
            except:
                datum = ""
            try:
                misto = re.search('\((.*?)\)', x).group().replace("(","").replace(")","").strip()
            except AttributeError:
                misto = ""
        else:
            datum = ""
            misto = ""
    except TypeError:
        datum = ""
        misto = ""
    return [datum, misto]

# %%
df["Slavnostní premiéra (datum)"] = df["Premiéra"].apply(lambda x: premiera(x, "slavnostní ")[0])
df["Slavnostní premiéra (místo)"] = df["Premiéra"].apply(lambda x: premiera(x, "slavnostní ")[1])
df["Distribuční premiéra (datum)"] = df["Premiéra"].apply(lambda x: premiera(x, "distribuční ")[0])
df["Distribuční premiéra (místo)"] = df["Premiéra"].apply(lambda x: premiera(x, "distribuční ")[1])
df["Festivalová premiéra (datum)"] = df["Premiéra"].apply(lambda x: premiera(x, "festivalová ")[0])
df["Festivalová premiéra (místo)"] = df["Premiéra"].apply(lambda x: premiera(x, "festivalová ")[1])
df["Zahraniční premiéra (datum)"] = df["Premiéra"].apply(lambda x: premiera(x, "zahraniční ")[0])
df["Zahraniční premiéra (místo)"] = df["Premiéra"].apply(lambda x: premiera(x, "zahraniční ")[1])
df["Premiéra bez upřesnění (datum)"] = df["Premiéra"].apply(lambda x: premiera(x, "")[0])

# %%
df["Premiéra bez upřesnění (datum)"]
# Out:
# 0       19. 6. 1898
# 1       24. 7. 1898
# 2         léto 1898
# 3       19. 6. 1898
# 4       24. 7. 1898
#            ...
# 4531     2. 2. 2022
# 4532    20. 4. 2022
# 4533     5. 4. 2022
# 4534     2. 8. 2022
# 4535     2. 3. 2022
# Name: Premiéra bez upřesnění (datum), Length: 4536, dtype: object

# %%
def na_data(x):
    df[x] = pd.to_datetime(df[x], errors="ignore", format = "%d. %m. %Y")

# %%
premiery = ["Slavnostní premiéra (datum)", "Distribuční premiéra (datum)", "Festivalová premiéra (datum)", "Zahraniční premiéra (datum)", "Premiéra bez upřesnění (datum)"]

# %%
for p in premiery:
    na_data(p)

# %%
df["Premiéra bez upřesnění (datum)"]
# Out:
# 0       19. 6. 1898
# 1       24. 7. 1898
# 2         léto 1898
# 3       19. 6. 1898
# 4       24. 7. 1898
#            ...
# 4531     2. 2. 2022
# 4532    20. 4. 2022
# 4533     5. 4. 2022
# 4534     2. 8. 2022
# 4535     2. 3. 2022
# Name: Premiéra bez upřesnění (datum), Length: 4536, dtype: object

# %%
df["Slavnostní premiéra (datum)"] = pd.to_datetime(df["Slavnostní premiéra (datum)"], errors="coerce", format = "%d. %m. %Y")

# %%
df["Slavnostní premiéra (datum)"].drop_duplicates().to_list()
# Out:
# [NaT,
#  Timestamp('1922-08-03 00:00:00'),
#  Timestamp('1929-12-13 00:00:00'),
#  Timestamp('1929-02-28 00:00:00'),
#  Timestamp('1929-07-12 00:00:00'),
#  Timestamp('1930-04-03 00:00:00'),
#  Timestamp('1930-10-23 00:00:00'),
#  Timestamp('1931-04-02 00:00:00'),
#  Timestamp('1931-10-15 00:00:00'),
#  Timestamp('1933-01-19 00:00:00'),
#  Timestamp('1933-09-19 00:00:00'),
#  Timestamp('1936-01-16 00:00:00'),
#  Timestamp('1938-06-02 00:00:00'),
#  Timestamp('1939-01-05 00:00:00'),
#  Timestamp('1942-03-18 00:00:00'),
#  Timestamp('1945-12-14 00:00:00'),
#  Timestamp('1946-06-07 00:00:00'),
#  Timestamp('1946-09-05 00:00:00'),
#  Timestamp('1952-06-05 00:00:00'),
#  Timestamp('1956-02-25 00:00:00'),
#  Timestamp('1958-06-26 00:00:00'),
#  Timestamp('1958-06-06 00:00:00'),
#  Timestamp('1963-11-25 00:00:00'),
#  Timestamp('1965-02-01 00:00:00'),
#  Timestamp('1964-02-25 00:00:00'),
#  Timestamp('1968-10-02 00:00:00'),
#  Timestamp('1969-04-24 00:00:00'),
#  Timestamp('1970-01-21 00:00:00'),
#  Timestamp('1970-04-08 00:00:00'),
#  Timestamp('1990-05-17 00:00:00'),
#  Timestamp('1970-11-18 00:00:00'),
#  Timestamp('1970-12-03 00:00:00'),
#  Timestamp('1971-02-18 00:00:00'),
#  Timestamp('1970-10-26 00:00:00'),
#  Timestamp('1971-03-03 00:00:00'),
#  Timestamp('1971-05-13 00:00:00'),
#  Timestamp('1971-10-13 00:00:00'),
#  Timestamp('1973-06-04 00:00:00'),
#  Timestamp('1972-11-03 00:00:00'),
#  Timestamp('1972-11-09 00:00:00'),
#  Timestamp('1974-04-26 00:00:00'),
#  Timestamp('1974-01-23 00:00:00'),
#  Timestamp('1974-03-05 00:00:00'),
#  Timestamp('1974-01-03 00:00:00'),
#  Timestamp('1974-03-28 00:00:00'),
#  Timestamp('1973-02-21 00:00:00'),
#  Timestamp('1974-02-28 00:00:00'),
#  Timestamp('1973-11-28 00:00:00'),
#  Timestamp('1973-03-21 00:00:00'),
#  Timestamp('1974-04-18 00:00:00'),
#  Timestamp('1974-04-14 00:00:00'),
#  Timestamp('1974-04-30 00:00:00'),
#  Timestamp('1975-02-24 00:00:00'),
#  Timestamp('1974-10-09 00:00:00'),
#  Timestamp('1975-05-14 00:00:00'),
#  Timestamp('1975-01-20 00:00:00'),
#  Timestamp('1975-01-23 00:00:00'),
#  Timestamp('1975-04-26 00:00:00'),
#  Timestamp('1974-09-18 00:00:00'),
#  Timestamp('1975-03-05 00:00:00'),
#  Timestamp('1974-06-01 00:00:00'),
#  Timestamp('1975-08-28 00:00:00'),
#  Timestamp('1976-02-12 00:00:00'),
#  Timestamp('1975-12-17 00:00:00'),
#  Timestamp('1976-03-19 00:00:00'),
#  Timestamp('1976-01-29 00:00:00'),
#  Timestamp('1976-02-06 00:00:00'),
#  Timestamp('1976-03-31 00:00:00'),
#  Timestamp('1976-03-12 00:00:00'),
#  Timestamp('1977-03-31 00:00:00'),
#  Timestamp('1976-12-09 00:00:00'),
#  Timestamp('1976-04-08 00:00:00'),
#  Timestamp('1976-08-25 00:00:00'),
#  Timestamp('1977-04-27 00:00:00'),
#  Timestamp('1978-09-14 00:00:00'),
#  Timestamp('1979-09-20 00:00:00'),
#  Timestamp('1980-12-13 00:00:00'),
#  Timestamp('1981-10-29 00:00:00'),
#  Timestamp('1982-12-01 00:00:00'),
#  Timestamp('1982-12-15 00:00:00'),
#  Timestamp('1985-09-26 00:00:00'),
#  Timestamp('1988-04-14 00:00:00'),
#  Timestamp('1988-01-28 00:00:00'),
#  Timestamp('1989-03-09 00:00:00'),
#  Timestamp('1990-09-19 00:00:00'),
#  Timestamp('1990-09-05 00:00:00'),
#  Timestamp('1990-03-07 00:00:00'),
#  Timestamp('1993-08-01 00:00:00'),
#  Timestamp('1993-05-12 00:00:00'),
#  Timestamp('1993-01-27 00:00:00'),
#  Timestamp('1993-09-08 00:00:00'),
#  Timestamp('1993-04-07 00:00:00'),
#  Timestamp('1995-02-09 00:00:00'),
#  Timestamp('1995-04-13 00:00:00'),
#  Timestamp('1995-04-27 00:00:00'),
#  Timestamp('1996-03-05 00:00:00'),
#  Timestamp('1995-09-28 00:00:00'),
#  Timestamp('1995-06-29 00:00:00'),
#  Timestamp('1996-04-04 00:00:00'),
#  Timestamp('1995-07-06 00:00:00'),
#  Timestamp('1995-10-12 00:00:00'),
#  Timestamp('1996-05-16 00:00:00'),
#  Timestamp('1996-06-13 00:00:00'),
#  Timestamp('1996-12-04 00:00:00'),
#  Timestamp('1997-01-30 00:00:00'),
#  Timestamp('1997-03-08 00:00:00'),
#  Timestamp('1997-01-15 00:00:00'),
#  Timestamp('1997-10-23 00:00:00'),
#  Timestamp('1997-09-10 00:00:00'),
#  Timestamp('1998-02-19 00:00:00'),
#  Timestamp('1999-01-27 00:00:00'),
#  Timestamp('2006-09-15 00:00:00'),
#  Timestamp('2000-10-25 00:00:00'),
#  Timestamp('2000-03-16 00:00:00'),
#  Timestamp('2003-05-16 00:00:00'),
#  Timestamp('2001-03-07 00:00:00'),
#  Timestamp('2002-12-16 00:00:00'),
#  Timestamp('2001-09-19 00:00:00'),
#  Timestamp('2003-01-16 00:00:00'),
#  Timestamp('2002-03-27 00:00:00'),
#  Timestamp('2003-02-19 00:00:00'),
#  Timestamp('2003-04-24 00:00:00'),
#  Timestamp('2003-09-03 00:00:00'),
#  Timestamp('2004-06-22 00:00:00'),
#  Timestamp('2004-11-03 00:00:00'),
#  Timestamp('2004-11-16 00:00:00'),
#  Timestamp('2004-08-18 00:00:00'),
#  Timestamp('2004-12-01 00:00:00'),
#  Timestamp('2004-09-15 00:00:00'),
#  Timestamp('2004-05-31 00:00:00'),
#  Timestamp('2004-04-14 00:00:00'),
#  Timestamp('2004-06-09 00:00:00'),
#  Timestamp('2005-11-02 00:00:00'),
#  Timestamp('2005-09-21 00:00:00'),
#  Timestamp('2005-09-24 00:00:00'),
#  Timestamp('2005-10-27 00:00:00'),
#  Timestamp('2005-04-19 00:00:00'),
#  Timestamp('2005-11-09 00:00:00'),
#  Timestamp('2005-09-14 00:00:00'),
#  Timestamp('2007-01-17 00:00:00'),
#  Timestamp('2006-10-11 00:00:00'),
#  Timestamp('2006-11-29 00:00:00'),
#  Timestamp('2006-09-05 00:00:00'),
#  Timestamp('2006-08-24 00:00:00'),
#  Timestamp('2006-12-18 00:00:00'),
#  Timestamp('2006-11-01 00:00:00'),
#  Timestamp('2006-05-31 00:00:00'),
#  Timestamp('2006-10-30 00:00:00'),
#  Timestamp('2006-01-25 00:00:00'),
#  Timestamp('2020-02-11 00:00:00'),
#  Timestamp('2020-02-25 00:00:00'),
#  Timestamp('2021-11-19 00:00:00'),
#  Timestamp('2020-01-05 00:00:00'),
#  Timestamp('2020-09-08 00:00:00'),
#  Timestamp('2021-09-18 00:00:00'),
#  Timestamp('2021-09-01 00:00:00'),
#  Timestamp('2021-08-23 00:00:00'),
#  Timestamp('2021-07-01 00:00:00'),
#  Timestamp('2021-08-01 00:00:00'),
#  Timestamp('2021-09-08 00:00:00'),
#  Timestamp('2021-09-06 00:00:00'),
#  Timestamp('2021-11-29 00:00:00'),
#  Timestamp('2021-08-03 00:00:00'),
#  Timestamp('2021-09-07 00:00:00'),
#  Timestamp('2022-05-03 00:00:00'),
#  Timestamp('2021-06-11 00:00:00'),
#  Timestamp('2022-01-05 00:00:00'),
#  Timestamp('2022-03-25 00:00:00'),
#  Timestamp('2021-11-11 00:00:00'),
#  Timestamp('2021-08-18 00:00:00'),
#  Timestamp('2021-07-27 00:00:00'),
#  Timestamp('2021-10-27 00:00:00'),
#  Timestamp('2021-10-18 00:00:00'),
#  Timestamp('2021-08-22 00:00:00'),
#  Timestamp('2021-09-13 00:00:00'),
#  Timestamp('2021-11-23 00:00:00'),
#  Timestamp('2022-02-08 00:00:00'),
#  Timestamp('2021-09-03 00:00:00'),
#  Timestamp('2021-07-21 00:00:00'),
#  Timestamp('2021-10-12 00:00:00'),
#  Timestamp('2021-10-05 00:00:00'),
#  Timestamp('2021-09-23 00:00:00'),
#  Timestamp('2021-10-19 00:00:00'),
#  Timestamp('2022-02-23 00:00:00'),
#  Timestamp('2021-09-24 00:00:00'),
#  Timestamp('2021-11-02 00:00:00'),
#  Timestamp('2021-07-07 00:00:00'),
#  Timestamp('2021-06-28 00:00:00'),
#  Timestamp('2021-07-15 00:00:00'),
#  Timestamp('2022-02-02 00:00:00'),
#  Timestamp('2022-04-20 00:00:00'),
#  Timestamp('2022-04-05 00:00:00'),
#  Timestamp('2022-08-02 00:00:00'),
#  Timestamp('2022-03-02 00:00:00')]

# %%
df.groupby(pd.Grouper(key='Slavnostní premiéra (datum)', freq='M'))["Film"].nunique().nlargest(10)
# Out:
# Slavnostní premiéra (datum)
# 2020-08-31    12
# 2020-09-30    12
# 2021-09-30    10
# 2021-08-31     9
# 2011-03-31     8
# 2006-09-30     7
# 2018-10-31     7
# 2019-09-30     7
# 2019-10-31     7
# 2020-02-29     7
# Name: Film, dtype: int64

# %%
df[df["Slavnostní premiéra (datum)"] > "2013-04-12"].groupby(df['Slavnostní premiéra (datum)'].dt.weekday)["Film"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='Slavnostní premiéra (datum)'>

# %%
df[df["Slavnostní premiéra (datum)"] > "2013-04-12"].groupby(df['Slavnostní premiéra (datum)'].dt.month)["Film"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='Slavnostní premiéra (datum)'>

# %%
df.groupby("Festivalová premiéra (místo)")["Film"].nunique().nlargest(50)
# Out:
# Festivalová premiéra (místo)
#                                                                                           4304
# 53. mezinárodní filmový festival Karlovy Vary                                               13
# 13. festival českých a slovenských filmů Praha /kino Světozor, Praha/                       12
# 2. Filmové žně 1941 Zlín                                                                    10
# 1. Filmové žně 1940 Zlín                                                                     9
# 22. mezinárodní festival dokumentárních filmů Ji.hlava                                       8
# 26. mezinárodní filmový festival Febiofest Praha                                             8
# 54. mezinárodní filmový festival Karlovy Vary                                                6
# 23. mezinárodní festival dokumentárních filmů Ji.hlava                                       5
# 27. filmový festival pracujících – léto ´76                                                  4
# 3. přehlídka nekomerční kinematografie a videa FEBIOFEST '96 /kino Blaník, Praha/            4
# 55. mezinárodní filmový festival Karlovy Vary                                                4
# 22. filmový festival pracujících – léto ´71                                                  3
# 23. mezinárodní festival dokumentárních filmů Ji.hlava /sekce Česká radost/                  3
# 24. filmový festival pracujících – červen ´73                                                3
# 24. mezinárodní festival dokumentárních filmů Ji.hlava /online/                              3
# 28. filmový festival pracujících – léto ´77                                                  3
# 45. mezinárodní festival animovaných filmů Annecy, Francie                                   3
# 47. Letní filmová škola Uherské Hradiště                                                     3
# 59. mezinárodní festival filmů pro děti a mládež Zlín Film Festival                          3
# 18. filmový festival pracujících – podzim ´67                                                2
# 18. mezinárodní festival animovaných filmů Anifilm Třeboň                                    2
# 20. filmový festival pracujících – léto ´69                                                  2
# 20. mezinárodní festival dokumentárních filmů o lidských právech Jeden svět, Praha           2
# 22. filmový festival pracujících – podzim ´71                                                2
# 23. filmový festival pracujících – červen ´72                                                2
# 24. filmový festival pracujících – leden ´73                                                 2
# 25. filmový festival pracujících – červen ´74                                                2
# 25. mezinárodní filmový festival Febiofest Praha                                             2
# 33. mezinárodní festival dokumentárních filmů Amsterdam, Nizozemí                            2
# 45. Letní filmová škola Uherské Hradiště                                                     2
# 50. mezinárodní festival dokumentárních filmů Visions du Réel Nyon, Švýcarsko                2
# 50. mezinárodní filmový festival Karlovy Vary                                                2
# 51. mezinárodní festival dokumentárních filmů Visions du Réel Nyon, Švýcarsko /online/       2
# 52. mezinárodní filmový festival Karlovy Vary                                                2
# 55. mezinárodní festival filmů pro děti a mládež Zlín Film Festival                          2
# 60. mezinárodní festival filmů pro děti a mládež Zlín Film Festival                          2
# 68. mezinárodní filmový festival Berlinale Berlín, Německo                                   2
# 11. festival FAMU, Praha                                                                     1
# 11. mezinárodní filmový festival pro děti a mládež Juniorfest, Domažlice                     1
# 12. mezinárodní festival dokumentárních filmů Jihlava                                        1
# 14. mezinárodní festival dokumentárních filmů Ji.hlava                                       1
# 15. festival krátkých filmů Praha                                                            1
# 17. filmový festival Millenium Docs Against Gravity Varšava, Polsko                          1
# 17. mezinárodní festival animovaných filmů Anifilm Třeboň                                    1
# 17. mezinárodní festival dokumentárních filmů Ji.hlava                                       1
# 18. mezinárodní festival dokumentárního filmu CPH:DOX Kodaň, Dánsko                          1
# 18. transylvánský mezinárodní filmový festival Kluž, Rumunsko                                1
# 19. filmový festival pracujících – podzim ´68 /kino Sevastopol, Praha/                       1
# 20. filmový festival pracujících – podzim ´69                                                1
# Name: Film, dtype: int64

# %%
top_kina = df.groupby("Slavnostní premiéra (místo)")["Film"].nunique().nlargest(10).dropna().index.to_list()

# %%
top_kina = [x for x in top_kina if x != ""]

# %%
df[(df["Slavnostní premiéra (místo)"].isin(top_kina)) & (df["Copyright"] > 1989)].groupby(["Copyright","Slavnostní premiéra (místo)"])["Slavnostní premiéra (datum)"].nunique().unstack().plot()
# Out:
# <AxesSubplot:xlabel='Copyright'>
