# %%
import os
import pandas as pd
df = pd.read_json(os.path.join("data", "filmy.json"))
pd.set_option('display.max_columns', None)

# %%
df = df.explode("Hrají").explode("Žánr")

# %%
obsazovanost = pd.Series(df.groupby("Hrají")["Film"].nunique(), name="Obsazovanost")

# %%
df = df.merge(obsazovanost, on="Hrají")

# %%
df.shape
# Out:
# (113596, 132)

# %%
", ".join(df["Žánr"].drop_duplicates().to_list())
# Out:
# 'fraška, anekdota, komedie, melodrama, dobrodružný, historický, drama, fantastický, kriminální, pohádka, osvětový, tragikomedie, špionážní, propagační, hudební, legenda, povídkový, životopisný, opereta, psychologický, detektivní, sociální, satira, válečný, trikový, bláznivá komedie, společenský, politický, poetický, /neidentifikován/, reklamní, romantický, parodie, lyrický, opera, sportovní, western, experimentální, podobenství, povídka, příběh, dětský, rodinný, muzikál, budovatelský, etuda, báseň, balada, moralita, alegorie, protiválečný, ilustrace písně, sci-fi, groteska, noir, hořká komedie, absurdní, fejeton, smutná komedie, revue, populárně-vědecký, záznam divadelní inscenace, umělecký, reportáž, erotický, milostný, thriller, instrukční, agitka, dokument, horor, ilustrace skladby, avantgardní, férie, černá komedie, road movie, tragédie, střihový, pantomima, esej, akční, mysteriózní, taneční, gangsterka, balet, výukový, medailon, videoklip'

# %%
df = df.replace("černá komedie","komedie").replace("bláznivá komedie","komedie").replace("hořká komedie","komedie").replace("smutná komedie","komedie")

# %%
zanry = df["Žánr"].drop_duplicates().to_list()

# %%
df.groupby("Žánr")["Film"].nunique().nlargest(15)
# Out:
# Žánr
# komedie          935
# drama            630
# psychologický    396
# příběh           228
# melodrama        164
# dětský           162
# historický       148
# pohádka          124
# povídka          122
# kriminální       120
# etuda             99
# satira            79
# životopisný       75
# dobrodružný       74
# hudební           71
# Name: Film, dtype: int64

# %%
df.sample(5)
# Out:
#                                     Film
# 71245   Dobří holubi se vracejí (397609)  \
# 101928                Crash Road (37358)
# 98077                      Gympl (45351)
# 64108               Bony a klid (397567)
# 61594              Strašná žena (396633)
#
#                                              Země původu  Copyright
# 71245                                     Československo       1988  \
# 101928                                   Česká republika       2007
# 98077                                    Česká republika       2007
# 64108                                     Československo       1987
# 61594   [Československo, Německá demokratická republika]       1965
#
#        Rok výroby                                           Premiéra  Minutáž
# 71245        1987          premiéra 1. 3. 1989 /nepřístupný mládeži/    110.0  \
# 101928  2005—2007  slavnostní premiéra 21. 11. 2007  (multiplex P...    100.0
# ...

# %%
pd.Series(df[(df["Žánr"].str.lower().str.contains("komedie")) & (df["Obsazovanost"] >= 10)].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nlargest(10)
# Out:
# Hrají
# František Krištof-Veselý (129585)    1.000000
# Lukáš Langmajer (35287)              1.000000
# Ladislav Smoljak (8168)              0.944444
# Helena Monczáková (128394)           0.916667
# Alice Bendová (8726)                 0.900000
# Dana Batulková (9391)                0.900000
# Tomáš Matonoha (946)                 0.900000
# Zuzana Onufráková (17671)            0.900000
# Vlasta Burian (11992)                0.871795
# Pavla Tomicová (5142)                0.833333
# dtype: float64

# %%
pd.Series(df[(df["Žánr"].str.lower().str.contains("komedie")) & (df["Obsazovanost"] >= 10)].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nsmallest(10)
# Out:
# Hrají
# Milan Sandhaus (5100)            0.037037
# Václav Neužil (28919)            0.041667
# Adolf Král (128881)              0.043478
# Ladislav Kazda (64089)           0.043478
# Václav Hladík (126900)           0.045455
# Otylie Beníšková (127055)        0.050000
# Stanislava Strobachová (5048)    0.050000
# Oldřich Slavík (4973)            0.052632
# Rudolf Široký (129897)           0.052632
# Václav Stýblo (105496)           0.052632
# dtype: float64

# %%
pd.Series(df[(df["Žánr"].str.lower().str.contains("válečný")) & (df["Obsazovanost"] >= 10)].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nlargest(10)
# Out:
# Hrají
# Alex Jandouš (125505)        0.333333
# Radim Fiala (1839)           0.300000
# Antonín Molčík (8251)        0.272727
# Jiří Plachý (126459)         0.250000
# Milan Jedlička (129728)      0.250000
# Gustáv Valach (10715)        0.230769
# Vlasta Vlasáková (127072)    0.230769
# Ladislav Chudík (14421)      0.210526
# Miriam Chytilová (27446)     0.200000
# Přemysl Kočí (17558)         0.200000
# dtype: float64

# %%
pd.Series(df[(df["Žánr"].str.lower().str.contains("erotický")) & (df["Obsazovanost"] >= 10)].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nlargest(10)
# Out:
# Hrají
# Josef Nedorost (6137)      0.181818
# Jiří Pomeje (3876)         0.136364
# Dana Homolová (8258)       0.111111
# Karel Brožek (75976)       0.105263
# Josef Bulík (75808)        0.100000
# Petr Meissel (7044)        0.100000
# Richard Krajčo (10906)     0.100000
# Sandra Pogodová (14669)    0.100000
# Michaela Kuklová (3313)    0.086957
# Jana Šedová (27310)        0.083333
# dtype: float64

# %%
pd.Series(df[(df["Žánr"].str.lower().str.contains("drama")) & (df["Obsazovanost"] >= 10)].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nlargest(10)
# Out:
# Hrají
# Frank Argus (28475)          1.000000
# Jan Svoboda (55926)          0.923077
# Jaro Hykman (126222)         0.909091
# Eduard Malý (127705)         0.857143
# V. Ch. Vladimírov (38066)    0.850000
# Jarmil Škrdlant (128910)     0.846154
# Marie Fingerová (130185)     0.833333
# Václav Norman (128122)       0.833333
# Anna Opplová (128017)        0.818182
# Helena Friedlová (127788)    0.818182
# dtype: float64

# %%
pd.Series(df[(df["Žánr"].str.lower().str.contains("detektiv")) & (df["Obsazovanost"] >= 10)].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nlargest(10)
# Out:
# Hrají
# Karel Hoffmann (11162)         0.300000
# Olga Navrátilová (80489)       0.272727
# Karel Linc (4960)              0.250000
# Věra Hanslíková (126597)       0.250000
# Karel Semerád (4095)           0.230769
# Vilém Lipský (127289)          0.200000
# Vlasta Mecnarowská (126721)    0.200000
# Adolf Šmíd (105085)            0.181818
# Dana Reimová (34506)           0.181818
# Jarmila Orlová (31061)         0.181818
# dtype: float64

# %%
pd.Series(df[(df["Žánr"].str.lower().str.contains("detektiv|kriminál")) & (df["Obsazovanost"] >= 10)].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nlargest(10)
# Out:
# Hrají
# René Přibil (12369)          0.466667
# Ladislav Goral (26524)       0.416667
# Valerie Chmelová (126056)    0.416667
# Jindřich Blažíček (35206)    0.400000
# Karel Hoffmann (11162)       0.400000
# Václav Syřiště (126657)      0.400000
# Robert Nebřenský (8478)      0.388889
# Lucie Benešová (21914)       0.363636
# Olga Navrátilová (80489)     0.363636
# Věra Vlčková (127099)        0.363636
# dtype: float64

# %%
pd.Series(df[(df["Žánr"].str.lower().str.contains("dětský")) & (df["Obsazovanost"] >= 10)].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nlargest(10)
# Out:
# Hrají
# Jana Tomečková (2371)        0.769231
# Josef Filip (127149)         0.769231
# Veronika Renčová (128659)    0.700000
# Karel Semerád (4095)         0.538462
# Tomáš Holý (27091)           0.500000
# Žaneta Fuchsová (36216)      0.454545
# Karel Hoffmann (11162)       0.400000
# Miloš Vosmanský (6077)       0.400000
# Vladimír Zátka (128952)      0.400000
# Eva Matalová (2375)          0.375000
# dtype: float64

# %%
pd.Series(df[(df["Žánr"].str.lower().str.contains("satira")) & (df["Obsazovanost"] >= 5)].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nlargest(10)
# Out:
# Hrají
# Lumír Tuček (165)           0.428571
# Bedřich Zelenka (36893)     0.400000
# Vladimír Dvořák (5114)      0.375000
# Anna Štrosová (5187)        0.363636
# Ivo Hrdina (129472)         0.363636
# Iva Šašková (128927)        0.333333
# Jiří Sehnal (13532)         0.333333
# Miroslav Vydlák (127593)    0.333333
# Antonín Bubeník (4997)      0.285714
# Jiří Jelínek (13726)        0.285714
# dtype: float64

# %% [markdown]
# ## Systematicky

# %%
df["Obsazovanost"].median()
# Out:
# 19.0

# %%
df["Obsazovanost"].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     4.0
# 0.50    19.0
# 0.75    50.0
# Name: Obsazovanost, dtype: float64

# %%
df["Obsazovanost"].quantile(0.75)
# Out:
# 50.0

# %% [markdown]
# Obsazovanější 1/2 herectva: žebříčky podle žánrů. (Jde o poměr mezi hraním ve filmech žánru x ostatních žánrech.)

# %% [markdown]
# for z in zanry:
#     print(z)
#     print(pd.Series(df[(df["Žánr"] == z) & (df["Obsazovanost"] >= df["Obsazovanost"].median())].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nlargest(3))
#     print("***")

# %% [markdown]
# Obsazovanější 1/3 herectva: žebříčky podle žánrů. (Jde o poměr mezi hraním ve filmech žánru x ostatních žánrech.)

# %%
for z in zanry:
    print(z)
    print(pd.Series(df[(df["Žánr"] == z) & (df["Obsazovanost"] >= df["Obsazovanost"].quantile(0.666))].groupby("Hrají")["Film"].nunique() / df.groupby("Hrají")["Obsazovanost"].max()).nlargest(5))
    print("***")
# Out:
# fraška
# Hrají
# Josef Waltner (126405)        0.131579
# Ada Karlovský (85828)         0.125000
# Karel Němec (128590)          0.081967
# Josef Rovenský (37766)        0.080000
# František Beranský (49046)    0.078947
# dtype: float64
# ***
# anekdota
# Hrají
# Ilona Jirotková (126679)     0.026316
# Tomáš Hanák (198)            0.025000
# Jiřina Šejbalová (125559)    0.023256
# František Kubíček (87096)    0.020833
# Pavel Landovský (1136)       0.020833
# dtype: float64
# ***
# komedie
# Hrají
# Vlasta Burian (11992)     0.871795
# Jára Kohout (4846)        0.750000
# Věra Ferbasová (33991)    0.730159
# Oldřich Nový (12009)      0.707317
# Petr Nárožný (1052)       0.680851
# dtype: float64
# ***
# melodrama
# Hrají
# Saša Dobrovolná (127820)     0.386364
# Jan Černý (127716)           0.340000
# Božena Svobodová (128040)    0.324324
# Hana Vítová (126418)         0.310345
# Elsa Vetešníková (76321)     0.297297
# dtype: float64
# ***
# dobrodružný
# Hrají
# ...
