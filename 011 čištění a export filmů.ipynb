# %% [markdown]
# Todo: sloučit povídky povídkových filmů do 1 řádku?

# %%
import re
import os
import json
import pandas as pd

# %%
with open(os.path.join("data_fixes", "opravy.json"), encoding="utf-8") as opravy:
    opravy = json.loads(opravy.read())

# %%
df = pd.read_json(os.path.join("data", "filmy_raw.json"))

# %%
df
# Out:
#                                                    Film
# 0                             Tábor padlých žen (10144)  \
# 1                         Eastern – Krvavý Hugo (10173)
# 2                                 O Ječmínkovi (102282)
# 3                                   Zimní víla (102314)
# 4                                    Narkoblues (10242)
# ...                                                 ...
# 4533  Hotel Sarajevo aneb Sny obyčejného svatebčana ...
# 4534                              Zdivočelá země (9738)
# 4535                                     Biograf (9769)
# 4536                                  Knoflíkáři (9793)
# 4537                     Baader Meinhof Komplex (99894)
#
#                                             Země původu  Copyright Rok výroby
# 0     Slovensko,                                    ...       1997       1997  \
# 1                                       Česká republika       1997       1997
# 2                                       Česká republika       2003       2002
# 3                                       Česká republika       1999       1999
# 4     Česká republika,                              ...       1997       1997
# ...                                                 ...        ...        ...
# 4533                                    Česká republika       1997       1997
# 4534                                    Česká republika       1997       1997
# 4535                                    Česká republika       1997       1997
# 4536                                    Česká republika       1997       1997
# 4537  Spolková republika Německo,                   ...       2008       2008
#
#                                                Premiéra  Minutáž
# 0     premiéra 28. 9. 2000 /doporučená přístupnost o...  100 min  \
# 1     nedistribuční premiéra 27. 4. 1997            ...    6 min
# 2     nedistribuční premiéra 18. 4. 2003  (televizní...   61 min
# 3     nedistribuční premiéra 24. 12. 1999  (televizn...   52 min
# 4         premiéra 10. 11. 2016 /přístupné bez omezení/    9 min
# ...                                                 ...      ...
# 4533                               premiéra 12. 8. 1997     None
# 4534  premiéra 13. 11. 1997 /přístupný/ (kino 64 U H...  114 min
# 4535  nedistribuční premiéra 12. 6. 1997            ...    5 min
# 4536  premiéra 20. 11. 1997 /doporučená přístupnost ...  102 min
# 4537  slavnostní premiéra 8. 4. 2009  (kino Světozor...  150 min
#
#                                         Režie Kategorie
# 0                                 Laco Halama      film  \
# 1                          Aurel Klimt (1189)      film
# 2                        Milan Cieslar (3593)      film
# 3                      Kryštof Hanzlík (1055)      film
# 4     Břetislav Pojar (3113), Ivan Vít (3030)      film
# ...                                       ...       ...
# 4533                   Rodrigo Morales (3466)      film
# 4534                       Hynek Bočan (2947)      film
# 4535                     Galina Hůlová (7957)      film
# 4536                      Petr Zelenka (4806)      film
# 4537                         Uli Edel (50906)      film
#
#                                               Žánr
# 0                         historický, tragikomedie  \
# 1                                         groteska
# 2                                          pohádka
# 3                                          pohádka
# 4                                         osvětový
# ...                                            ...
# 4533                                       povídka
# 4534                       dobrodružný, historický
# 4535                                      anekdota
# 4536                            komedie, povídkový
# 4537  historický, politický, thriller, životopisný
#
#                                Typologie  ... Výtvarník pozadí
# 0                     hraný, distribuční  ...             None  \
# 1     animovaný, distribuční, studentský  ...             None
# 2                     hraný, distribuční  ...             None
# 3                     hraný, distribuční  ...             None
# 4                 animovaný, distribuční  ...             None
# ...                                  ...  ...              ...
# 4533                  hraný, distribuční  ...             None
# 4534                  hraný, distribuční  ...             None
# 4535  animovaný, distribuční, studentský  ...             None
# 4536                  hraný, distribuční  ...             None
# 4537                  hraný, distribuční  ...             None
#
#      Výrobní skupina Zákazník Vývozní společnost Umělecké vedení Zpěv role
# 0               None     None               None            None      None  \
# 1               None     None               None            None      None
# 2               None     None               None            None      None
# 3               None     None               None            None      None
# 4               None     None               None            None      None
# ...              ...      ...                ...             ...       ...
# 4533            None     None               None            None      None
# 4534            None     None               None            None      None
# 4535            None     None               None            None      None
# 4536            None     None               None            None      None
# 4537            None     None               None            None      None
#
#      Překlad české verze Rychlost Přístupnost cyklus
# 0                   None     None        None   None
# 1                   None     None        None   None
# 2                   None     None        None   None
# 3                   None     None        None   None
# 4                   None     None        None   None
# ...                  ...      ...         ...    ...
# 4533                None     None        None   None
# 4534                None     None        None   None
# 4535                None     None        None   None
# 4536                None     None        None   None
# 4537                None     None        None   None
#
# [4538 rows x 131 columns]

# %%
", ".join(df.columns.to_list())
# Out:
# 'Film, Země původu, Copyright, Rok výroby, Premiéra, Minutáž, Režie, Kategorie, Žánr, Typologie, Originální název, Český název, Anglický název, Souběžný název, Pracovní název, Hrají, Postavy, Pomocná režie, Asistent režie, Původní filmový námět, Scénář, Dramaturg, Kamera, Asistent kamery, Architekt, Návrhy kostýmů, Masky, Střih, Zvuk, Producent, Vedoucí výroby, Zástupce vedoucího výroby, Odborný poradce, Hudba, Choreografie, Lokace, Distribuční slogan, Výrobce, S podporou, Nositelé copyrightu, Distribuce, Délka, Distribuční nosič, Poměr stran, Barva, Zvukový, Zvukový systém/formát, Verze, Mluveno, Podtitulky, Úvodní/závěrečné titulky, Anotace, Obsah, Technický scénář, Výtvarník, Animace, Triky, Postprodukce, Návrhy titulků, Pedagogické vedení, Použitá hudba, Studentský film, Původní metráž, Mezititulky, Ocenění, Poznámka, Mluví, Vizuální efekty, Vedoucí produkce, Předloha, Kaskadéři, Text písně, Zpívá, pásmo, Části, Produkce, Výtvarná spolupráce, Nahrál, Partner, Animační technika, Výprava, Spolupráce, Komentář, Autor komentáře, Druhá kamera, Zvláštní efekty, Koproducent, Výběr hudby, Hudební dramaturgie, Písně, Produkční data, Koordinátor kaskadérů, Výkonná produkce, Zástupce vedoucího produkce, Hudební režie, Účinkují, Dirigent, Ateliéry, Režie české verze, Výrobce české verze, Tančí, České podtitulky, Výrobce českých podtitulků, Asistent vedoucího produkce, Natáčecí formát, Dialogy české verze, Autor projektu, Stav filmu, Souběžný anglický název, Assistent architekta, Asistent zvuku, Podnázev, Asistent vedoucího výroby, Skript, Kostýmy, Asistent střihu, povídkový film, Povídky, Hudba k písni, Prodej práv, Podnázev anglický, Výtvarník pozadí, Výrobní skupina, Zákazník, Vývozní společnost, Umělecké vedení, Zpěv role, Překlad české verze, Rychlost, Přístupnost, cyklus'

# %% [markdown]
# ## Pryč s duplikáty

# %%
df = df.drop_duplicates(subset="Film")

# %% [markdown]
# ## Převedení položek oddělených čárkami na seznamy pro snadné .explode() v budoucnu

# %%
seznamove_sloupce = [
    "Animace",
    "Animační technika",
    "Architekt",
    "Asistent kamery",
    "Asistent režie",
    "Ateliéry",
    "Autor komentáře",
    "Barva",
    "Distribuční nosič",
    "Dramaturg",
    "Druhá kamera",
    "Hudba",
    "Choreografie",
    "Kamera",
    "Kaskadéři",
    "Koordinátor kaskadérů",
    "Koproducent",
    "Masky",
    "Mezititulky",
    "Mluveno",
    "Natáčecí formát",
    "Návrhy kostýmů",
    "Návrhy titulků",
    "Odborný poradce",
    "Pedagogické vedení",
    "Podtitulky",
    "Pomocná režie",
    "Postprodukce",
    "Producent",
    "Produkce",
    "Předloha",
    "Původní filmový námět",
    "Režie",
    "Scénář",
    "Spolupráce",
    "Střih",
    "Technický scénář",
    "Typologie",
    "Úvodní/závěrečné titulky",
    "Vedoucí produkce",
    "Vedoucí výroby",
    "Verze",
    "Výprava",
    "Výkonná produkce",
    "Výtvarná spolupráce",
    "Výtvarník",
    "Zástupce vedoucího produkce",
    "Zástupce vedoucího výroby",
    "Země původu",
    "Zpívá",
    "Zvuk",
    "Zvukový systém/formát",
    "Žánr"]

# %%
seznamove_sloupce_firmy = [
    "Distribuce",
    "Nositelé copyrightu",
    "Partner",
    "S podporou",
    "Triky",
    "Vizuální efekty",
    "Výrobce",
    "Zvláštní efekty"
]

# %%
jiz_seznam = [
    "Dirigent",
    "Hudba k písni",
    "Nahrál",
    "Písně",
    "Použitá hudba",
    "Tančí",
    "Text písně",
    "Hudební dramaturgie",
    "Hudební režie",
    "Výběr hudby",
    "Zpěv role"
]

# %% [markdown]
# ## Funkce pro čištění

# %%
def nahrad(bunka, original, nahrada):
    
    if isinstance(bunka, list):
        opravena_bunka = []
        try:
            for b in bunka:
                if b == original:
                    opravena_bunka.append(nahrada)
                elif original in b:
                    opravena_bunka.append(b.replace(original,nahrada))
                else:
                    opravena_bunka.append(b)
        except:
            opravena_bunka = bunka
            
    elif isinstance(bunka, str):
        opravena_bunka = ""
        if bunka == original:
            opravena_bunka = nahrada
        elif original in bunka:
            opravena_bunka = bunka.replace(original, nahrada)
        else:
            opravena_bunka = bunka
    
    else:
        opravena_bunka = bunka
    
    return opravena_bunka

# %%
def citlivy_orez(x):
    if isinstance(x, str):
        x = x.strip()
    if isinstance(x, list):
        try:
            x = [y.strip() for y in x]
        except:
            pass
    return(x)

# %%
def do_seznamu(polozka):
    try:
        if "," in polozka:
            polozka = str(polozka).split(",")
            polozka = [p.strip() for p in polozka]
    except:
        pass
    return(polozka)

# %%
def firmy_do_seznamu(polozka):
    if polozka:
        polozka = re.sub("\s"," ",polozka)
        polozka = re.sub("\n"," ",polozka)
        polozka = polozka.replace(" spol. s "," s. ").replace(" spol.s "," s. ").replace("s.r.o.","s. r. o.").replace("s. r.o.","s. r. o.").replace("a.s.","a. s.").replace(", s. r. o."," s. r. o.").replace(",s. r. o."," s. r. o.").replace(", a. s."," a. s.").replace(",a. s."," a. s.").replace(", v. o. s."," v. o. s.").replace("ČESKÁ TELEVIZE","Česká televize").replace("BONTONFILM","Bontonfilm").replace("FALCON","Falcon")
        polozka = do_seznamu(polozka)
    else:
        polozka = polozka
    return(polozka)

# %% [markdown]
# ## Čištěníčko

# %%
df[df["Režie"].str.contains("české verze Agnieszka Holland /ž/",na=False)]
# Out:
#                                    Film
# 300  Jánošík. Pravdivá historie (21574)  \
#
#                                            Země původu  Copyright
# 300  Polsko,                                       ...       2009  \
#
#           Rok výroby                                           Premiéra
# 300  2002, 2008—2009  zahraniční premiéra 26. 8. 2009  (Nowy Sącz, P...  \
#
#      Minutáž                                      Režie Kategorie
# 300  137 min  české verze Agnieszka Holland /ž/ (12106)      film  \
#
#                         Žánr           Typologie  ... Výtvarník pozadí
# 300  historický, životopisný  hraný, distribuční  ...             None  \
#
#     Výrobní skupina Zákazník Vývozní společnost Umělecké vedení Zpěv role
# 300            None     None               None            None      None  \
#
#     Překlad české verze Rychlost Přístupnost cyklus
# 300                None     None        None   None
#
# [1 rows x 131 columns]

# %%
df["Režie"] = df["Režie"].apply(lambda x: nahrad(x,"české verze", ""))
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_6712\1158444040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Režie"] = df["Režie"].apply(lambda x: nahrad(x,"české verze", ""))

# %%
df[df["Režie"].str.contains("české verze Agnieszka Holland /ž/",na=False)]
# Out:
# Empty DataFrame
# Columns: [Film, Země původu, Copyright, Rok výroby, Premiéra, Minutáž, Režie, Kategorie, Žánr, Typologie, Originální název, Český název, Anglický název, Souběžný název, Pracovní název, Hrají, Postavy, Pomocná režie, Asistent režie, Původní filmový námět, Scénář, Dramaturg, Kamera, Asistent kamery, Architekt, Návrhy kostýmů, Masky, Střih, Zvuk, Producent, Vedoucí výroby, Zástupce vedoucího výroby, Odborný poradce, Hudba, Choreografie, Lokace, Distribuční slogan, Výrobce, S podporou, Nositelé copyrightu, Distribuce, Délka, Distribuční nosič, Poměr stran, Barva, Zvukový, Zvukový systém/formát, Verze, Mluveno, Podtitulky, Úvodní/závěrečné titulky, Anotace, Obsah, Technický scénář, Výtvarník, Animace, Triky, Postprodukce, Návrhy titulků, Pedagogické vedení, Použitá hudba, Studentský film, Původní metráž, Mezititulky, Ocenění, Poznámka, Mluví, Vizuální efekty, Vedoucí produkce, Předloha, Kaskadéři, Text písně, Zpívá, pásmo, Části, Produkce, Výtvarná spolupráce, Nahrál, Partner, Animační technika, Výprava, Spolupráce, Komentář, Autor komentáře, Druhá kamera, Zvláštní efekty, Koproducent, Výběr hudby, Hudební dramaturgie, Písně, Produkční data, Koordinátor kaskadérů, Výkonná produkce, Zástupce vedoucího produkce, Hudební režie, Účinkují, Dirigent, Ateliéry, Režie české verze, Výrobce české verze, ...]
# Index: []
#
# [0 rows x 131 columns]

# %%
df[df["Režie"].str.contains("Agnieszka Holland",na=False)]
# Out:
#                                     Film
# 300   Jánošík. Pravdivá historie (21574)  \
# 2100                 Hřích boha (396804)
# 3029                 Hořící keř (398412)
# 3671         Přes kosti mrtvých (401201)
# 4131                   Šarlatán (402092)
#
#                                             Země původu  Copyright
# 300   Polsko,                                       ...       2009  \
# 2100                                     Československo       1969
# 3029                                    Česká republika       2013
# 3671  Polsko,                                       ...       2017
# 4131  Česká republika,                              ...       2020
#
#            Rok výroby                                           Premiéra
# 300   2002, 2008—2009  zahraniční premiéra 26. 8. 2009  (Nowy Sącz, P...  \
# 2100             1969                                               None
# 3029             2013       premiéra 12. 9. 2013 /přístupné bez omezení/
# 3671        2016—2017  premiéra 20. 4. 2017 /nevhodné pro děti do 12 ...
# 4131             2019  festivalová premiéra 27. 2. 2020  (70. mezinár...
#
#       Minutáž                                              Režie Kategorie
# 300   137 min                      Agnieszka Holland /ž/ (12106)      film  \
# 2100   23 min                          Agnieszka Holland (12106)      film
# 3029  206 min                          Agnieszka Holland (12106)      film
# 3671  128 min  Agnieszka Holland /ž/ (12106), Kasia Adamik /ž...      film
# 4131  118 min                      Agnieszka Holland /ž/ (12106)      film
#
#                                         Žánr
# 300                  historický, životopisný  \
# 2100                                  příběh
# 3029  historický, psychologický, životopisný
# 3671     kriminální, psychologický, thriller
# 4131          drama, historický, životopisný
#
#                              Typologie  ... Výtvarník pozadí Výrobní skupina
# 300                 hraný, distribuční  ...             None            None  \
# 2100  hraný, nedistribuční, studentský  ...             None            None
# 3029                hraný, distribuční  ...             None            None
# 3671                hraný, distribuční  ...             None            None
# 4131                hraný, distribuční  ...             None            None
#
#      Zákazník Vývozní společnost Umělecké vedení Zpěv role
# 300      None               None            None      None  \
# 2100     None               None            None      None
# 3029     None               None            None      None
# 3671     None               None            None      None
# 4131     None               None            None      None
#
#      Překlad české verze Rychlost Přístupnost cyklus
# 300                 None     None        None   None
# 2100                None     None        None   None
# 3029                None     None        None   None
# 3671                None     None        None   None
# 4131                None     None        None   None
#
# [5 rows x 131 columns]

# %%
df = df.apply(lambda x: citlivy_orez(x))

# %%
for s in seznamove_sloupce:
    df[s] = df[s].apply(lambda x: do_seznamu(x))
for s in seznamove_sloupce_firmy:
    df[s] = df[s].apply(lambda x: firmy_do_seznamu(x))

# %%
def seznam_lokaci(lokace_hrube):
    lokace_ciste = []
    if lokace_hrube:
        lokace_hrube = lokace_hrube.split("),")
        for x in lokace_hrube:
            if "(" in x:
                x = x + ")"
            x = x.strip()
            x = x.replace("))",")")
            if x[0:2] == ", ":
                x = x[2:]
            if x != ")":
                lokace_ciste.append(x)
    return(lokace_ciste)

# %%
df["Lokace"] = df["Lokace"].apply(lambda x: seznam_lokaci(x))

# %%
df["Minutáž"] = df["Minutáž"].apply(lambda x: str(x).replace("min","").strip())
df["Minutáž"] = pd.to_numeric(df["Minutáž"], errors="coerce")

# %%
def ratio(x):
    if x:
        x = x.replace("1:","")
        x = x.split(", ")
        x = [y.strip() for y in x]
        x = [y.replace(",",".") for y in x]
        x = [pd.to_numeric(y) for y in x]
        if len(x) == 1:
            x = x[0]
    return(x)

# %%
df["Poměr stran"] = df["Poměr stran"].apply(lambda x: ratio(x))

# %%
def metraz(x):
    if x:
        x = int(x.replace("metrů","").replace(" ",""))
    else:
        x = x
    return x

# %%
df["Původní metráž"] = df["Původní metráž"].apply(lambda x: metraz(x))

# %%
def kill_whitespace(x):
    def seriously(y):
        y = re.sub("\s+", " ", y)
        return(y)
    if isinstance(x, list):
        x = [seriously(y) for y in x]
    if isinstance(x, str):
        x = seriously(x)
    return(x)

# %%
df["Ocenění"] = df["Ocenění"].apply(lambda x: kill_whitespace(x))

# %%
def roky_vyroby(x):
    if x:
        zacatek = int(x[:4])
        konec = int(x[-4:])
    else:
        zacatek = None
        konec = None
    return [zacatek, konec]

# %%
df["Začátek výroby"] = df["Rok výroby"].apply(lambda x: roky_vyroby(x)[0])
df["Konec výroby"] = df["Rok výroby"].apply(lambda x: roky_vyroby(x)[1])

# %%
df = df.sort_values(by = "Copyright")

# %% [markdown]
# ## Oprava minutáže

# %%
df[df["Minutáž"] > 130].groupby(["Film","Copyright"])["Minutáž"].max().nlargest(60)
# Out:
# Film                                                                                                                                              Copyright
# Místo v houfu (396595)                                                                                                                            1964         1112.0
# Hrdina divokého západu (402185)                                                                                                                   1920          700.0
# Zapomenuté transporty (79193)                                                                                                                     2007          341.0
# Komunismus a síť, aneb Konec zastupitelské demokracie (402026)                                                                                    2019          337.0
# Bohemia docta aneb Labyrint světa a lusthauz srdce /Božská komedie/ (17002)                                                                       2000          254.0
# Kdo bude hlídat hlídače? Dalibor aneb Klíč k Chaloupce strýčka Toma (20716)                                                                       2002          245.0
# Dny zrady (396979)                                                                                                                                1973          227.0
# Venoušek a Stázička (395308)                                                                                                                      1922          223.0
# Co dělat? Cesta z Prahy do Českého Krumlova aneb Jak jsem sestavoval novou vládu (9101)                                                           1996          216.0
# Nový Hyperion aneb Volnost, rovnost, bratrství (7145)                                                                                             1992          207.0
# Hořící keř (398412)                                                                                                                               2013          206.0
# 25 ze šedesátých aneb Československá nová vlna (158554)                                                                                           2010          205.0
# Tmář a jeho rod aneb Slzavé údolí pyramid (80194)                                                                                                 2011          199.0
# Lazebník sibiřský (24194)                                                                                                                         1999          179.0
# Vojta Lavička: Nahoru a dolů (103360)                                                                                                             2013          176.0
# Nabarvené ptáče (401962)                                                                                                                          2019          170.0
# Babička I., II. (396899)                                                                                                                          1971          163.0
# Marketa Lazarová (396753)                                                                                                                         1967          160.0
# Zviditelnění (397888)                                                                                                                             1997          157.0
# Ragtime (401385)                                                                                                                                  1981          155.0
# Amadeus (401253)                                                                                                                                  1984          155.0
# Nejasná zpráva o konci světa (9463)                                                                                                               1997          152.0
# Baader Meinhof Komplex (99894)                                                                                                                    2008          150.0
# Želary (13452)                                                                                                                                    2003          150.0
# Putování Jana Amose (397429)                                                                                                                      1983          149.0
# Záviš, kníže pornofolku pod vlivem Griffithovy Intolerance a Tatiho Prázdnin pana Hulota aneb Vznik a zánik Československa (1918 – 1992) (38463)  2006          147.0
# Pouta (80516)                                                                                                                                     2010          146.0
# Toman (401772)                                                                                                                                    2018          145.0
# Casino Royale (47114)                                                                                                                             2006          145.0
# Plukovník Švec (395482)                                                                                                                           1929          144.0
# Císařův pekař – Pekařův císař (396131)                                                                                                            1951          144.0
# Osvobození Prahy (397108)                                                                                                                         1976          141.0
# Edith Piaf (52854)                                                                                                                                2007          141.0
# „Je mi jedno, že se zapíšeme do dějin jako barbaři“ (401916)                                                                                      2018          139.0
# Královská aféra (182846)                                                                                                                          2012          138.0
# Bathory (40761)                                                                                                                                   2008          138.0
# Občanský průkaz (103354)                                                                                                                          2010          137.0
# Jánošík. Pravdivá historie (21574)                                                                                                                2009          137.0
# Krajina ve stínu (402170)                                                                                                                         2020          136.0
# Útěk do Budína (18265)                                                                                                                            2002          135.0
# Anna proletářka (396154)                                                                                                                          1952          135.0
# Bouřlivé víno (397122)                                                                                                                            1976          135.0
# Prodaná nevěsta (395602)                                                                                                                          1933          134.0
# Román hloupého Honzy (395387)                                                                                                                     1926          133.0
# Sarajevský atentát (397073)                                                                                                                       1975          133.0
# Temné slunce (397277)                                                                                                                             1980          133.0
# Babovřesky aneb Z dopisu jedné drbny (400563)                                                                                                     2013          133.0
# Karel (402130)                                                                                                                                    2020          133.0
# Kentauři (397170)                                                                                                                                 1978          133.0
# Hvězda padá vzhůru (397037)                                                                                                                       1974          133.0
# Fotograf (400581)                                                                                                                                 2015          133.0
# Ať žije republika (396660)                                                                                                                        1965          132.0
# Valmont (401384)                                                                                                                                  1989          131.0
# Kdyby tisíc klarinetů (396600)                                                                                                                    1964          131.0
# Zahradnictví: Rodinný přítel (401671)                                                                                                             2017          131.0
# Cirkus v cirkuse (397082)                                                                                                                         1975          131.0
# Oliver Twist (37449)                                                                                                                              2005          131.0
# Name: Minutáž, dtype: float64

# %% [markdown]
# - Místo v houfu (396595) – Zjevná chyba, nahradíme údajem z ČSDF.
# - Venoušek a Stázička, Vojta Lavička: Nahoru a dolů (103360) – dtto
# - Hrdina divokého západu (402185) – Složitější: "Humorné příhody Eddieho Pola a Marie Walcampové v „15 epizodách a 142 dílech“. Nejméně špatné ze špatných řešení: nahradíme mediánem za rok 1920, takže to nerozdrbe statistiky.
# - Zapomenuté transporty (79193) – vyhazujeme, nechávám jednotlivé díly.

# %%
df.loc[df["Film"] == "Místo v houfu (396595)","Minutáž"]=115
df.loc[df["Film"] == "Venoušek a Stázička (395308)","Minutáž"]=68
df.loc[df["Film"] == "Vojta Lavička: Nahoru a dolů (103360)","Minutáž"]=89
df.loc[df["Film"] == "Hrdina divokého západu (402185)","Minutáž"]=df[df["Copyright"] == 1920]["Minutáž"].median().astype(int)
df = df[~(df["Film"] == "Zapomenuté transporty (79193)")]

# %%
df = df.drop(labels="cyklus", axis=1)

# %% [markdown]
# ## Odstranění exilových filmů M. Formana a bondovky

# %%
df = df[~df.Film.isin(opravy["exil"])]
df = df[df["Země původu"].str.contains("Česk|Rakousko-Uhersko",na=True)]

# %% [markdown]
# ## Oprava jmen

# %%
jmena = opravy["jmena"]

# %%
for key, val in jmena.items():
    df = df.applymap(lambda x: nahrad(x, key, val))

# %% [markdown]
# ## Odženění

# %%
import json
with open(os.path.join("data_fixes", "seznamy.json"), encoding="utf-8") as seznamy:
    seznamy = json.loads(seznamy.read())

# %%
profese = seznamy["profese"]

# %%
df[df["Režie"].str.contains("/ž/",na=False)]
# Out:
#                                            Film
# 3000          Jezevec nosí pochybnosti (397705)  \
# 4452           Poslední Vánoce mého domu (8046)
# 4454                               Zámek (8048)
# 4426                  Špendlík na motýla (7788)
# 4451                        Kulaté ruiny (8045)
# 4316                  Černobílá v barvě (53571)
# 311                            Ene bene (22433)
# 80                                Výlet (12883)
# 4266                             Kvaska (45361)
# 4253                      Malá pokušení (44539)
# 4297                           Tajnosti (52699)
# 4362                     Stínu neutečeš (58832)
# 4378                            Babička (66080)
# 382                            Lištičky (37318)
# 144                              Tacho (163239)
# 20                       Mamas & Papas (106667)
# 148                       Perfect Days (163669)
# 254                    Křehká identita (197143)
# 3484                  Láska, soudruhu! (400613)
# 3035                    Můj pes Killer (398425)
# 3487                              MY 2 (400616)
# 3797                      Doma je tady (401744)
# 3709                          Superbia (401654)
# 3659                         Tanečnice (401150)
# 4035                        Spolu sami (401989)
# 3874                              Útěk (401824)
# 3873                      Touch Me Not (401823)
# 3824                 Můj neznámý vojín (401773)
# 3828  Poslední mise Generála Jermakova (401777)
# 3831                      Hlasy v lese (401780)
# 4079             Viva video video viva (402036)
# 4056                     Ukradený stát (402010)
# 4051                 Ženská na vrcholu (402005)
# 4178                   Žáby bez jazyka (402141)
# 4112      Kiruna – překrásný nový svět (402071)
# 4143                             Dcera (402104)
# 4014             The Sound Is Innocent (401967)
# 4160      Jednotka intenzivního života (402123)
# 4177                           Mstitel (402140)
#
#                                             Země původu  Copyright Rok výroby
# 3000                                     Československo       1992       1992  \
# 4452                         [Česká republika, Francie]       1994       1994
# 4454                         [Česká republika, Francie]       1994       1994
# 4426                  [Česká republika, Velká Británie]       1994  1993—1994
# 4451                         [Česká republika, Francie]       1994       1994
# 4316                                    Česká republika       1999       1998
# 311                                     Česká republika       1999       1999
# 80                         [Česká republika, Slovensko]       2002       2001
# 4266                                    Česká republika       2006       2006
# 4253                                    Česká republika       2006       2005
# 4297                       [Česká republika, Slovensko]       2007       2006
# 4362                                    Česká republika       2009       2009
# 4378                                    Česká republika       2009       2009
# 382                 [Česká republika, Slovensko, Irsko]       2009       2009
# 144                                     Česká republika       2010       2010
# 20                                      Česká republika       2010       2009
# 148                                     Česká republika       2011       2011
# 254                        [Slovensko, Česká republika]       2012       2012
# 3484                  [Finsko, Norsko, Česká republika]       2013       2013
# 3035                       [Slovensko, Česká republika]       2013       2012
# 3487                                    Česká republika       2014       2013
# 3797                        [Česká republika, Rakousko]       2016       2016
# 3709             [Maďarsko, Česká republika, Slovensko]       2016       2016
# 3659                 [Francie, Belgie, Česká republika]       2016  2013—2016
# 4035                                    Česká republika       2018       2018
# 3874                 [Polsko, Česká republika, Švédsko]       2018  2017—2018
# 3873  [Rumunsko, Spolková republika Německo, Česká r...       2018  2015—2018
# 3824             [Česká republika, Lotyšsko, Slovensko]       2018  2016—2018
# 3828                                    Česká republika       2018  2017—2018
# 3831  [Slovensko, Česká republika, Maďarsko, Polsko,...       2018  2017—2018
# 4079                                    Česká republika       2019       2019
# 4056                       [Slovensko, Česká republika]       2019  2017—2019
# 4051                       [Česká republika, Slovensko]       2019       2019
# 4178                       [Česká republika, Slovensko]       2019       2018
# 4112                                    Česká republika       2019  2015—2019
# 4143                                    Česká republika       2019  2018—2019
# 4014              [Česká republika, Francie, Slovensko]       2019  2016—2019
# 4160                                    Česká republika       2021  2019—2021
# 4177                                    Česká republika       2021  2019—2020
#
#                                                Premiéra  Minutáž
# 3000                                               None     17.0  \
# 4452                                               None     11.0
# 4454                                               None     11.0
# 4426  premiéra 16. 2. 1995 /přístupný/ (kino Světozo...    113.0
# 4451                                               None     13.0
# 4316  slavnostní premiéra 27. 1. 1999               ...     58.0
# 311                    premiéra 10. 2. 2000 /přístupný/    104.0
# 80    premiéra 21. 3. 2002 /doporučená přístupnost o...    100.0
# 4266  slavnostní premiéra 21. 2. 2007  (multiplex Pa...    102.0
# 4253  premiéra 1. 6. 2006 /přístupný/ (kino Aero, Pr...      8.0
# 4297  slavnostní premiéra 16. 5. 2007  (multiplex Vi...     97.0
# 4362  premiéra 10. 12. 2009 /přístupný/ (kino Lucern...    102.0
# 4378  slavnostní premiéra 25. 2. 2009  (kino Bio Oko...     75.0
# 382   premiéra 17. 9. 2009 /doporučená přístupnost o...     86.0
# 144   slavnostní premiéra 1. 12. 2010  (multiplex Ci...     99.0
# 20    slavnostní premiéra 14. 4. 2010  (multiplex Ci...    110.0
# 148   slavnostní premiéra 26. 10. 2011  (kina Světoz...    100.0
# 254        premiéra 19. 9. 2013 /přístupné bez omezení/     70.0
# 3484  premiéra 24. 4. 2014 /nevhodné pro děti do 12 ...    105.0
# 3035  premiéra 11. 4. 2013 /nevhodné pro děti do 12 ...     87.0
# 3487  premiéra 20. 11. 2014 /nevhodné pro děti do 12...     99.0
# 3797  distribuční premiéra 23. 11. 2017 /nevhodné pr...     76.0
# 3709  premiéra 8. 3. 2017 /nevhodné pro děti do 12 let/     15.0
# 3659  zahraniční premiéra 28. 9. 2016  (Paříž, Franc...    108.0
# 4035  festivalová premiéra 26. 10. 2018  (22. meziná...     10.0
# 3874  festivalová premiéra 15. 5. 2018  (71. mezinár...    103.0
# 3873  festivalová premiéra 22. 2. 2018  (68. mezinár...    123.0
# 3824  slavnostní premiéra 17. 8. 2018  (palác Lucern...     80.0
# 3828  distribuční premiéra 21. 8. 2018 /přístupné be...     26.0
# 3831                                        21. 8. 2018     26.0
# 4079  slavnostní premiéra 12. 2. 2020  (kino Světozo...     90.0
# 4056  zahraniční premiéra 10. 10. 2019  (Bratislava,...     79.0
# 4051  předpremiéra 2. 11. 2019  (kino Vesmír, Náchod...    108.0
# 4178  festivalová premiéra 26. 1. 2020  (49. mezinár...    116.0
# 4112  festivalová premiéra 26. 10. 2019  (23. meziná...     87.0
# 4143  festivalová premiéra 10. 6. 2019  (43. mezinár...     15.0
# 4014  festivalová premiéra 10. 4. 2019  (50. mezinár...     69.0
# 4160  festivalová premiéra 25. 8. 2021  (55. mezinár...     77.0
# 4177  slavnostní premiéra 28. 6. 2021  (multiplex Ci...     96.0
#
#                                   Režie Kategorie
# 3000          Jasmina Bralić /ž/ (9246)      film  \
# 4452         Mira Erdevički /ž/ (11299)   povídka
# 4454  Natalia Koryncka-Gruz /ž/ (79384)   povídka
# 4426         Hannah Kodicek /ž/ (79383)      film
# 4451              Julia Szederkényi /ž/   povídka
# 4316  Mira Erdevički-Charap /ž/ (11299)      film
# 311              Alice Nellis /ž/ (535)      film
# 80               Alice Nellis /ž/ (535)      film
# 4266           Mirjam Landa /ž/ (11733)      film
# 4253        Slobodanka Radun /ž/ (6321)      film
# 4297             Alice Nellis /ž/ (535)      film
# 4362              Lenka Kny /ž/ (23107)      film
# 4378          Zuzana Piussi /ž/ (39166)      film
# 382              Mira Fornay /ž/ (6226)      film
# 144            Mirjam Landa /ž/ (11733)      film
# 20               Alice Nellis /ž/ (535)      film
# 148              Alice Nellis /ž/ (535)      film
# 254           Zuzana Piussi /ž/ (39166)      film
# 3484           Taru Mäkelä /ž/ (101580)      film
# 3035             Mira Fornay /ž/ (6226)      film
# 3487        Slobodanka Radun /ž/ (6321)      film
# 3797          Tereza Kotyk /ž/ (131484)      film
# 3709             Luca Tóth /ž/ (130390)      film
# 3659   Stéphanie Di Giusto /ž/ (130114)      film
# 4035   Diana Cam Van Nguyen /ž/ (34536)      film
# 3874           Agnieszka Smoczyńska /ž/      film
# 3873                 Adina Pintilie /ž/      film
# 3824          Anna Kryvenko /ž/ (84024)      film
# 3828             Jevdokija Moskvina /ž/   povídka
# 3831            Marie Elisa Scheidt /ž/   povídka
# 4079          Adéla Komrzý /ž/ (125538)      film
# 4056          Zuzana Piussi /ž/ (39166)      film
# 4051              Lenka Kny /ž/ (23107)      film
# 4178             Mira Fornay /ž/ (6226)      film
# 4112      Greta Stocklassa /ž/ (112117)      film
# 4143      Daria Kashcheeva /ž/ (105636)      film
# 4014          Johana Ožvold /ž/ (30779)      film
# 4160          Adéla Komrzý /ž/ (125538)      film
# 4177    Lucia Klein Svoboda /ž/ (19838)      film
#
#                                                    Žánr
# 3000                                             příběh  \
# 4452                                [povídka, dokument]
# 4454                                [povídka, dokument]
# 4426                                      psychologický
# 4451                          [experimentální, povídka]
# 4316                                           dokument
# 311                                        tragikomedie
# 80                          [psychologický, road movie]
# 4266                                            muzikál
# 4253                                      psychologický
# 4297           [komedie, psychologický, smutná komedie]
# 4362                                      psychologický
# 4378                                           dokument
# 382                                       psychologický
# 144                                        tragikomedie
# 20                               [drama, psychologický]
# 148                           [komedie, smutná komedie]
# 254                                            dokument
# 3484               [historický, komedie, hořká komedie]
# 3035                                      psychologický
# 3487                          [psychologický, milostný]
# 3797                                      psychologický
# 3709                                        podobenství
# 3659  [historický, psychologický, taneční, životopisný]
# 4035                                     experimentální
# 3874                                      psychologický
# 3873                    [experimentální, psychologický]
# 3824                                 [historický, esej]
# 3828                   [historický, politický, povídka]
# 3831                   [historický, politický, povídka]
# 4079                                           umělecký
# 4056                                          politický
# 4051                              [komedie, romantický]
# 4178             [drama, experimentální, psychologický]
# 4112                             [sociální, časosběrný]
# 4143                             [drama, psychologický]
# 4014                    [experimentální, hudební, esej]
# 4160                   [sociální, osvětový, časosběrný]
# 4177               [komedie, parodie, bláznivá komedie]
#
#                                         Typologie  ... Výrobní skupina
# 3000             [hraný, distribuční, studentský]  ...            None  \
# 4452         [hraný, distribuční, krátkometrážní]  ...            None
# 4454         [hraný, distribuční, krátkometrážní]  ...            None
# 4426                         [hraný, distribuční]  ...            None
# 4451         [hraný, distribuční, krátkometrážní]  ...            None
# 4316                  [dokumentární, distribuční]  ...            None
# 311                          [hraný, distribuční]  ...            None
# 80                           [hraný, distribuční]  ...            None
# 4266                         [hraný, distribuční]  ...            None
# 4253                         [hraný, distribuční]  ...            None
# 4297                         [hraný, distribuční]  ...            None
# 4362                         [hraný, distribuční]  ...            None
# 4378                  [dokumentární, distribuční]  ...            None
# 382                          [hraný, distribuční]  ...            None
# 144                          [hraný, distribuční]  ...            None
# 20                           [hraný, distribuční]  ...            None
# 148                          [hraný, distribuční]  ...            None
# 254                   [dokumentární, distribuční]  ...            None
# 3484                         [hraný, distribuční]  ...            None
# 3035                         [hraný, distribuční]  ...            None
# 3487                         [hraný, distribuční]  ...            None
# 3797                         [hraný, distribuční]  ...            None
# 3709                     [animovaný, distribuční]  ...            None
# 3659                         [hraný, distribuční]  ...            None
# 4035         [animovaný, distribuční, studentský]  ...            None
# 3874                         [hraný, distribuční]  ...            None
# 3873                         [hraný, distribuční]  ...            None
# 3824                  [dokumentární, distribuční]  ...            None
# 3828                  [dokumentární, distribuční]  ...            None
# 3831  [dokumentární, distribuční, krátkometrážní]  ...            None
# 4079                  [dokumentární, distribuční]  ...            None
# 4056                  [dokumentární, distribuční]  ...            None
# 4051                         [hraný, distribuční]  ...            None
# 4178                         [hraný, distribuční]  ...            None
# 4112      [dokumentární, distribuční, studentský]  ...            None
# 4143         [animovaný, distribuční, studentský]  ...            None
# 4014                  [dokumentární, distribuční]  ...            None
# 4160      [dokumentární, distribuční, studentský]  ...            None
# 4177                         [hraný, distribuční]  ...            None
#
#      Zákazník Vývozní společnost Umělecké vedení Zpěv role
# 3000     None               None            None      None  \
# 4452     None               None            None      None
# 4454     None               None            None      None
# 4426     None               None            None      None
# 4451     None               None            None      None
# 4316     None               None            None      None
# 311      None               None            None      None
# 80       None               None            None      None
# 4266     None               None            None      None
# 4253     None               None            None      None
# 4297     None               None            None      None
# 4362     None               None            None      None
# 4378     None               None            None      None
# 382      None               None            None      None
# 144      None               None            None      None
# 20       None               None            None      None
# 148      None               None            None      None
# 254      None               None            None      None
# 3484     None               None            None      None
# 3035     None               None            None      None
# 3487     None               None            None      None
# 3797     None               None            None      None
# 3709     None               None            None      None
# 3659     None               None            None      None
# 4035     None               None            None      None
# 3874     None               None            None      None
# 3873     None               None            None      None
# 3824     None               None            None      None
# 3828     None               None            None      None
# 3831     None               None            None      None
# 4079     None               None            None      None
# 4056     None               None            None      None
# 4051     None               None            None      None
# 4178     None               None            None      None
# 4112     None               None            None      None
# 4143     None               None            None      None
# 4014     None               None            None      None
# 4160     None               None            None      None
# 4177     None               None            None      None
#
#      Překlad české verze Rychlost Přístupnost Začátek výroby Konec výroby
# 3000                None     None        None           1992         1992
# 4452                None     None        None           1994         1994
# 4454                None     None        None           1994         1994
# 4426                None     None        None           1993         1994
# 4451                None     None        None           1994         1994
# 4316                None     None        None           1998         1998
# 311                 None     None        None           1999         1999
# 80                  None     None        None           2001         2001
# 4266                None     None        None           2006         2006
# 4253                None     None        None           2005         2005
# 4297                None     None        None           2006         2006
# 4362                None     None        None           2009         2009
# 4378                None     None        None           2009         2009
# 382                 None     None        None           2009         2009
# 144                 None     None        None           2010         2010
# 20                  None     None        None           2009         2009
# 148                 None     None        None           2011         2011
# 254                 None     None        None           2012         2012
# 3484                None     None        None           2013         2013
# 3035                None   24 fps        None           2012         2012
# 3487                None     None        None           2013         2013
# 3797                None     None        None           2016         2016
# 3709                None     None        None           2016         2016
# 3659                None     None        None           2013         2016
# 4035                None     None        None           2018         2018
# 3874                None     None        None           2017         2018
# 3873                None     None        None           2015         2018
# 3824                None     None        None           2016         2018
# 3828                None     None        None           2017         2018
# 3831                None     None        None           2017         2018
# 4079                None     None        None           2019         2019
# 4056                None     None        None           2017         2019
# 4051                None     None        None           2019         2019
# 4178                None     None        None           2018         2018
# 4112                None     None        None           2015         2019
# 4143                None     None        None           2018         2019
# 4014                None     None        None           2016         2019
# 4160                None     None        None           2019         2021
# 4177                None     None        None           2019         2020
#
# [39 rows x 132 columns]

# %%
def odzen(bunka):
    
    def odz(x):
        return x.replace(" /ž/","").strip()
    
    if isinstance(bunka, list):
        try:
            cista_bunka = [odz(x) for x in bunka]
        except:
            cista_bunka = bunka
            
    if isinstance(bunka, str):
        cista_bunka = odz(bunka)
        
    else:
        cista_bunka = bunka
        
    return cista_bunka

# %%
for p in profese:
    df[p] = df[p].apply(lambda x: nahrad(x, " /ž/", ""))

# %%
df[df["Režie"].str.contains("/ž/",na=False)]
# Out:
# Empty DataFrame
# Columns: [Film, Země původu, Copyright, Rok výroby, Premiéra, Minutáž, Režie, Kategorie, Žánr, Typologie, Originální název, Český název, Anglický název, Souběžný název, Pracovní název, Hrají, Postavy, Pomocná režie, Asistent režie, Původní filmový námět, Scénář, Dramaturg, Kamera, Asistent kamery, Architekt, Návrhy kostýmů, Masky, Střih, Zvuk, Producent, Vedoucí výroby, Zástupce vedoucího výroby, Odborný poradce, Hudba, Choreografie, Lokace, Distribuční slogan, Výrobce, S podporou, Nositelé copyrightu, Distribuce, Délka, Distribuční nosič, Poměr stran, Barva, Zvukový, Zvukový systém/formát, Verze, Mluveno, Podtitulky, Úvodní/závěrečné titulky, Anotace, Obsah, Technický scénář, Výtvarník, Animace, Triky, Postprodukce, Návrhy titulků, Pedagogické vedení, Použitá hudba, Studentský film, Původní metráž, Mezititulky, Ocenění, Poznámka, Mluví, Vizuální efekty, Vedoucí produkce, Předloha, Kaskadéři, Text písně, Zpívá, pásmo, Části, Produkce, Výtvarná spolupráce, Nahrál, Partner, Animační technika, Výprava, Spolupráce, Komentář, Autor komentáře, Druhá kamera, Zvláštní efekty, Koproducent, Výběr hudby, Hudební dramaturgie, Písně, Produkční data, Koordinátor kaskadérů, Výkonná produkce, Zástupce vedoucího produkce, Hudební režie, Účinkují, Dirigent, Ateliéry, Režie české verze, Výrobce české verze, ...]
# Index: []
#
# [0 rows x 132 columns]

# %%
df[df["Režie"].str.contains("Smoczyńska",na=False)]
# Out:
#                Film                         Země původu  Copyright Rok výroby
# 3874  Útěk (401824)  [Polsko, Česká republika, Švédsko]       2018  2017—2018  \
#
#                                                Premiéra  Minutáž
# 3874  festivalová premiéra 15. 5. 2018  (71. mezinár...    103.0  \
#
#                      Režie Kategorie           Žánr             Typologie
# 3874  Agnieszka Smoczyńska      film  psychologický  [hraný, distribuční]  \
#
#       ... Výrobní skupina Zákazník Vývozní společnost Umělecké vedení
# 3874  ...            None     None               None            None  \
#
#      Zpěv role Překlad české verze Rychlost Přístupnost Začátek výroby
# 3874      None                None     None        None           2017  \
#
#      Konec výroby
# 3874         2018
#
# [1 rows x 132 columns]

# %% [markdown]
# ## Odstranění druhých závorek

# %%
df["Vedoucí produkce"].drop_duplicates().to_list()
# Out:
# [None,
#  'Václav Eisenhamer (3534)',
#  'Jiří Ježek (4473)',
#  'Pavel Šolc (5420)',
#  'Jaromír Lukáš (27426)',
#  'Pavel Nový (4450)',
#  ['Lucie Hertlová (74907)', 'Viktor Mayer (3334)'],
#  ['Daniela Stašková (34813)', 'Zdenka Deitchová (1143)'],
#  'Daniela Stašková (34813)',
#  'Šárka Cimbalová (85990)',
#  'Jana Novosadová (vedoucí natáčení)',
#  'Jaroslav Kučera (vedoucí natáčení)',
#  'Ivan Filus (9671)',
#  'Luboš Tůma (9232)',
#  'Ivana Jaroschy (3246)',
#  'Antonín Suchánek (12599)',
#  'Jindřich Bareš (7470)',
#  'Markéta Hájková (2388)',
#  'Ingrid Klímová (147)',
#  'Michaela Jarošová (1349)',
#  ['Aleš Novák (644)', 'Ivan Nagy (34483)'],
#  'Ľuboslav Žiško (2808)',
#  'Pavla Tomsová (7093)',
#  ['Zdenka Fialová (6996)', 'Vladimír Kořínek (2106)'],
#  'Josef Nepovím (7697)',
#  ['Martin Kořínek (1768)', 'Jo Farr (1769)'],
#  'Jiřina Bílá (6711)',
#  'Adam Polák (2507)',
#  'Radmila Haertová',
#  'Hana Bílá (4013)',
#  'Alexej Guha (658)',
#  'Ivan Nagy (34483)',
#  ['Ľuboslav Žiško (2808)', 'Martin Kopřiva (1338)'],
#  'Aleš Novák (644)',
#  ['Libor Zlomek (3007)', 'Alexej Guha (658)'],
#  ['Milan Kuchynka (4813)', 'Darina Levová (1245)'],
#  'Petr Herák (6827)',
#  ['Martin Kořínek (1768)', 'Jiří Koštýř (5973)'],
#  'Klára Bukovská (1799)',
#  'Prisana Maew Trachai (5284)',
#  'Simona Nováčková (7300)',
#  'Václava Režová (12111)',
#  ['Otakar Svoboda (8666)',
#   'Vojtěch Svoboda (9228)',
#   'Viktor Průša (11155)',
#   'Václav Myslík (9227)'],
#  ['Miroslav Fedor (16517)', 'Aleš Novák (644)'],
#  'Oľga Detaryová (21405)',
#  ['Daria Špačková (6352)', 'Stephanie Wagner (13649)'],
#  'Šárka Dvořáková (2046)',
#  'Ljuba Pašková (89423)',
#  ['Pavel Špaček (1691)', 'Jiří Koštýř (5973)'],
#  ['Martin Hůlovec (7406)', 'Radmila Haertlová (3247)'],
#  'Olga Grossmannová (1625)',
#  ['Jaroslava Halmi (16974)', 'Jiří Koštýř (5973)'],
#  'Filip Čermák (7274)',
#  'Jiří Holan (17138)',
#  ['Jiří Synek (2387)', 'Jiří Koštýř (5973)'],
#  'Vladislava Poláčková (17659)',
#  ['David Kaplan (22880)', 'Jiří Koštýř (5973)'],
#  'Eva Hladíková (12110)',
#  ['Jiří Konečný (1922)', 'Jiří Koštýř (5973)'],
#  ['Věra Ferdová (7278)', 'Jiří Koštýř (5973)'],
#  'Michaela Flenerová (17147)',
#  'Radovan Kramář (25448)',
#  ['Olga Grossmannová (1625)', 'Jiří Koštýř (5973)', 'Zuzana Vrbová (7187)'],
#  'Daniel Růžička (22068)',
#  'Pavel Čechák (3090)',
#  ['Ludvík Mareček (24134)', 'Jiří Koštýř (5973)'],
#  'Ivan Vakaráč (6109)',
#  'Barbora Adamová (2345)',
#  ['Máša Charouzdová (13538)',
#   'Ivana Průšová (712)',
#   'Robert Riedl (713)',
#   'Dagmar Juráková (1250)',
#   'Roman Blaas (18440)'],
#  ['Filip Čermák (7274)', 'Jiří Koštýř (5973)'],
#  ['Štěpánka Kresslová (19095)', 'Jiří Koštýř (5973)', 'Zuzana Vrbová (7187)'],
#  ['Barbora Kinkalová (21237)', 'Jiří Koštýř (5973)'],
#  ['Jana Garajová (9812)', 'Andrea Hradecká (42529)'],
#  'Jiří Koštýř (5973)',
#  ['Šárka Dvořáková (2046)', 'Jiří Koštýř (5973)'],
#  'Jan Krása (2514)',
#  ['Jaroslava Halmiová (34868)', 'Jiří Koštýř (5973)'],
#  ['Pavel Čechák (3090)', 'Jiří Koštýř (5973)'],
#  'Silvia Trizuljaková (10989)',
#  'Pavel Berčík (10606)',
#  'Ilona Jirásková (1648)',
#  ['Vladimíra Lenertová (22004)', 'Iva Dobrovská (27641)'],
#  ['Lenka Čintalanová (2333)', 'Martina Šantavá (6810)'],
#  'Ludvík Mareček (24134)',
#  ['Michał Szczerbic (56911)', 'Jan Strašík (56912)'],
#  'Zuzana Konrádová (11199)',
#  'Věra Ferdová (7278)',
#  ['Helena Machová (3118)', 'Marek Jindra (61286)'],
#  'Igor Chvála (46386)',
#  'Milan Kuchynka (4813)',
#  ['Marta Dudáková (19588)',
#   'Jiří Koštýř (5973)',
#   'Jana Mašíková (1745)',
#   'Helena Machová (3118)'],
#  'Silvia Panáková (57069)',
#  'Lukáš Kaplan (9094)',
#  ['Lubomír Konečný (22829)', 'Lucie Pascu (32919)', 'Erika Hníková (1742)'],
#  ['Zuzana Bieliková (40783)',
#   'Roman Blaas (18440)',
#   'Lucie Zvěřinová (24395)'],
#  'Jana Pilařová (52051)',
#  ['Tereza Horská (3612)', 'Roman Blaas (18440)'],
#  'Pavla Kubečková (35194)',
#  ['Galina Šustová (10886)', 'Robert Riedl (713)'],
#  'Jakub Jíra (5438)',
#  'Lea Hasoňová (76512)',
#  ['Michaela Syslová Kuchynková (9632)', 'Jiří Koštýř (5973)'],
#  'Václav Motl (76572)',
#  'Bára Adamová (2345)',
#  ['Tomáš Voltr (76740)', 'Ivana Buková (6103)'],
#  ['Věra Ferdová (7278)', 'Jana Bebrová (26704)', 'Jiří Koštýř (5973)'],
#  'Ivana Neumanová (81882)',
#  'Jana Střelková (80750)',
#  ['Marta Dudáková (19588)',
#   'Veronika Lerchová (74546)',
#   'Jiří Koštýř (5973)',
#   'Thomas Král (80887)',
#   'Grit Wißkirchen (80906)',
#   'Ralf Kukula (80907)',
#   'Jiří Novák (53206)'],
#  'Matěj Stehlík (12750)',
#  'David Butula (36498)',
#  'Alexander Nardelli (9061)',
#  ['Jana Gospičová (26807)',
#   'Marian Dalkovič (79891)',
#   'Magdaléna Rajtárová (79893)'],
#  ['Jiří Koštýř (5973)', 'Roman Kašparovský (10486)'],
#  'Šárka Střelková (29831)',
#  'Jiří Hauzner (79565)',
#  'Luděk Valchař (21986)',
#  ['Jiří Koštýř (5973)', 'Aleš Týbl (14604)', 'Gregor Novak (84534)'],
#  ['Jiří Hauzner (79565)', 'Jiří Koštýř (5973)'],
#  ['Ctibor Pouba (24273)', 'Jiří Koštýř (5973)'],
#  'Daria Špačková (6352)',
#  'Zdeněk Hala (29088)',
#  ['Roman Blaas (18440)', 'Natalia Guzikiewiczova (85236)'],
#  ['Jakub Sláma (47206)', 'Jiří Koštýř (5973)'],
#  ['Ondřej Šejnoha (9940)', 'Sergiu Támas (84217)'],
#  ['Eliška Sekavová (11783)', 'Bára Příkaská (24653)'],
#  ['Roman Kašparovský (10486)', 'Jiří Koštýř (5973)'],
#  ['Romana Skalická (85811)', 'Michal Milbauer (81788)'],
#  'Roman Blaas (18440)',
#  'Kristina Šedivá (47768)',
#  'Alexandra Burianová (85869)',
#  'Šimon Borecký (84628)',
#  ['Helena Machová (3118)', 'Marek Jindra (61286)', 'Zuzana Janáková (80996)'],
#  'Louise Bellicaud (85087)',
#  ['Jiří Koštýř (5973)', 'Pavel Pavlík (84873)'],
#  'Sylwia Rajdaszka (84888)',
#  ['Lucie Zázvorková (20057)', 'Jiří Koštýř (5973)'],
#  'Tereza Petrásková (86952)',
#  ['Jiří Koštýř (5973)', 'Michaela Flenerová (17147)'],
#  ['Roman Jedlička (851)', 'Jiří Koštýř (5973)'],
#  ['Petr Koza (19211)', 'Lukáš Kaplan (9094)'],
#  ['Tereza Horská (3612)', 'Lenka Neužilová Stárková (24203)'],
#  ['Markéta Hauznerová (K2)',
#   'Dagmar Šperlová (Endorfin)',
#   'Albert Malinovský (Panchart films)',
#   'Jana Vokrouhlíková (ČT)'],
#  'Marie Schillerová',
#  'Zuzana Janáková (80996)',
#  ['Petr Koza (19211)', 'Petr Herák (6827)'],
#  'Petr Šplíchal (83958)',
#  'Tereza Horská (3612)',
#  ['Jana Gospičová (26807)', 'Jiří Koštýř (5973)'],
#  ['Luděk Valchář (21986)', 'Jiří Koštýř (5973)'],
#  ['Jiří Koštýř (5973)',
#   'Šárka Střelková (29831)',
#   'Barbora Chaloupecká (18918)'],
#  'Dagmar Šperlová (75522)',
#  'Zuzana Pavlů (1390)',
#  ['Šárka Střelková (29831)', 'Jiří Koštýř (5973)'],
#  'Eva Jindráková (22199)',
#  'Jana Havelková (28107)',
#  ['Klára Botlíková (28294)', 'Jiří Koštýř (5973)'],
#  'Marek Jindra (61286)',
#  'Václav Mottl (2927)',
#  ['Alžběta Janáčková (124064)', 'Jiří Koštýř (5973)', 'Tomáš Pešula (30563)'],
#  ['Jan Krása (2514)', 'Jindřich Bareš (7470)'],
#  'Kateřina Zavadilová (ČT)',
#  ['Andrea Macková (8286)', 'Tomáš Kotalík (75883)', 'Jiří Košťál (8534)'],
#  'Jana Vokrouhlíková (8895)',
#  'Alexander Nardelli (ČT)',
#  'Petr Morávek (33355)',
#  'Hana Jandová-Svěráková (13493)',
#  'Martina Stránská (vedoucí natáčení)',
#  ['Zuzana Ricotti (72507)', 'Radoslav Bolek (7696)', 'Jiří Koštýř (5973)'],
#  'Martina Knoblochová (35186)',
#  ['Tadeáš Trojánek (35301)', 'Jiří Koštýř (5973)'],
#  'Jaroslava Šajnerová',
#  'Petr Zöld',
#  'Milada Rebcová (2229)',
#  'Kateřina Menclová',
#  ['Radka Mizerová (122042)', 'Jiří Koštýř (5973)'],
#  'Vojtěch Svoboda (9228)',
#  'Alena Markvartová (25070)',
#  'Ivana Aussenbergová',
#  'Filip Brouk (20047)',
#  ['Kristýna Drozdová (65929)', 'Jiří Koštýř (5973)'],
#  ['Filip Brouk (20047)', 'Jiří Koštýř (5973)'],
#  ['Valentino Rudolf', 'Ioana Draghiciová'],
#  ['Jiří Holan', 'Romana Brožková'],
#  ['Klára Žaloudková (54668)',
#   'Marek Jindra (61286)',
#   'Tomáš Šimon (45286)',
#   'Jiří Koštýř (5973)'],
#  ['István Nedeczky',
#   'Gábor Szántó',
#   'Dagmar Šperlová',
#   'Dóra Horváth',
#   'Eszter Gárgyán',
#   'Dóra Szücs',
#   'Friederike Krämer (Německo)'],
#  ['Mikuláš Novotný (47649)',
#   'Background Films (124219)',
#   'Jana Kabátová (3195)'],
#  'Milada Rebcová',
#  'Tereza Keilová (15028)',
#  ['Tereza Keilová (15028)',
#   'Petra Zelinková (528)',
#   'Markéta Sedláčková (128502)'],
#  'Tomáš Šimon (45286)',
#  ['Tomáš Šimon (45286)', 'Marek Jindra (61286)'],
#  ['Kateřina Doležalová (76076)', 'Marek Jindra (61286)', 'Jiří Koštýř (5973)'],
#  'Jana Kabátová (3195)',
#  'Barbora Bernardová (ČT)',
#  'Kamila Hlochová (67226)',
#  'Marta Santovjáková Gerlíková (129919)',
#  ['Eva Jindráková (22199)', 'Eva Šánová (2022)', 'Jiří Koštýř (5973)'],
#  ['Dagmar Šperlová (75522)', 'Zdeněk Hala (29088)'],
#  'Viktor Jedlička (vedoucí natáčení)',
#  ['Aleš Týbl (14604)', 'Jiří Koštýř (5973)', 'Robert Slekovič (75508)'],
#  'Eva Kovářová (28293)',
#  ['Gabriela Duchoňová (82510)', 'Kristýna Drozdová (65929)'],
#  'Michal Hollán (87595)',
#  ['Klára Bukovská (1799)', 'Boris Krištof (3877)'],
#  ['Jakub Pinkava (54651)', 'Jiří Koštýř (5973)', 'Miroslav Sochor (123241)'],
#  'Petr Přikryl (57286)',
#  'Radka Bohuslavová (57349)',
#  'Kateřina Špůrová (46588)',
#  'Kateřina Doležalová (76076)',
#  'Jana Gospičová (26807)',
#  'Anna Tydlitátová (84052)',
#  ['Pavlína Kalandrová (24356)',
#   'Miroslav Novák (19941)',
#   'Jana Vokrouhlíková (8895)'],
#  'Zuzana Frašová',
#  ['Kristýna Květová (1048)',
#   'Marek Jindra (61286)',
#   'Alena Prokopová (30863)',
#   'Renata Vlčková (527)'],
#  'Albert Malinovský (84874)',
#  'Barbora Bernardová',
#  'Jakub Tlapák (7988)',
#  ['Ljuba Pašková (89423)', 'Ivan Nagy (34483)'],
#  'Eva Koukolíčková',
#  'Anna Matisová (RTVS)',
#  'Annamari Ligosztájeva (Maďarsko)',
#  ['Pavel Vácha (24312)', 'Jiří Koštýř (5973)'],
#  'Eduard Prokhasko',
#  'Romana Brožková (9454)',
#  ['Filip Brouk (20047)', 'Ľubomír Slivka (46744)', 'Jiří Koštýř (5973)'],
#  'Petra Zelinková (528)',
#  'Hana Šťastná (vedoucí natáčení)',
#  ['Kryštof Šafer (9567)', 'Štěpánka Holubová (73406)'],
#  'Eva Šánová (2022)',
#  ['Jiří Koštýř (5973)', 'Eva Kovářová (28293)', 'Klára Botlíková (28294)'],
#  'Alžběta Šerclová',
#  'Jiří Husák (ČR)',
#  ['Michal Sikora (105306)', 'Lucie Zvěřinová (24395)'],
#  'Eva Holíková',
#  ['Martina Knoblochová (35186)', 'Kateřina Šafaříková (88066)'],
#  ['Jan Munzar (57365)', 'Klára Petršová (87717)'],
#  ['Jiří Koštýř (5973)', 'Věra Ferdová (7278)'],
#  'Klára Žaloudková (54668)',
#  'Radka Mizerová (122042)',
#  ['Petra Zelinková (528)', 'Barbora Svobodová (2227)'],
#  'Daša Parízková',
#  ['Tomáš Šimon (45286)', 'Marek Jindra (61286)', 'Alena Prokopová (30863)'],
#  ['Eva Pavlíčková (33413)', 'Tomáš Šimon (45286)'],
#  'Bety Suchanová (56711)',
#  'Robert Riedl (713)',
#  'Anna Paděrová (105241)',
#  ['Šárka Střelková (29831)', 'Hynek Svoboda (13044)'],
#  'Kristýna Drozdová (65929)',
#  ['Pavel Vácha (24312)', 'Jiří Koštýř (5973)', 'Petra Švecová (79091)'],
#  ['Martina Štruncová (76092)', 'Jitka Chaloupková (22202)'],
#  'Kateřina Kovářová (88592)',
#  'Lucie Hájková (koncert)',
#  'Jakub Medek (86036)',
#  ['Martin Melichar (5848)',
#   'Lenka Neužil Stárková (24203)',
#   'Ladislav Kožík (13729)'],
#  ['Jiří Husák', 'Mina Holdhus (Norsko)'],
#  ['Jan Strašík (56912)', 'Petr Šplíchal (83958)'],
#  ['Kateřina Špůrová (46588)', 'Petr Šplíchal (83958)', 'Daniel Rouha (6848)'],
#  ['Filip Brouk (20047)', 'Hana Bílá (4013)'],
#  ['Jiří Holan (17138)', 'Jiří Koštýř (5973)'],
#  ['Tereza Keilová (15028)',
#   'Kateřina Doležalová (76076)',
#   'Robert Riedl (713)'],
#  ['Zuzana Jankovičová',
#   'Míša Jeleneková',
#   'Elina Zazerska',
#   'Kristele Pudāne',
#   'Zoltán Pálmai',
#   'Péter Fűlőp',
#   'Genovéva Petrovits'],
#  ['Tomáš Šimon (45286)', 'Petr Horák (26388)'],
#  'Patrik Stanko (65367)',
#  'Kir Laustsen',
#  ['Ilze Pelnēna (Studio Vertov)', 'Galina Stěpanova (Studio Vertov)'],
#  ['Madara Kalnina', 'Zane Štrobindere (vedoucí natáčení)'],
#  'Katarína Stankayová (RTVS)',
#  ['Agnieszka Janowska (85402)', 'Paweł Kosuń (85420)'],
#  'Shay Tova Govhary Saldis (Izrael)',
#  'Tatiana Vallová (127596)',
#  ['Kateřina Doležalová (76076)', 'Jiří Koštýř (5973)'],
#  'Petra Kupková (105160)',
#  ['Jiří Hauzner (79565)', 'Tomáš Chlost (47114)'],
#  'Pavlína Bartoňová (1233)',
#  ['Tomáš Šimon (45286)', 'Zuzana Hadravová (116477)'],
#  'Michaela Imramovská (124112)',
#  'Jakub Pinkava (54651)',
#  'Veronika Havelková (121959)',
#  ['Kristýna Drozdová (65929)', 'Veronika Havelková (121959)'],
#  ['Zuzana Zmítková (77910)', 'Jiří Koštýř (5973)', 'Jakub Medek (86036)'],
#  ['Jan Hartl (57435)', 'Jiří Koštýř (5973)'],
#  ['Petr Šplíchal (83958)', 'Dana Voláková (27749)'],
#  'Barbora Červenková (12273)',
#  'Otakáro Maria Schmidt (1578)',
#  ['Lucie Kadeřávková (69426)', 'Jiří Koštýř (5973)'],
#  'Elena Chvojková',
#  ['Mirka Grimaldi (13150)', 'Josefína Borecká (85233)', 'Jiří Koštýř (5973)'],
#  'Jan Šimek (ČT)',
#  ['Ivan Nagy (34483)', 'Denis Kučera (78386)'],
#  ['Roman Jedlička (851)', 'Petr Šplíchal (83958)', 'Dana Voláková (27749)'],
#  ['Martin Vansa', 'Mirek Vymětal (vedoucí natáčení)'],
#  'Martina Stránská (54667)',
#  ['Michal Sikora (105306)', 'Zdeněk Hala (29088)'],
#  ['Renata Vlčková (527)', 'Tomáš Šimon (45286)', 'Marek Jindra (61286)'],
#  'Jana Balážiová',
#  ['Konstantin Georgiev (Agitprop)',
#   'Katarzyna Drapała (Silver Frame)',
#   'Katarína Stankayová (RTVS)'],
#  'Arťom Naďjožin',
#  ['Zuzana Kučerová (84049)', 'Zdeněk Hala (29088)'],
#  ['Eva Pavlíčková (33413)', 'Zdeněk Hala (29088)'],
#  'Zuzana Zmítková (77910)',
#  'Marta Hostinská (9988)',
#  'Hana Hendrychová (63371)',
#  ['Barbora Svobodová (2227)', 'Petra Zelinková (528)'],
#  ['Poto Balbontin (La Claqueta)',
#   'Lolo Díaz (La Claqueta)',
#   'Fidel Pérez (La Claqueta)',
#   'Barbora Dlabajová (Evolution Films)'],
#  'Primož Ledinek',
#  ['Jure Spivalo',
#   'Neigeme Glasgow-Maeda (Wady Films)',
#   'Michaela Majer (slovenská verze)'],
#  ['Klára Žaloudková (54668)', 'Jiří Koštýř (5973)', 'Nicole Brlej (85250)'],
#  ['Martina Havelková Kraslová', 'Kateřina Kráčmerová (vedoucí natáčení)'],
#  ['Dominika Fáberová (vedoucí natáčení)',
#   'Roman Genský (vedoucí výrobního štábu RTVS)'],
#  'Tibor Horváth (66846)',
#  ['Václav Mottl (2927)', 'Pavel Voráček (88187)'],
#  ['Peter Krátky (81137)', 'Jiří Koštýř (5973)'],
#  ['Eva Pavlíčková (33413)', 'Jakub Pinkava (54651)'],
#  ['Zdeněk Hala (29088)', 'Tomáš Šimon (45286)', 'Marek Jindra (61286)'],
#  ['František Michálek (129961)', 'Jiří Koštýř (5973)'],
#  ['Lukáš Jíra (moloko film)',
#   'Daniel Hampel (moloko film)',
#   'Barbora Bernardová (ČT)'],
#  'Roman Jedlička (851)',
#  'Petra Dobešová (Pink)',
#  ['Jan Unger (2072)', 'Jiří Koštýř (5973)'],
#  ['Zuzana Zmítková (77910)', 'Hana Bílá (4013)'],
#  ['Albert Malinovský (84874)', 'Ján Jurga (79892)'],
#  ['Lubomír Budín (ČT)', 'Jelena Kudel (koordinátorka výroby ČT)'],
#  ['Filip Brouk (20047)', 'Šárka Střelková (29831)'],
#  ['Kateřina Špůrová (46588)', 'Jiří Koštýř (5973)', 'Roman Jordan (104997)'],
#  'Pavel Vácha (24312)',
#  'Soňa Mrázová',
#  'Diana Bobčíková',
#  ['Filip Brouk (20047)', 'Hana Přidalová (21598)'],
#  ['Martina Stránská (54667)', 'Jiří Koštýř (5973)'],
#  ['František Michálek (129961)',
#   'Petra Fabíková (6401)',
#   'Jiří Koštýř (5973)'],
#  'Denis Kučera (78386)',
#  ['Aleš Týbl (14604)', 'Robert Slekovič (75508)'],
#  'Juliette Cazanave (Petit à Petit Production)',
#  ['Markéta Císařová (29186)', 'Barbora Svobodová (2227)'],
#  ['Sascha Beier (Saxonia Entertainment)', 'Magda Tučková (ČT)'],
#  'Jakub Vacík',
#  'Jindřich Keil',
#  'Tomáš Macháček (vedoucí natáčení)',
#  'Milan Cyroň (56268)',
#  ['Vinciane Strepenne',
#   'Marcela Vrátilová',
#   'Sabine Kraft',
#   'Karsten Matern',
#   'André Naumann',
#   'Nicole Zscherny',
#   'Barbara Bernini (Doghouse Films)',
#   'Georg Aschauer (vývoj Neuer Österreichischer Trickfilm)'],
#  ['Pavel Vácha (24312)', 'Eva Pavlíčková (33413)', 'Jiří Koštýř (5973)'],
#  'Václav Prouza',
#  ['Šárka Oujezdská (2046)', 'Radka Bohuslavová (57349)'],
#  'Leona Hájková (5370)',
#  'Petra Milotová',
#  'Marcela Hladká',
#  'Kristýna Kamenická',
#  ['Anna Poláčková (118220)', 'Kateřina Kovářová (88592)'],
#  'Barbora Svobodová (2227)',
#  'Johana Vejvodová (ČT)',
#  ['Filip Brouk (20047)', 'Magdalena Sládková (77985)', 'Jiří Koštýř (5973)'],
#  ['Zdeněk Hala (29088)', 'Alena Prokopová (30863)'],
#  ['Markéta Bruknerová (73110)', 'Jiří Koštýř (5973)'],
#  ['Zdeněk Meduna (35834)', 'Hana Bílá (4013)'],
#  'Veronika Finková (7516)',
#  ['Markéta Janečková (vedoucí natáčení)', 'Lucie Jánová (vedoucí natáčení)'],
#  'Jan Unger (2072)',
#  'Pavla Prunerová (Bedna Films)',
#  ['Filip Brouk (20047)', 'Jiří Koštýř (5973)', 'Ondřej Zach (10828)'],
#  ['Josefína Borecká (85233)',
#   'Mirka Grimaldi (13150)',
#   'Vanessa Biermannová (56286)',
#   'Jiří Koštýř (5973)'],
#  'Dominika Zelinková (vedoucí natáčení)',
#  ['Zuzana Zmítková (77910)', 'Jakub Medek (86036)'],
#  'Katarína Múčková (vedoucí výrobního štábu RTVS)',
#  'Eva Greplová',
#  ['Viktor Krištof (55232)', 'Miroslav Vymětal (35614)'],
#  'Tereza Podlipná (ČT)',
#  'Barbora Zelenková (74766)',
#  ['Janek Paľovský (38608)', 'Vilém Postránecký (52826)'],
#  ['Martin Janoušek (10866)', 'Zdeněk Hala (29088)'],
#  'Peter Baran (PubRes)',
#  'Alena Ponková (33773)',
#  'Renata Vlčková (527)',
#  ['Miroslav Vymětal (35614)',
#   'Barbora Kinkalová (21237)',
#   'Petr Koza (19211)',
#   'Jiří Koštýř (5973)',
#   'Lenka Čížková (80286)'],
#  'Radomír Šofr (23447)',
#  'Ján Jurga (79892)',
#  ['Lucie Klímek (69426)', 'Filip Brouk (20047)'],
#  ['Robert Zapletal (2001)', 'Jiří Koštýř (5973)'],
#  ['Roman Jedlička (851)',
#   'Zuzana Ricotti (72507)',
#   'Jakub Medek (86036)',
#   'Pavel Mráz (46762)',
#   'Jiří Koštýř (5973)',
#   'Tatiana Vallová (127596)'],
#  ['Zuzana Zmítková (77910)', 'Šárka Střelková (29831)', 'Jiří Koštýř (5973)'],
#  'Robert Slekovič (75508)',
#  ['Eva Kameníková (80747)', 'Jiří Koštýř (5973)'],
#  ['Veronika Finková (7516)', 'Jiří Koštýř (5973)'],
#  ['Simona Kadrnková (8189)',
#   'Jiří Koštýř (5973)',
#   'Martina Svobodová (81630)'],
#  'Jan Rolínek (ČT)',
#  'Michal Sikora (105306)',
#  ['Šárka Střelková (29831)',
#   'Zuzana Zmítková (77910)',
#   'Jiří Koštýř (5973)',
#   'Roman Jordan (104997)'],
#  ['Kamila Hlochová (67226)', 'Jiří Koštýř (5973)']]

# %%
def odzavorkuj(bunka):
    
    def odzav(x):
        return re.sub("\([^\d]*\)","", x)
    
    if isinstance(bunka, list):
        try:
            cista_bunka = [odzav(x).strip() for x in bunka]
        except:
            cista_bunka = bunka
            
    if isinstance(bunka, str):
        cista_bunka = odzav(bunka).strip()
        
    else:
        cista_bunka = bunka
        
    return cista_bunka

# %%
for p in profese:
    df[p] = df[p].apply(lambda x: odzavorkuj(x))

# %%
df["Vedoucí produkce"].drop_duplicates().to_list()
# Out:
# [None,
#  'Václav Eisenhamer (3534)',
#  'Jiří Ježek (4473)',
#  'Pavel Šolc (5420)',
#  'Jaromír Lukáš (27426)',
#  'Pavel Nový (4450)',
#  ['Lucie Hertlová (74907)', 'Viktor Mayer (3334)'],
#  ['Daniela Stašková (34813)', 'Zdenka Deitchová (1143)'],
#  'Daniela Stašková (34813)',
#  'Šárka Cimbalová (85990)',
#  'Jana Novosadová',
#  'Jaroslav Kučera',
#  'Ivan Filus (9671)',
#  'Luboš Tůma (9232)',
#  'Ivana Jaroschy (3246)',
#  'Antonín Suchánek (12599)',
#  'Jindřich Bareš (7470)',
#  'Markéta Hájková (2388)',
#  'Ingrid Klímová (147)',
#  'Michaela Jarošová (1349)',
#  ['Aleš Novák (644)', 'Ivan Nagy (34483)'],
#  'Ľuboslav Žiško (2808)',
#  'Pavla Tomsová (7093)',
#  ['Zdenka Fialová (6996)', 'Vladimír Kořínek (2106)'],
#  'Josef Nepovím (7697)',
#  ['Martin Kořínek (1768)', 'Jo Farr (1769)'],
#  'Jiřina Bílá (6711)',
#  'Adam Polák (2507)',
#  'Radmila Haertová',
#  'Hana Bílá (4013)',
#  'Alexej Guha (658)',
#  'Ivan Nagy (34483)',
#  ['Ľuboslav Žiško (2808)', 'Martin Kopřiva (1338)'],
#  'Aleš Novák (644)',
#  ['Libor Zlomek (3007)', 'Alexej Guha (658)'],
#  ['Milan Kuchynka (4813)', 'Darina Levová (1245)'],
#  'Petr Herák (6827)',
#  ['Martin Kořínek (1768)', 'Jiří Koštýř (5973)'],
#  'Klára Bukovská (1799)',
#  'Prisana Maew Trachai (5284)',
#  'Simona Nováčková (7300)',
#  'Václava Režová (12111)',
#  ['Otakar Svoboda (8666)',
#   'Vojtěch Svoboda (9228)',
#   'Viktor Průša (11155)',
#   'Václav Myslík (9227)'],
#  ['Miroslav Fedor (16517)', 'Aleš Novák (644)'],
#  'Oľga Detaryová (21405)',
#  ['Daria Špačková (6352)', 'Stephanie Wagner (13649)'],
#  'Šárka Dvořáková (2046)',
#  'Ljuba Pašková (89423)',
#  ['Pavel Špaček (1691)', 'Jiří Koštýř (5973)'],
#  ['Martin Hůlovec (7406)', 'Radmila Haertlová (3247)'],
#  'Olga Grossmannová (1625)',
#  ['Jaroslava Halmi (16974)', 'Jiří Koštýř (5973)'],
#  'Filip Čermák (7274)',
#  'Jiří Holan (17138)',
#  ['Jiří Synek (2387)', 'Jiří Koštýř (5973)'],
#  'Vladislava Poláčková (17659)',
#  ['David Kaplan (22880)', 'Jiří Koštýř (5973)'],
#  'Eva Hladíková (12110)',
#  ['Jiří Konečný (1922)', 'Jiří Koštýř (5973)'],
#  ['Věra Ferdová (7278)', 'Jiří Koštýř (5973)'],
#  'Michaela Flenerová (17147)',
#  'Radovan Kramář (25448)',
#  ['Olga Grossmannová (1625)', 'Jiří Koštýř (5973)', 'Zuzana Vrbová (7187)'],
#  'Daniel Růžička (22068)',
#  'Pavel Čechák (3090)',
#  ['Ludvík Mareček (24134)', 'Jiří Koštýř (5973)'],
#  'Ivan Vakaráč (6109)',
#  'Barbora Adamová (2345)',
#  ['Máša Charouzdová (13538)',
#   'Ivana Průšová (712)',
#   'Robert Riedl (713)',
#   'Dagmar Juráková (1250)',
#   'Roman Blaas (18440)'],
#  ['Filip Čermák (7274)', 'Jiří Koštýř (5973)'],
#  ['Štěpánka Kresslová (19095)', 'Jiří Koštýř (5973)', 'Zuzana Vrbová (7187)'],
#  ['Barbora Kinkalová (21237)', 'Jiří Koštýř (5973)'],
#  ['Jana Garajová (9812)', 'Andrea Hradecká (42529)'],
#  'Jiří Koštýř (5973)',
#  ['Šárka Dvořáková (2046)', 'Jiří Koštýř (5973)'],
#  'Jan Krása (2514)',
#  ['Jaroslava Halmiová (34868)', 'Jiří Koštýř (5973)'],
#  ['Pavel Čechák (3090)', 'Jiří Koštýř (5973)'],
#  'Silvia Trizuljaková (10989)',
#  'Pavel Berčík (10606)',
#  'Ilona Jirásková (1648)',
#  ['Vladimíra Lenertová (22004)', 'Iva Dobrovská (27641)'],
#  ['Lenka Čintalanová (2333)', 'Martina Šantavá (6810)'],
#  'Ludvík Mareček (24134)',
#  ['Michał Szczerbic (56911)', 'Jan Strašík (56912)'],
#  'Zuzana Konrádová (11199)',
#  'Věra Ferdová (7278)',
#  ['Helena Machová (3118)', 'Marek Jindra (61286)'],
#  'Igor Chvála (46386)',
#  'Milan Kuchynka (4813)',
#  ['Marta Dudáková (19588)',
#   'Jiří Koštýř (5973)',
#   'Jana Mašíková (1745)',
#   'Helena Machová (3118)'],
#  'Silvia Panáková (57069)',
#  'Lukáš Kaplan (9094)',
#  ['Lubomír Konečný (22829)', 'Lucie Pascu (32919)', 'Erika Hníková (1742)'],
#  ['Zuzana Bieliková (40783)',
#   'Roman Blaas (18440)',
#   'Lucie Zvěřinová (24395)'],
#  'Jana Pilařová (52051)',
#  ['Tereza Horská (3612)', 'Roman Blaas (18440)'],
#  'Pavla Kubečková (35194)',
#  ['Galina Šustová (10886)', 'Robert Riedl (713)'],
#  'Jakub Jíra (5438)',
#  'Lea Hasoňová (76512)',
#  ['Michaela Syslová Kuchynková (9632)', 'Jiří Koštýř (5973)'],
#  'Václav Motl (76572)',
#  'Bára Adamová (2345)',
#  ['Tomáš Voltr (76740)', 'Ivana Buková (6103)'],
#  ['Věra Ferdová (7278)', 'Jana Bebrová (26704)', 'Jiří Koštýř (5973)'],
#  'Ivana Neumanová (81882)',
#  'Jana Střelková (80750)',
#  ['Marta Dudáková (19588)',
#   'Veronika Lerchová (74546)',
#   'Jiří Koštýř (5973)',
#   'Thomas Král (80887)',
#   'Grit Wißkirchen (80906)',
#   'Ralf Kukula (80907)',
#   'Jiří Novák (53206)'],
#  'Matěj Stehlík (12750)',
#  'David Butula (36498)',
#  'Alexander Nardelli (9061)',
#  ['Jana Gospičová (26807)',
#   'Marian Dalkovič (79891)',
#   'Magdaléna Rajtárová (79893)'],
#  ['Jiří Koštýř (5973)', 'Roman Kašparovský (10486)'],
#  'Šárka Střelková (29831)',
#  'Jiří Hauzner (79565)',
#  'Luděk Valchař (21986)',
#  ['Jiří Koštýř (5973)', 'Aleš Týbl (14604)', 'Gregor Novak (84534)'],
#  ['Jiří Hauzner (79565)', 'Jiří Koštýř (5973)'],
#  ['Ctibor Pouba (24273)', 'Jiří Koštýř (5973)'],
#  'Daria Špačková (6352)',
#  'Zdeněk Hala (29088)',
#  ['Roman Blaas (18440)', 'Natalia Guzikiewiczova (85236)'],
#  ['Jakub Sláma (47206)', 'Jiří Koštýř (5973)'],
#  ['Ondřej Šejnoha (9940)', 'Sergiu Támas (84217)'],
#  ['Eliška Sekavová (11783)', 'Bára Příkaská (24653)'],
#  ['Roman Kašparovský (10486)', 'Jiří Koštýř (5973)'],
#  ['Romana Skalická (85811)', 'Michal Milbauer (81788)'],
#  'Roman Blaas (18440)',
#  'Kristina Šedivá (47768)',
#  'Alexandra Burianová (85869)',
#  'Šimon Borecký (84628)',
#  ['Helena Machová (3118)', 'Marek Jindra (61286)', 'Zuzana Janáková (80996)'],
#  'Louise Bellicaud (85087)',
#  ['Jiří Koštýř (5973)', 'Pavel Pavlík (84873)'],
#  'Sylwia Rajdaszka (84888)',
#  ['Lucie Zázvorková (20057)', 'Jiří Koštýř (5973)'],
#  'Tereza Petrásková (86952)',
#  ['Jiří Koštýř (5973)', 'Michaela Flenerová (17147)'],
#  ['Roman Jedlička (851)', 'Jiří Koštýř (5973)'],
#  ['Petr Koza (19211)', 'Lukáš Kaplan (9094)'],
#  ['Tereza Horská (3612)', 'Lenka Neužilová Stárková (24203)'],
#  ['Markéta Hauznerová (K2)',
#   'Dagmar Šperlová (Endorfin)',
#   'Albert Malinovský (Panchart films)',
#   'Jana Vokrouhlíková (ČT)'],
#  'Marie Schillerová',
#  'Zuzana Janáková (80996)',
#  ['Petr Koza (19211)', 'Petr Herák (6827)'],
#  'Petr Šplíchal (83958)',
#  'Tereza Horská (3612)',
#  ['Jana Gospičová (26807)', 'Jiří Koštýř (5973)'],
#  ['Luděk Valchář (21986)', 'Jiří Koštýř (5973)'],
#  ['Jiří Koštýř (5973)',
#   'Šárka Střelková (29831)',
#   'Barbora Chaloupecká (18918)'],
#  'Dagmar Šperlová (75522)',
#  'Zuzana Pavlů (1390)',
#  ['Šárka Střelková (29831)', 'Jiří Koštýř (5973)'],
#  'Eva Jindráková (22199)',
#  'Jana Havelková (28107)',
#  ['Klára Botlíková (28294)', 'Jiří Koštýř (5973)'],
#  'Marek Jindra (61286)',
#  'Václav Mottl (2927)',
#  ['Alžběta Janáčková (124064)', 'Jiří Koštýř (5973)', 'Tomáš Pešula (30563)'],
#  ['Jan Krása (2514)', 'Jindřich Bareš (7470)'],
#  'Kateřina Zavadilová',
#  ['Andrea Macková (8286)', 'Tomáš Kotalík (75883)', 'Jiří Košťál (8534)'],
#  'Jana Vokrouhlíková (8895)',
#  'Alexander Nardelli',
#  'Petr Morávek (33355)',
#  'Hana Jandová-Svěráková (13493)',
#  'Martina Stránská',
#  ['Zuzana Ricotti (72507)', 'Radoslav Bolek (7696)', 'Jiří Koštýř (5973)'],
#  'Martina Knoblochová (35186)',
#  ['Tadeáš Trojánek (35301)', 'Jiří Koštýř (5973)'],
#  'Jaroslava Šajnerová',
#  'Petr Zöld',
#  'Milada Rebcová (2229)',
#  'Kateřina Menclová',
#  ['Radka Mizerová (122042)', 'Jiří Koštýř (5973)'],
#  'Vojtěch Svoboda (9228)',
#  'Alena Markvartová (25070)',
#  'Ivana Aussenbergová',
#  'Filip Brouk (20047)',
#  ['Kristýna Drozdová (65929)', 'Jiří Koštýř (5973)'],
#  ['Filip Brouk (20047)', 'Jiří Koštýř (5973)'],
#  ['Valentino Rudolf', 'Ioana Draghiciová'],
#  ['Jiří Holan', 'Romana Brožková'],
#  ['Klára Žaloudková (54668)',
#   'Marek Jindra (61286)',
#   'Tomáš Šimon (45286)',
#   'Jiří Koštýř (5973)'],
#  ['István Nedeczky',
#   'Gábor Szántó',
#   'Dagmar Šperlová',
#   'Dóra Horváth',
#   'Eszter Gárgyán',
#   'Dóra Szücs',
#   'Friederike Krämer (Německo)'],
#  ['Mikuláš Novotný (47649)',
#   'Background Films (124219)',
#   'Jana Kabátová (3195)'],
#  'Milada Rebcová',
#  'Tereza Keilová (15028)',
#  ['Tereza Keilová (15028)',
#   'Petra Zelinková (528)',
#   'Markéta Sedláčková (128502)'],
#  'Tomáš Šimon (45286)',
#  ['Tomáš Šimon (45286)', 'Marek Jindra (61286)'],
#  ['Kateřina Doležalová (76076)', 'Marek Jindra (61286)', 'Jiří Koštýř (5973)'],
#  'Jana Kabátová (3195)',
#  'Barbora Bernardová',
#  'Kamila Hlochová (67226)',
#  'Marta Santovjáková Gerlíková (129919)',
#  ['Eva Jindráková (22199)', 'Eva Šánová (2022)', 'Jiří Koštýř (5973)'],
#  ['Dagmar Šperlová (75522)', 'Zdeněk Hala (29088)'],
#  'Viktor Jedlička',
#  ['Aleš Týbl (14604)', 'Jiří Koštýř (5973)', 'Robert Slekovič (75508)'],
#  'Eva Kovářová (28293)',
#  ['Gabriela Duchoňová (82510)', 'Kristýna Drozdová (65929)'],
#  'Michal Hollán (87595)',
#  ['Klára Bukovská (1799)', 'Boris Krištof (3877)'],
#  ['Jakub Pinkava (54651)', 'Jiří Koštýř (5973)', 'Miroslav Sochor (123241)'],
#  'Petr Přikryl (57286)',
#  'Radka Bohuslavová (57349)',
#  'Kateřina Špůrová (46588)',
#  'Kateřina Doležalová (76076)',
#  'Jana Gospičová (26807)',
#  'Anna Tydlitátová (84052)',
#  ['Pavlína Kalandrová (24356)',
#   'Miroslav Novák (19941)',
#   'Jana Vokrouhlíková (8895)'],
#  'Zuzana Frašová',
#  ['Kristýna Květová (1048)',
#   'Marek Jindra (61286)',
#   'Alena Prokopová (30863)',
#   'Renata Vlčková (527)'],
#  'Albert Malinovský (84874)',
#  'Jakub Tlapák (7988)',
#  ['Ljuba Pašková (89423)', 'Ivan Nagy (34483)'],
#  'Eva Koukolíčková',
#  'Anna Matisová',
#  'Annamari Ligosztájeva',
#  ['Pavel Vácha (24312)', 'Jiří Koštýř (5973)'],
#  'Eduard Prokhasko',
#  'Romana Brožková (9454)',
#  ['Filip Brouk (20047)', 'Ľubomír Slivka (46744)', 'Jiří Koštýř (5973)'],
#  'Petra Zelinková (528)',
#  'Hana Šťastná',
#  ['Kryštof Šafer (9567)', 'Štěpánka Holubová (73406)'],
#  'Eva Šánová (2022)',
#  ['Jiří Koštýř (5973)', 'Eva Kovářová (28293)', 'Klára Botlíková (28294)'],
#  'Alžběta Šerclová',
#  'Jiří Husák',
#  ['Michal Sikora (105306)', 'Lucie Zvěřinová (24395)'],
#  'Eva Holíková',
#  ['Martina Knoblochová (35186)', 'Kateřina Šafaříková (88066)'],
#  ['Jan Munzar (57365)', 'Klára Petršová (87717)'],
#  ['Jiří Koštýř (5973)', 'Věra Ferdová (7278)'],
#  'Klára Žaloudková (54668)',
#  'Radka Mizerová (122042)',
#  ['Petra Zelinková (528)', 'Barbora Svobodová (2227)'],
#  'Daša Parízková',
#  ['Tomáš Šimon (45286)', 'Marek Jindra (61286)', 'Alena Prokopová (30863)'],
#  ['Eva Pavlíčková (33413)', 'Tomáš Šimon (45286)'],
#  'Bety Suchanová (56711)',
#  'Robert Riedl (713)',
#  'Anna Paděrová (105241)',
#  ['Šárka Střelková (29831)', 'Hynek Svoboda (13044)'],
#  'Kristýna Drozdová (65929)',
#  ['Pavel Vácha (24312)', 'Jiří Koštýř (5973)', 'Petra Švecová (79091)'],
#  ['Martina Štruncová (76092)', 'Jitka Chaloupková (22202)'],
#  'Kateřina Kovářová (88592)',
#  'Lucie Hájková',
#  'Jakub Medek (86036)',
#  ['Martin Melichar (5848)',
#   'Lenka Neužil Stárková (24203)',
#   'Ladislav Kožík (13729)'],
#  ['Jiří Husák', 'Mina Holdhus (Norsko)'],
#  ['Jan Strašík (56912)', 'Petr Šplíchal (83958)'],
#  ['Kateřina Špůrová (46588)', 'Petr Šplíchal (83958)', 'Daniel Rouha (6848)'],
#  ['Filip Brouk (20047)', 'Hana Bílá (4013)'],
#  ['Jiří Holan (17138)', 'Jiří Koštýř (5973)'],
#  ['Tereza Keilová (15028)',
#   'Kateřina Doležalová (76076)',
#   'Robert Riedl (713)'],
#  ['Zuzana Jankovičová',
#   'Míša Jeleneková',
#   'Elina Zazerska',
#   'Kristele Pudāne',
#   'Zoltán Pálmai',
#   'Péter Fűlőp',
#   'Genovéva Petrovits'],
#  ['Tomáš Šimon (45286)', 'Petr Horák (26388)'],
#  'Patrik Stanko (65367)',
#  'Kir Laustsen',
#  ['Ilze Pelnēna (Studio Vertov)', 'Galina Stěpanova (Studio Vertov)'],
#  ['Madara Kalnina', 'Zane Štrobindere (vedoucí natáčení)'],
#  'Katarína Stankayová',
#  ['Agnieszka Janowska (85402)', 'Paweł Kosuń (85420)'],
#  'Shay Tova Govhary Saldis',
#  'Tatiana Vallová (127596)',
#  ['Kateřina Doležalová (76076)', 'Jiří Koštýř (5973)'],
#  'Petra Kupková (105160)',
#  ['Jiří Hauzner (79565)', 'Tomáš Chlost (47114)'],
#  'Pavlína Bartoňová (1233)',
#  ['Tomáš Šimon (45286)', 'Zuzana Hadravová (116477)'],
#  'Michaela Imramovská (124112)',
#  'Jakub Pinkava (54651)',
#  'Veronika Havelková (121959)',
#  ['Kristýna Drozdová (65929)', 'Veronika Havelková (121959)'],
#  ['Zuzana Zmítková (77910)', 'Jiří Koštýř (5973)', 'Jakub Medek (86036)'],
#  ['Jan Hartl (57435)', 'Jiří Koštýř (5973)'],
#  ['Petr Šplíchal (83958)', 'Dana Voláková (27749)'],
#  'Barbora Červenková (12273)',
#  'Otakáro Maria Schmidt (1578)',
#  ['Lucie Kadeřávková (69426)', 'Jiří Koštýř (5973)'],
#  'Elena Chvojková',
#  ['Mirka Grimaldi (13150)', 'Josefína Borecká (85233)', 'Jiří Koštýř (5973)'],
#  'Jan Šimek',
#  ['Ivan Nagy (34483)', 'Denis Kučera (78386)'],
#  ['Roman Jedlička (851)', 'Petr Šplíchal (83958)', 'Dana Voláková (27749)'],
#  ['Martin Vansa', 'Mirek Vymětal (vedoucí natáčení)'],
#  'Martina Stránská (54667)',
#  ['Michal Sikora (105306)', 'Zdeněk Hala (29088)'],
#  ['Renata Vlčková (527)', 'Tomáš Šimon (45286)', 'Marek Jindra (61286)'],
#  'Jana Balážiová',
#  ['Konstantin Georgiev (Agitprop)',
#   'Katarzyna Drapała (Silver Frame)',
#   'Katarína Stankayová (RTVS)'],
#  'Arťom Naďjožin',
#  ['Zuzana Kučerová (84049)', 'Zdeněk Hala (29088)'],
#  ['Eva Pavlíčková (33413)', 'Zdeněk Hala (29088)'],
#  'Zuzana Zmítková (77910)',
#  'Marta Hostinská (9988)',
#  'Hana Hendrychová (63371)',
#  ['Barbora Svobodová (2227)', 'Petra Zelinková (528)'],
#  ['Poto Balbontin (La Claqueta)',
#   'Lolo Díaz (La Claqueta)',
#   'Fidel Pérez (La Claqueta)',
#   'Barbora Dlabajová (Evolution Films)'],
#  'Primož Ledinek',
#  ['Jure Spivalo',
#   'Neigeme Glasgow-Maeda (Wady Films)',
#   'Michaela Majer (slovenská verze)'],
#  ['Klára Žaloudková (54668)', 'Jiří Koštýř (5973)', 'Nicole Brlej (85250)'],
#  ['Martina Havelková Kraslová', 'Kateřina Kráčmerová (vedoucí natáčení)'],
#  ['Dominika Fáberová (vedoucí natáčení)',
#   'Roman Genský (vedoucí výrobního štábu RTVS)'],
#  'Tibor Horváth (66846)',
#  ['Václav Mottl (2927)', 'Pavel Voráček (88187)'],
#  ['Peter Krátky (81137)', 'Jiří Koštýř (5973)'],
#  ['Eva Pavlíčková (33413)', 'Jakub Pinkava (54651)'],
#  ['Zdeněk Hala (29088)', 'Tomáš Šimon (45286)', 'Marek Jindra (61286)'],
#  ['František Michálek (129961)', 'Jiří Koštýř (5973)'],
#  ['Lukáš Jíra (moloko film)',
#   'Daniel Hampel (moloko film)',
#   'Barbora Bernardová (ČT)'],
#  'Roman Jedlička (851)',
#  'Petra Dobešová',
#  ['Jan Unger (2072)', 'Jiří Koštýř (5973)'],
#  ['Zuzana Zmítková (77910)', 'Hana Bílá (4013)'],
#  ['Albert Malinovský (84874)', 'Ján Jurga (79892)'],
#  ['Lubomír Budín (ČT)', 'Jelena Kudel (koordinátorka výroby ČT)'],
#  ['Filip Brouk (20047)', 'Šárka Střelková (29831)'],
#  ['Kateřina Špůrová (46588)', 'Jiří Koštýř (5973)', 'Roman Jordan (104997)'],
#  'Pavel Vácha (24312)',
#  'Soňa Mrázová',
#  'Diana Bobčíková',
#  ['Filip Brouk (20047)', 'Hana Přidalová (21598)'],
#  ['Martina Stránská (54667)', 'Jiří Koštýř (5973)'],
#  ['František Michálek (129961)',
#   'Petra Fabíková (6401)',
#   'Jiří Koštýř (5973)'],
#  'Denis Kučera (78386)',
#  ['Aleš Týbl (14604)', 'Robert Slekovič (75508)'],
#  'Juliette Cazanave',
#  ['Markéta Císařová (29186)', 'Barbora Svobodová (2227)'],
#  ['Sascha Beier (Saxonia Entertainment)', 'Magda Tučková (ČT)'],
#  'Jakub Vacík',
#  'Jindřich Keil',
#  'Tomáš Macháček',
#  'Milan Cyroň (56268)',
#  ['Vinciane Strepenne',
#   'Marcela Vrátilová',
#   'Sabine Kraft',
#   'Karsten Matern',
#   'André Naumann',
#   'Nicole Zscherny',
#   'Barbara Bernini (Doghouse Films)',
#   'Georg Aschauer (vývoj Neuer Österreichischer Trickfilm)'],
#  ['Pavel Vácha (24312)', 'Eva Pavlíčková (33413)', 'Jiří Koštýř (5973)'],
#  'Václav Prouza',
#  ['Šárka Oujezdská (2046)', 'Radka Bohuslavová (57349)'],
#  'Leona Hájková (5370)',
#  'Petra Milotová',
#  'Marcela Hladká',
#  'Kristýna Kamenická',
#  ['Anna Poláčková (118220)', 'Kateřina Kovářová (88592)'],
#  'Barbora Svobodová (2227)',
#  'Johana Vejvodová',
#  ['Filip Brouk (20047)', 'Magdalena Sládková (77985)', 'Jiří Koštýř (5973)'],
#  ['Zdeněk Hala (29088)', 'Alena Prokopová (30863)'],
#  ['Markéta Bruknerová (73110)', 'Jiří Koštýř (5973)'],
#  ['Zdeněk Meduna (35834)', 'Hana Bílá (4013)'],
#  'Veronika Finková (7516)',
#  ['Markéta Janečková (vedoucí natáčení)', 'Lucie Jánová (vedoucí natáčení)'],
#  'Jan Unger (2072)',
#  'Pavla Prunerová',
#  ['Filip Brouk (20047)', 'Jiří Koštýř (5973)', 'Ondřej Zach (10828)'],
#  ['Josefína Borecká (85233)',
#   'Mirka Grimaldi (13150)',
#   'Vanessa Biermannová (56286)',
#   'Jiří Koštýř (5973)'],
#  'Dominika Zelinková',
#  ['Zuzana Zmítková (77910)', 'Jakub Medek (86036)'],
#  'Katarína Múčková',
#  'Eva Greplová',
#  ['Viktor Krištof (55232)', 'Miroslav Vymětal (35614)'],
#  'Tereza Podlipná',
#  'Barbora Zelenková (74766)',
#  ['Janek Paľovský (38608)', 'Vilém Postránecký (52826)'],
#  ['Martin Janoušek (10866)', 'Zdeněk Hala (29088)'],
#  'Peter Baran',
#  'Alena Ponková (33773)',
#  'Renata Vlčková (527)',
#  ['Miroslav Vymětal (35614)',
#   'Barbora Kinkalová (21237)',
#   'Petr Koza (19211)',
#   'Jiří Koštýř (5973)',
#   'Lenka Čížková (80286)'],
#  'Radomír Šofr (23447)',
#  'Ján Jurga (79892)',
#  ['Lucie Klímek (69426)', 'Filip Brouk (20047)'],
#  ['Robert Zapletal (2001)', 'Jiří Koštýř (5973)'],
#  ['Roman Jedlička (851)',
#   'Zuzana Ricotti (72507)',
#   'Jakub Medek (86036)',
#   'Pavel Mráz (46762)',
#   'Jiří Koštýř (5973)',
#   'Tatiana Vallová (127596)'],
#  ['Zuzana Zmítková (77910)', 'Šárka Střelková (29831)', 'Jiří Koštýř (5973)'],
#  'Robert Slekovič (75508)',
#  ['Eva Kameníková (80747)', 'Jiří Koštýř (5973)'],
#  ['Veronika Finková (7516)', 'Jiří Koštýř (5973)'],
#  ['Simona Kadrnková (8189)',
#   'Jiří Koštýř (5973)',
#   'Martina Svobodová (81630)'],
#  'Jan Rolínek',
#  'Michal Sikora (105306)',
#  ['Šárka Střelková (29831)',
#   'Zuzana Zmítková (77910)',
#   'Jiří Koštýř (5973)',
#   'Roman Jordan (104997)'],
#  ['Kamila Hlochová (67226)', 'Jiří Koštýř (5973)']]

# %% [markdown]
# ## Kontrola, export

# %%
df
# Out:
#                                                    Film
# 3763   Polední výstřel na Mariánských hradbách (401709)  \
# 3758    Cvičení s kužely Sokolů malostranských (401704)
# 3759                                  Cyklisté (401705)
# 3760  Defilování vojska o Božím těle na Královských ...
# 3761                         Hanácké banderium (401707)
# ...                                                 ...
# 4211                         Mimořádná událost (402176)
# 4208                       Po čem muži touží 2 (402173)
# 4222                              Až zařve lev (402204)
# 4232                             Planeta Praha (402218)
# 4201                               Identita ES (402166)
#
#                                Země původu  Copyright            Rok výroby
# 3763                      Rakousko-Uhersko       1898                  1898  \
# 3758                      Rakousko-Uhersko       1898                  1898
# 3759                      Rakousko-Uhersko       1898                  1898
# 3760                      Rakousko-Uhersko       1898                  1898
# 3761                      Rakousko-Uhersko       1898                  1898
# ...                                    ...        ...                   ...
# 4211                       Česká republika       2022                  2021
# 4208          [Česká republika, Slovensko]       2022                  2021
# 4222                       Česká republika       2022             2020—2021
# 4232          [Česká republika, Slovensko]       2022             2020—2021
# 4201  [Česká republika, Kanada, Slovensko]       2022  2015—2016, 2020—2021
#
#                                                Premiéra  Minutáž
# 3763  premiéra 19. 6. 1898  (Výstava architektury a ...      1.0  \
# 3758  premiéra 24. 7. 1898  (Výstava architektury a ...      1.0
# 3759  premiéra léto 1898  (Výstava architektury a in...      1.0
# 3760  premiéra 19. 6. 1898  (Výstava architektury a ...      1.0
# 3761  premiéra 24. 7. 1898  (Výstava architektury a ...      1.0
# ...                                                 ...      ...
# 4211  slavnostní premiéra 2. 2. 2022  (kino Lucerna,...    102.0
# 4208  slavnostní premiéra 20. 4. 2022  (multiplex Ci...     96.0
# 4222  slavnostní premiéra 5. 4. 2022  (kino Lucerna,...    104.0
# 4232  slavnostní premiéra 2. 8. 2022  (kino Aero, Pr...     89.0
# 4201  slavnostní premiéra 2. 3. 2022  (kino Bio Oko,...     79.0
#
#                         Režie Kategorie                                 Žánr
# 3763  Jan Kříženecký (127419)      film                             reportáž  \
# 3758  Jan Kříženecký (127419)      film                [reportáž, sportovní]
# 3759  Jan Kříženecký (127419)      film                             reportáž
# 3760  Jan Kříženecký (127419)      film                             reportáž
# 3761  Jan Kříženecký (127419)      film                             reportáž
# ...                       ...       ...                                  ...
# 4211     Jiří Havelka (28977)      film  [komedie, satira, bláznivá komedie]
# 4208    Rudolf Havlík (79764)      film               [fantastický, komedie]
# 4222    Jan E. Svatoš (77843)      film      [historický, životopisný, esej]
# 4232         Jan Hošek (5629)      film              [přírodopisný, rodinný]
# 4201   Alena Činčerová (5732)      film                             medailon
#
#                         Typologie  ... Výrobní skupina Zákazník
# 3763  [dokumentární, distribuční]  ...            None     None  \
# 3758  [dokumentární, distribuční]  ...            None     None
# 3759  [dokumentární, distribuční]  ...            None     None
# 3760  [dokumentární, distribuční]  ...            None     None
# 3761  [dokumentární, distribuční]  ...            None     None
# ...                           ...  ...             ...      ...
# 4211         [hraný, distribuční]  ...            None     None
# 4208         [hraný, distribuční]  ...            None     None
# 4222  [dokumentární, distribuční]  ...            None     None
# 4232  [dokumentární, distribuční]  ...            None     None
# 4201  [dokumentární, distribuční]  ...            None     None
#
#      Vývozní společnost Umělecké vedení Zpěv role Překlad české verze
# 3763               None            None      None                None  \
# 3758               None            None      None                None
# 3759               None            None      None                None
# 3760               None            None      None                None
# 3761               None            None      None                None
# ...                 ...             ...       ...                 ...
# 4211               None            None      None                None
# 4208               None            None      None                None
# 4222               None            None      None                None
# 4232               None            None      None                None
# 4201               None            None      None                None
#
#      Rychlost Přístupnost Začátek výroby Konec výroby
# 3763     None        None           1898         1898
# 3758     None        None           1898         1898
# 3759     None        None           1898         1898
# 3760     None        None           1898         1898
# 3761     None        None           1898         1898
# ...       ...         ...            ...          ...
# 4211     None        None           2021         2021
# 4208     None        None           2021         2021
# 4222     None        None           2020         2021
# 4232     None        None           2020         2021
# 4201     None        None           2015         2021
#
# [4511 rows x 132 columns]

# %%
with open(os.path.join("seznamove_sloupce.txt"), "w+", encoding = "utf-8") as s_sloupce:
    s_sloupce.writelines("\n".join(seznamove_sloupce))
    s_sloupce.writelines("\n")
    s_sloupce.writelines("\n".join(seznamove_sloupce_firmy))
    s_sloupce.writelines("\n")
    s_sloupce.writelines("\n".join(jiz_seznam))

# %%
with open(os.path.join("dlouhometrazni.txt"), "w+", encoding = "utf-8") as dlouhometrazni:
    dlouhometrazni.writelines("\n".join(df[df["Délka"] == "dlouhometrážní"]["Film"].drop_duplicates().to_list()))

# %%
", ".join(df.columns.to_list())
# Out:
# 'Film, Země původu, Copyright, Rok výroby, Premiéra, Minutáž, Režie, Kategorie, Žánr, Typologie, Originální název, Český název, Anglický název, Souběžný název, Pracovní název, Hrají, Postavy, Pomocná režie, Asistent režie, Původní filmový námět, Scénář, Dramaturg, Kamera, Asistent kamery, Architekt, Návrhy kostýmů, Masky, Střih, Zvuk, Producent, Vedoucí výroby, Zástupce vedoucího výroby, Odborný poradce, Hudba, Choreografie, Lokace, Distribuční slogan, Výrobce, S podporou, Nositelé copyrightu, Distribuce, Délka, Distribuční nosič, Poměr stran, Barva, Zvukový, Zvukový systém/formát, Verze, Mluveno, Podtitulky, Úvodní/závěrečné titulky, Anotace, Obsah, Technický scénář, Výtvarník, Animace, Triky, Postprodukce, Návrhy titulků, Pedagogické vedení, Použitá hudba, Studentský film, Původní metráž, Mezititulky, Ocenění, Poznámka, Mluví, Vizuální efekty, Vedoucí produkce, Předloha, Kaskadéři, Text písně, Zpívá, pásmo, Části, Produkce, Výtvarná spolupráce, Nahrál, Partner, Animační technika, Výprava, Spolupráce, Komentář, Autor komentáře, Druhá kamera, Zvláštní efekty, Koproducent, Výběr hudby, Hudební dramaturgie, Písně, Produkční data, Koordinátor kaskadérů, Výkonná produkce, Zástupce vedoucího produkce, Hudební režie, Účinkují, Dirigent, Ateliéry, Režie české verze, Výrobce české verze, Tančí, České podtitulky, Výrobce českých podtitulků, Asistent vedoucího produkce, Natáčecí formát, Dialogy české verze, Autor projektu, Stav filmu, Souběžný anglický název, Assistent architekta, Asistent zvuku, Podnázev, Asistent vedoucího výroby, Skript, Kostýmy, Asistent střihu, povídkový film, Povídky, Hudba k písni, Prodej práv, Podnázev anglický, Výtvarník pozadí, Výrobní skupina, Zákazník, Vývozní společnost, Umělecké vedení, Zpěv role, Překlad české verze, Rychlost, Přístupnost, Začátek výroby, Konec výroby'

# %%
df
# Out:
#                                                    Film
# 3763   Polední výstřel na Mariánských hradbách (401709)  \
# 3758    Cvičení s kužely Sokolů malostranských (401704)
# 3759                                  Cyklisté (401705)
# 3760  Defilování vojska o Božím těle na Královských ...
# 3761                         Hanácké banderium (401707)
# ...                                                 ...
# 4211                         Mimořádná událost (402176)
# 4208                       Po čem muži touží 2 (402173)
# 4222                              Až zařve lev (402204)
# 4232                             Planeta Praha (402218)
# 4201                               Identita ES (402166)
#
#                                Země původu  Copyright            Rok výroby
# 3763                      Rakousko-Uhersko       1898                  1898  \
# 3758                      Rakousko-Uhersko       1898                  1898
# 3759                      Rakousko-Uhersko       1898                  1898
# 3760                      Rakousko-Uhersko       1898                  1898
# 3761                      Rakousko-Uhersko       1898                  1898
# ...                                    ...        ...                   ...
# 4211                       Česká republika       2022                  2021
# 4208          [Česká republika, Slovensko]       2022                  2021
# 4222                       Česká republika       2022             2020—2021
# 4232          [Česká republika, Slovensko]       2022             2020—2021
# 4201  [Česká republika, Kanada, Slovensko]       2022  2015—2016, 2020—2021
#
#                                                Premiéra  Minutáž
# 3763  premiéra 19. 6. 1898  (Výstava architektury a ...      1.0  \
# 3758  premiéra 24. 7. 1898  (Výstava architektury a ...      1.0
# 3759  premiéra léto 1898  (Výstava architektury a in...      1.0
# 3760  premiéra 19. 6. 1898  (Výstava architektury a ...      1.0
# 3761  premiéra 24. 7. 1898  (Výstava architektury a ...      1.0
# ...                                                 ...      ...
# 4211  slavnostní premiéra 2. 2. 2022  (kino Lucerna,...    102.0
# 4208  slavnostní premiéra 20. 4. 2022  (multiplex Ci...     96.0
# 4222  slavnostní premiéra 5. 4. 2022  (kino Lucerna,...    104.0
# 4232  slavnostní premiéra 2. 8. 2022  (kino Aero, Pr...     89.0
# 4201  slavnostní premiéra 2. 3. 2022  (kino Bio Oko,...     79.0
#
#                         Režie Kategorie                                 Žánr
# 3763  Jan Kříženecký (127419)      film                             reportáž  \
# 3758  Jan Kříženecký (127419)      film                [reportáž, sportovní]
# 3759  Jan Kříženecký (127419)      film                             reportáž
# 3760  Jan Kříženecký (127419)      film                             reportáž
# 3761  Jan Kříženecký (127419)      film                             reportáž
# ...                       ...       ...                                  ...
# 4211     Jiří Havelka (28977)      film  [komedie, satira, bláznivá komedie]
# 4208    Rudolf Havlík (79764)      film               [fantastický, komedie]
# 4222    Jan E. Svatoš (77843)      film      [historický, životopisný, esej]
# 4232         Jan Hošek (5629)      film              [přírodopisný, rodinný]
# 4201   Alena Činčerová (5732)      film                             medailon
#
#                         Typologie  ... Výrobní skupina Zákazník
# 3763  [dokumentární, distribuční]  ...            None     None  \
# 3758  [dokumentární, distribuční]  ...            None     None
# 3759  [dokumentární, distribuční]  ...            None     None
# 3760  [dokumentární, distribuční]  ...            None     None
# 3761  [dokumentární, distribuční]  ...            None     None
# ...                           ...  ...             ...      ...
# 4211         [hraný, distribuční]  ...            None     None
# 4208         [hraný, distribuční]  ...            None     None
# 4222  [dokumentární, distribuční]  ...            None     None
# 4232  [dokumentární, distribuční]  ...            None     None
# 4201  [dokumentární, distribuční]  ...            None     None
#
#      Vývozní společnost Umělecké vedení Zpěv role Překlad české verze
# 3763               None            None      None                None  \
# 3758               None            None      None                None
# 3759               None            None      None                None
# 3760               None            None      None                None
# 3761               None            None      None                None
# ...                 ...             ...       ...                 ...
# 4211               None            None      None                None
# 4208               None            None      None                None
# 4222               None            None      None                None
# 4232               None            None      None                None
# 4201               None            None      None                None
#
#      Rychlost Přístupnost Začátek výroby Konec výroby
# 3763     None        None           1898         1898
# 3758     None        None           1898         1898
# 3759     None        None           1898         1898
# 3760     None        None           1898         1898
# 3761     None        None           1898         1898
# ...       ...         ...            ...          ...
# 4211     None        None           2021         2021
# 4208     None        None           2021         2021
# 4222     None        None           2020         2021
# 4232     None        None           2020         2021
# 4201     None        None           2015         2021
#
# [4511 rows x 132 columns]

# %%
df.to_json(os.path.join("data", "filmy.json"), orient="records")

# %%
import zipfile
try:
    import zlib
    mode= zipfile.ZIP_DEFLATED
except:
    mode= zipfile.ZIP_STORED

# %%
with zipfile.ZipFile(os.path.join("data", "filmy.zip"), mode="w") as my_zip:
    my_zip.write(os.path.join("data", "filmy.json"), compress_type=zipfile.ZIP_DEFLATED)
