# %%
import pandas as pd

# %%
herectvo = pd.read_json("herectvo.json")

# %%
herectvo = herectvo.explode("Role")
herectvo = herectvo.explode("Úloha")

# %%
herectvo = herectvo[herectvo["Úloha"] == "Hrají"]

# %%
", ".join(herectvo.groupby("Jméno")["Film"].nunique().nlargest(1000).index.to_list())
# Out:
# 'Jan W. Speerger (55928), Theodor Pištěk (37366), Eman Fiala (64088), Jaroslav Marvan (9550), František Filipovský (4735), Alois Dvorský (127491), Oldřich Velen (12725), Milka Balek-Brodská (28799), Josef Kemr (4897), Jaroslav Tomsa (2576), Václav Trégl (35224), Vladimír Hlavatý (34999), Josef Hlinomaz (26212), Karel Hovorka (76534), Jiří Lír (4926), Vladimír Řepa (127334), Vladimír Menšík (126036), František Kreuzmann (75624), Karel Augusta (5058), Vladimír Navrátil (12670), Lubomír Kostelka (841), Bohuš Záhorský (53346), Mirko Musil (33555), Jindřich Plachta (5829), Ota Motyčka (81341), Rudolf Hrušínský st. (4842), Josef Somr (1054), Vlastimil Brodský (833), Jiřina Bílá (3629), Miloš Kopecký (4959), Jan Kuželka (1445), Václav Kotva (2718), Hermína Vojtová (127041), Ella Nollová (127319), Jaroslav Vojta (77195), Zdeněk Srstka (7960), Jan Skopeček (8252), F. X. Mlejnek (128287), Helena Růžičková (3862), Rudolf Deyl ml. (126471), František Černý (127313), Raoul Schránil (5103), Jiří H
# ...

# %%
páry = [
    ["Jaromír Hanzlík (14425)","Daniela Kolářová (1847)"],
    ["Josef Abrhám (2274)","Libuše Šafránková (2272)"]
]
