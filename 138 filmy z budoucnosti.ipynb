# %%
import os

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_json(os.path.join("data", "filmy.json"))

# %%
df[df['Obsah'].str.lower().str.contains('2024',na=False)]['Obsah'].to_list()
# Out:
# []

# %%
df[df['Obsah'].str.lower().str.contains('2025',na=False)]['Obsah'].to_list()
# Out:
# []

# %%
df[df['Obsah'].str.lower().str.contains('2026',na=False)]
# Out:
#               Film                                        Země původu  \
# 3542  Doom (38741)  [Velká Británie, Česká republika, Spolková rep...
#
#       Copyright Rok výroby                                           Premiéra  \
# 3542       2005       2005  slavnostní premiéra 27. 10. 2005  (multiplex V...
#
#       Minutáž                         Režie Kategorie                    Žánr  \
# 3542    105.0  [Andrzej Bartkowiak (23449)]      film  [horor, sci-fi, akční]
#
#                  Typologie Originální název Český název Anglický název  \
# 3542  [hraný, distribuční]             Doom        Doom           Doom
#
#      Souběžný název Pracovní název  \
# 3542           None           None
#
#                                                   Hrají  \
# 3542  [Karl Urban (24755), Rosamund Pike (24756), Th...
#
#                                                 Postavy  \
# 3542  [John Grimm, Samantha Grimmová, Serža, Drtič, ...
#
# ...

# %%
df[df['Obsah'].str.lower().str.contains('2026',na=False)]['Obsah'].to_list()
# Out:
# ['V roce 2026 byl v nevadské poušti objeven portál, vedoucí do pradávného města na Marsu. Byl nazván Archa. Ani o dvacet let později se vědcům nepodařilo zjistit, co se stalo s civilizací, která jej postavila. – Union Aerospace Corporation (UAC), výzkumná stanice Olduvai, Mars. Skupina vědců zoufale prchá z podzemní laboratoře, ale cosi velkého je pronásleduje a postupně je likviduje. Doktoru Carmackovi se podaří na poslední chvíli otevřít čipovou kartou dveře a ohlásit na Zemi, že došlo ke katastrofě a že je třeba zavést karanténu 5. stupně. Na ocelové dveře cosi buší tak mocně, že praskají… – Speciální útvar vojenského námořnictva, Kalifornie, USA. Svalnatý seržant RRTS (Rapid Response Tactical Squad) dostane rozkaz zjistit se svým oddílem stupeň ohrožení na Olduvai, zachránit majetek UAC a jakýmikoliv prostředky zachovat karanténu u obou vstupů Archy i za cenu likvidace lidí. Na Olduvai je podle hlášení šest vědců zamčených v laboratoři a dalších devětasedmdesát zaměstnanců UAC. –
# ...
