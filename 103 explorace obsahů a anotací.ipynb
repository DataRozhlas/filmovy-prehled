# %%
import os

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_json(os.path.join("data", "filmy.json"))

# %% [markdown]
# Bacha:
# - povídkové filmy
# - české/německé verze
# - forman

# %% [markdown]
# ## Anotace

# %%
(df[(df["Délka"] == "dlouhometrážní") & (~df["Anotace"].isnull())].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní")].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
df[(df["Délka"] == "dlouhometrážní") & (~df["Anotace"].isnull())]["Anotace"]
# Out:
# 145     Kreslená groteska s hrdiny z prostředí americk...
# 274     Jeden z nejvýraznějších filmařů počátků českos...
# 308     Zrestaurovaný poetický němý snímek Pohádka máj...
# 324     Němá veselohra Svatopluka Innemanna Falešná ko...
# 346     Němou komedii Milenky starého kriminálníka (19...
#                               ...
# 4520    Režisér, herec a dramatik Jiří Havelka (nar. 1...
# 4521    Komedií Po čem muži touží 2 navázal režisér Ru...
# 4522    V umělecké eseji Až zařve lev kombinuje režisé...
# 4523    Celovečerní dokumentární snímek Planeta Praha ...
# 4524    Autorský film Identita ES zkušené dokumentaris...
# Name: Anotace, Length: 2050, dtype: object

# %%
df[(df["Délka"] == "dlouhometrážní") & (~df["Anotace"].isnull())]["Anotace"].to_list()
# Out:
# ['Kreslená groteska s hrdiny z prostředí amerického divokého západu.',
#  'Jeden z nejvýraznějších filmařů počátků československé kinematografie Karel Lamač zaznamenal úspěch s melodramatem Bílý ráj. Příběh i řemeslné zpracování snímku ukazují poučenost americkou kinematografií. Hlavní hrdinkou je sirota Nina, do jejíhož života zasáhne uprchlý vězeň, který chce naposledy navštívit umírající matku. Film natočený se skromným rozpočtem 90 000 korun se dočkal příznivého přijetí u českých i zahraničních diváků. Kapitál na jeho výrobu poskytla společnost Kalosfilm (Karel-Anny-Lamač-Ondra-spol), kterou založil filmový nadšenec Alfréd Baštýř. Kromě Karla Lamače se na filmu podílely další dvě významné osobnosti českého filmu – Gustav Machatý a Martin Frič.',
# ...

# %% [markdown]
# ## Obsah

# %%
(df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní")].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())]["Obsah"]
# Out:
# 145     Humorné příhody Eddieho Pola a Marie Walcampov...
# 154     Jiří se setkává v nevěstinci s Lucií, která se...
# 159     Při VII. všesokolském sletu roku 1920 vypráví ...
# 162     Sochař a sběratel starých tisků Šalda získá st...
# 164     Ve vile boháče Kodeše se strhne velká hádka me...
#                               ...
# 4520    Podle neskutečné události trvající přesně 14 m...
# 4521    Moderní emancipovaná psycholožka Irena Kopáčov...
# 4522    „Věř těm, kteří hledají pravdu, a pochybuj o t...
# 4523    Údolí kolem řeky Vltavy, po tisíce let stejné,...
# 4524    Skutečné jméno osmdesátníka Emila Skamene, kan...
# Name: Obsah, Length: 2866, dtype: object

# %%
df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())]["Obsah"].to_list()
# Out:
# ['Humorné příhody Eddieho Pola a Marie Walcampové v „15 epizodách a 142 dílech“.',
#  'Jiří se setkává v nevěstinci s Lucií, která se mu svěří se svým osudem. Do nevěstince ji dal otec, pijan, který se chtěl nechat svou dcerou živit. Jiří se nad Lucií slituje a vezme ji do domu své tety. Tam ji navštíví opilý otec. Jiří se ho chce zbavit a dá mu nějaké peníze, ale celá společenská smetánka se dozví o Luciině minulosti. Lucie se seznámí s nemocným přítelem Jiřího, Rudolfem Žákem. Jiří se velmi změnil. Kandiduje na poslance a Lucie je pro něho přítěží. Varuje ji, že ji společnost nepřijme a nedovolí začít žít nový život. Rudolf umírá. Po pohřbu se Lucie u hřbitovní brány naposledy setká se svým opilým otcem. Zklamaná životem pomýšlí na sebevraždu. Nakonec se vrátí zpět do nevěstince. Její otec umírá v příkopě u silnice.',
# ...

# %%
df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull()) & (df["Copyright"] == 1953)]["Obsah"].to_list()
# Out:
# ['Agent Papoušek má v Československu povzbudit činnost špionážní skupiny a provést sabotážní akci v Severním přístavu. Do Severního přístavu nastoupí nový vedoucí tranzitního oddělení Bartoš. Ředitel Dušek není jeho příchodem nadšený, domnívá se, že ho Bartoš má nahradit ve funkci. Nelíbí se mu také, že jeho dcera Helena začala s Bartošem chodit. Bartoš hned po nástupu učiní opatření, aby zabránil nebezpečnému úniku hospodářských informací. V jeho činech ho podporuje jen Šubrt, který neustále zdůrazňuje svou uvědomělost. Jedné noci je Bartoš napaden v kanceláři neznámým mužem. V době vyšetřování přijede do Severního přístavu Papouškův společník Berka. Před předáním tašky s výbušninou zpanikaří a zahyne pod koly auta. Berka byl už z Prahy sledován Bezpečností, která spojí záhy tento případ se záležitostí Bartošovou. V „uvědomělém“ Šubrtovi pak odhalí záškodníka a dopadne ho i se společnicí. Papoušek zahyne při přestřelce s příslušníkem SNB. Po těchto událostech si všichni uvědomí nutn
# ...

# %% [markdown]
# ## Sólo df, délka anotací

# %%
obsahy = df[~df["Obsah"].isnull()][["Film","Copyright","Obsah"]]

# %%
obsahy
# Out:
#                                                    Film  Copyright
# 0      Polední výstřel na Mariánských hradbách (401709)       1898  \
# 1       Cvičení s kužely Sokolů malostranských (401704)       1898
# 2                                     Cyklisté (401705)       1898
# 3     Defilování vojska o Božím těle na Královských ...       1898
# 4                            Hanácké banderium (401707)       1898
# ...                                                 ...        ...
# 4520                         Mimořádná událost (402176)       2022
# 4521                       Po čem muži touží 2 (402173)       2022
# 4522                              Až zařve lev (402204)       2022
# 4523                             Planeta Praha (402218)       2022
# 4524                               Identita ES (402166)       2022
#
#                                                   Obsah
# 0     Na Mariánských hradbách v Praze připravuje sku...
# ...

# %%
obsahy["Rozsah"] = obsahy["Obsah"].apply(lambda x: len(x))

# %%
obsahy.sort_values(by="Rozsah").head(5)
# Out:
#                                    Film  Copyright            Obsah  Rozsah
# 4324              Okupace 1968 (401776)       2018   Povídkový film      14
# 3594  Jedné noci v jednom městě (50479)       2007   Povídkový film      14
# 3645                    Kuličky (53944)       2008   Povídkový film      14
# 3379   Mrtvý les a jiný bulšit (397709)       2000   Povídkový film      14
# 2016         U telefonu Martin (396686)       1966  Povídkový film.      15

# %%
obsahy.sort_values(by="Rozsah").tail(20)
# Out:
#                                                    Film  Copyright
# 4442                                   Bábovky (402094)       2020  \
# 4433               Můj otec Antonín Kratochvíl (402148)       2020
# 4524                               Identita ES (402166)       2022
# 4451                                     Havel (402069)       2020
# 4514                   Sny o toulavých kočkách (402146)       2021
# 4475                          Krajina ve stínu (402170)       2020
# 4395                         Forman vs. Forman (401969)       2019
# 4259                    Vítězové Anifilmu 2018 (401930)       2018
# 4462                             Příběh tantry (402060)       2020
# 4338                              Moje století (401854)       2019
# 4303                                     Toman (401772)       2018
# 4356                             Ukradený stát (402010)       2019
# 4389                                  Amundsen (401963)       2019
# ...

# %%
obsahy.groupby("Copyright")["Rozsah"].mean().plot.bar(figsize = (20,5))
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
obsahy.groupby("Copyright")["Rozsah"].median().plot.bar(figsize = (20,5))
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %% [markdown]
# ## Různé poměry

# %%
def vobsahu(x):
    x = x.lower()
    return (df[(df["Délka"] == "dlouhometrážní") & (df["Obsah"].str.lower().str.contains(x))].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))

# %%
vobsahu("kavárn")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("továrn|průmysl|fabrik|fabric")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("rozvod|rozved|rozved|rozvád")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("bombard")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("polib|políb")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("Stalin")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("svatba|oženit|vdát|provdat|zásnub|zasnoub")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("láska")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("(gay|homosex)")
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_3660\1944087335.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return (df[(df["Délka"] == "dlouhometrážní") & (df["Obsah"].str.lower().str.contains(x))].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("vražd")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("sex")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("sex|soulož|pohlavní styk")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("podnikate")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("restitu")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("spartaki")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("prostitu")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("sovětsk")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("znásiln")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("drog")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("( facka| facku)")
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_27784\1944087335.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return (df[(df["Délka"] == "dlouhometrážní") & (df["Obsah"].str.lower().str.contains(x))].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu(" pěstí")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("KSČ|komunis| strany| strana")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("autobus")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("hotel")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("(motocykl|motork|motorc)")
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_27784\1944087335.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return (df[(df["Délka"] == "dlouhometrážní") & (df["Obsah"].str.lower().str.contains(x))].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("telefon")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("notebook")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu(" mobil")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("záškrt")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("(AIDS| HIV)")
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_3324\1944087335.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return (df[(df["Délka"] == "dlouhometrážní") & (df["Obsah"].str.lower().str.contains(x))].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("dolar")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("internet")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("počítač")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("panenstv")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("partyz")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("milenk")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("(vidličk)")
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_3324\1944087335.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return (df[(df["Délka"] == "dlouhometrážní") & (df["Obsah"].str.lower().str.contains(x))].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("(potrat|interrupc)")
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_27784\1944087335.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return (df[(df["Délka"] == "dlouhometrážní") & (df["Obsah"].str.lower().str.contains(x))].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("emigr")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("(špion|špión|agent)")
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_27784\1944087335.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return (df[(df["Délka"] == "dlouhometrážní") & (df["Obsah"].str.lower().str.contains(x))].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("(milenk|milence|milenec|milenci)")
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_27784\1944087335.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return (df[(df["Délka"] == "dlouhometrážní") & (df["Obsah"].str.lower().str.contains(x))].groupby("Copyright")["Film"].nunique() / df[(df["Délka"] == "dlouhometrážní") & (~df["Obsah"].isnull())].groupby("Copyright")["Film"].nunique()).plot.bar(figsize = (20,5))
# <AxesSubplot:xlabel='Copyright'>

# %% [markdown]
# #POZN v 50s nejsou milenky

# %%
vobsahu("okupač|okupant|okupac|okupov")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("revoluc|revoluč")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("socialis")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("komunist")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %% [markdown]
# #POZN zajímavý, v 80s ve filmech skoro nejsou komunisti

# %%
vobsahu("nacist")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("svatební noc")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %%
vobsahu("víkend")
# Out:
# <AxesSubplot:xlabel='Copyright'>

# %% [markdown]
# ## Nápady do GPT

# %% [markdown]
# - odehrává se film v minulosti, přítomnosti, nebo budoucnosti?
